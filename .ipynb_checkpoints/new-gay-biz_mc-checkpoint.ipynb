# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
gaybizDf = pd.read_pickle('/Users/michaelcriste/Documents/GitHub/informal-queer-spaces/data/newgaybiz_clean.pandas')
gaybizDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1737 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   business_id       1737 non-null   object
#  1   gay_text          1737 non-null   object
#  2   gay_text_len      1737 non-null   object
#  3   gay_counts        1737 non-null   object
#  4   gay_unique_count  1737 non-null   object
#  5   known             1737 non-null   object
# dtypes: object(6)
# memory usage: 95.0+ KB

# %%
gaybizDf.head()
# Out:
#               business_id                                           gay_text  \
# 0  wPi7p5fZyGTOjDU28IlTqA  [gay, gay, lgbtq, gay, gay, gay, gay, gay, gay...
# 1  FhwTEGqdir75uyXZqWqxlw  [gay, gay, gay, gay, gay, gay, gay, gay, gay, ...
# 2  ZH41CKIlAZrrQD-DMV2TWA  [drag, drag, drag, drag, drag, drag, drag, dra...
# 3  4FHXsFTyvvxc-pISdYkoeQ  [lesbians, lesbian, lesbians, gay, lesbians, l...
# 4  IORvbG2rAIVJ-1d148cCmg  [drag, gay, gay, queer, gay, gay, gay, gay, qu...
#
#   gay_text_len                                         gay_counts  \
# 0          222  {'gay': 178, 'lgbtq': 5, 'twinks': 1, 'lesbian...
# 1          169  {'gay': 153, 'gays': 5, 'queen': 9, 'homophobi...
# 2          165  {'drag': 130, 'queens': 10, 'gay': 12, 'homose...
# 3          105  {'lesbians': 16, 'lesbian': 40, 'gay': 31, 'qu...
# 4           90  {'drag': 10, 'gay': 54, 'queer': 9, 'queen': 2...
#
#   gay_unique_count  known
# 0               13   True
# 1                5  False
# 2                9   True
# 3                9  False
# 4               10   True

# %%
phillybizDf = pd.read_pickle('/Users/michaelcriste/Documents/GitHub/informal-queer-spaces/data/bizPhil.pandas')
phillybizDf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 44840 entries, 3 to 150339
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   44840 non-null  object
#  1   name          44840 non-null  object
#  2   address       44840 non-null  object
#  3   city          44840 non-null  object
#  4   state         44840 non-null  object
#  5   postal_code   44840 non-null  object
#  6   latitude      44840 non-null  float64
#  7   longitude     44840 non-null  float64
#  8   stars         44840 non-null  float64
#  9   review_count  44840 non-null  int64
#  10  is_open       44840 non-null  int64
#  11  attributes    40920 non-null  object
#  12  categories    44802 non-null  object
#  13  hours         37236 non-null  object
#  14  geometry      44840 non-null  geometry
# dtypes: float64(3), geometry(1), int64(2), object(9)
# memory usage: 5.5+ MB

# %%
phillybizDf.head()
# Out:
#                business_id                           name        address  \
# 3   MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries    935 Race St
# 4   mWMc6_wTdE0EUBKIGXDVfA       Perkiomen Valley Brewery  101 Walnut St
# 15  MUTTqe8uqyMdBl186RmNeA                       Tuna Bar    205 Race St
# 19  ROeacJQwBeh05Rqg7F6TCg                            BAP  1224 South St
# 25  PSo_C1Sfa13JHjzVNW6ziQ  Indian Walk Veterinary Center  662 Durham Rd
#
#             city state postal_code   latitude  longitude  stars  review_count  \
# 3   Philadelphia    PA       19107  39.955505 -75.155564    4.0            80
# 4     Green Lane    PA       18054  40.338183 -75.471659    4.5            13
# 15  Philadelphia    PA       19106  39.953949 -75.143226    4.0           245
# 19  Philadelphia    PA       19147  39.943223 -75.162568    4.5           205
# 25       Newtown    PA       18940  40.273493 -74.987496    5.0            15
#
#     is_open                                         attributes  \
# 3         1  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4         1  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 15        1  {'RestaurantsReservations': 'True', 'Restauran...
# 19        1  {'NoiseLevel': 'u'quiet'', 'GoodForMeal': '{'d...
# 25        1                                               None
#
#                                            categories  \
# 3   Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                           Brewpubs, Breweries, Food
# 15                  Sushi Bars, Restaurants, Japanese
# 19                                Korean, Restaurants
# 25    Pet Services, Pet Groomers, Pets, Veterinarians
#
#                                                 hours  \
# 3   {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4   {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# 15  {'Tuesday': '13:30-22:0', 'Wednesday': '13:30-...
# 19  {'Monday': '11:30-20:30', 'Tuesday': '11:30-20...
# 25  {'Monday': '8:0-19:0', 'Tuesday': '8:0-19:0', ...
#
#                       geometry
# 3   POINT (-75.15556 39.95551)
# 4   POINT (-75.47166 40.33818)
# 15  POINT (-75.14323 39.95395)
# 19  POINT (-75.16257 39.94322)
# 25  POINT (-74.98750 40.27349)

# %%
joinedDf = pd.merge(gaybizDf, phillybizDf, how='left', on='business_id')
joinedDf.head()
# Out:
#               business_id                                           gay_text  \
# 0  wPi7p5fZyGTOjDU28IlTqA  [gay, gay, lgbtq, gay, gay, gay, gay, gay, gay...
# 1  FhwTEGqdir75uyXZqWqxlw  [gay, gay, gay, gay, gay, gay, gay, gay, gay, ...
# 2  ZH41CKIlAZrrQD-DMV2TWA  [drag, drag, drag, drag, drag, drag, drag, dra...
# 3  4FHXsFTyvvxc-pISdYkoeQ  [lesbians, lesbian, lesbians, gay, lesbians, l...
# 4  IORvbG2rAIVJ-1d148cCmg  [drag, gay, gay, queer, gay, gay, gay, gay, qu...
#
#   gay_text_len                                         gay_counts  \
# 0          222  {'gay': 178, 'lgbtq': 5, 'twinks': 1, 'lesbian...
# 1          169  {'gay': 153, 'gays': 5, 'queen': 9, 'homophobi...
# 2          165  {'drag': 130, 'queens': 10, 'gay': 12, 'homose...
# 3          105  {'lesbians': 16, 'lesbian': 40, 'gay': 31, 'qu...
# 4           90  {'drag': 10, 'gay': 54, 'queer': 9, 'queen': 2...
#
#   gay_unique_count  known                            name  \
# 0               13   True                         Woody's
# 1                5  False               Big Gay Ice Cream
# 2                9   True                 Bob & Barbara's
# 3                9  False  Sisters Restaurant & Nightclub
# 4               10   True                Voyeur Nightclub
#
#                address          city state postal_code   latitude  longitude  \
# 0        202 S 13th St  Philadelphia    PA       19107  39.949064 -75.162410
# 1        1351 South St  Philadelphia    PA       19147  39.943738 -75.165094
# 2        1509 South St  Philadelphia    PA       19146  39.944050 -75.167550
# 3   1320 Chancellor St  Philadelphia    PA       19107  39.948499 -75.163109
# 4  1221 Saint James St  Philadelphia    PA       19107  39.948345 -75.161863
#
#    stars  review_count  is_open  \
# 0    3.0         325.0      1.0
# 1    3.5         404.0      0.0
# 2    4.0         295.0      1.0
# 3    3.0          51.0      0.0
# 4    3.0         163.0      1.0
#
#                                           attributes  \
# 0  {'BusinessParking': '{'garage': False, 'street...
# 1  {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 2  {'RestaurantsGoodForGroups': 'True', 'BikePark...
# 3  {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 4  {'RestaurantsPriceRange2': '2', 'NoiseLevel': ...
#
#                                           categories  \
# 0  Restaurants, Bars, American (Traditional), Gay...
# 1  Ice Cream & Frozen Yogurt, Party & Event Plann...
# 2  Lounges, Bars, Nightlife, Dive Bars, Adult Ent...
# 3  Bars, Restaurants, Dance Clubs, Gay Bars, Nigh...
# 4             Nightlife, Dance Clubs, Gay Bars, Bars
#
#                                                hours  \
# 0  {'Monday': '19:0-2:0', 'Tuesday': '19:0-2:0', ...
# 1  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 2  {'Wednesday': '16:0-2:0', 'Thursday': '16:0-2:...
# 3                                               None
# 4  {'Tuesday': '23:45-3:0', 'Wednesday': '23:0-3:...
#
#                      geometry
# 0  POINT (-75.16241 39.94906)
# 1  POINT (-75.16509 39.94374)
# 2  POINT (-75.16755 39.94405)
# 3  POINT (-75.16311 39.94850)
# 4  POINT (-75.16186 39.94834)

# %%
joinedDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1737 entries, 0 to 1736
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   business_id       1737 non-null   object
#  1   gay_text          1737 non-null   object
#  2   gay_text_len      1737 non-null   object
#  3   gay_counts        1737 non-null   object
#  4   gay_unique_count  1737 non-null   object
#  5   known             1737 non-null   object
#  6   name              1731 non-null   object
#  7   address           1731 non-null   object
#  8   city              1731 non-null   object
#  9   state             1731 non-null   object
#  10  postal_code       1731 non-null   object
#  11  latitude          1731 non-null   float64
#  12  longitude         1731 non-null   float64
#  13  stars             1731 non-null   float64
#  14  review_count      1731 non-null   float64
#  15  is_open           1731 non-null   float64
#  16  attributes        1653 non-null   object
#  17  categories        1731 non-null   object
#  18  hours             1576 non-null   object
#  19  geometry          1731 non-null   geometry
# dtypes: float64(5), geometry(1), object(14)
# memory usage: 285.0+ KB

# %%
joinedDf.tail(100)
# Out:
#                  business_id        gay_text gay_text_len  \
# 1637  p6BHu9wwWTWpVgGcnZOQqA  [queer, queer]            2
# 1638  pF5W8eHkP6bvQjCgoj2MCA    [bear, bear]            2
# 1639  68jYcCg7p8zEeArIUgky9Q    [bears, gay]            2
# 1640  6CUkqed0rhHtFwQ2i7Otsw    [bear, bear]            2
# 1641  7Ld1DxAhSlGSateku0iqbg    [bear, drag]            2
# ...                      ...             ...          ...
# 1732  9UD0Smup80sh-c7zc9ySdA
# 1733                  #NAME?
# 1734  9RotEBfTRO5rZl2StsC5Og
# 1735  43_EES4bS7l-jQVZhqx9Pw
# 1736  Qc974_Ezjpqg2wW5uoEUxA
#
#                   gay_counts gay_unique_count  known  \
# 1637            {'queer': 2}                1  False
# 1638             {'bear': 2}                1  False
# 1639  {'bears': 1, 'gay': 1}                2  False
# 1640             {'bear': 2}                1  False
# 1641  {'bear': 1, 'drag': 1}                2  False
# ...                      ...              ...    ...
# 1732
# 1733
# 1734
# 1735
# 1736
#
#                               name              address          city state  \
# 1637             Wooden Shoe Books         704 South St  Philadelphia    PA
# 1638               Furniture Mecca   5648 Lancaster Ave  Philadelphia    PA
# 1639                         James         824 S 8th St  Philadelphia    PA
# 1640   Barcelona Wine Bar Passyunk  1709 E Passyunk Ave  Philadelphia    PA
# 1641            Ristorante Attilio   1900 Lancaster Ave    Wilmington    DE
# ...                            ...                  ...           ...   ...
# 1732  Danny's Midnight Confessions        133 S 13th St  Philadelphia    PA
# 1733                           NaN                  NaN           NaN   NaN
# 1734                      Rosewood       1302 Walnut St  Philadelphia    PA
# 1735                           NaN                  NaN           NaN   NaN
# 1736         Level Up Bar & Lounge       1330 Walnut St  Philadelphia    PA
#
#      postal_code   latitude  longitude  stars  review_count  is_open  \
# 1637       19147  39.942081 -75.154162    4.5          32.0      1.0
# 1638       19131  39.980125 -75.235420    1.5          28.0      1.0
# 1639       19147  39.938877 -75.156333    4.0         101.0      0.0
# 1640       19148  39.928085 -75.165255    4.5         608.0      1.0
# 1641       19805  39.746369 -75.573711    4.0          50.0      1.0
# ...          ...        ...        ...    ...           ...      ...
# 1732       19107  39.949469 -75.161737    4.0          34.0      1.0
# 1733         NaN        NaN        NaN    NaN           NaN      NaN
# 1734       19107  39.948965 -75.162311    3.0          12.0      1.0
# 1735         NaN        NaN        NaN    NaN           NaN      NaN
# 1736       19107  39.949152 -75.163395    3.5           5.0      1.0
#
#                                              attributes  \
# 1637  {'BusinessParking': '{'garage': False, 'street...
# 1638  {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 1639  {'BYOBCorkage': ''no'', 'RestaurantsAttire': '...
# 1640  {'HasTV': 'False', 'Music': '{'dj': False, 'ba...
# 1641  {'RestaurantsGoodForGroups': 'True', 'HasTV': ...
# ...                                                 ...
# 1732  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1733                                                NaN
# 1734  {'OutdoorSeating': 'False', 'Alcohol': 'u'full...
# 1735                                                NaN
# 1736  {'RestaurantsTableService': 'True', 'Restauran...
#
#                                              categories  \
# 1637   Books, Mags, Music & Video, Bookstores, Shopping
# 1638          Furniture Stores, Shopping, Home & Garden
# 1639  Automotive, Bars, Restaurants, Nightlife, Amer...
# 1640  Nightlife, Bars, Restaurants, Wine Bars, Tapas...
# 1641                               Restaurants, Italian
# ...                                                 ...
# 1732  Adult, Books, Mags, Music & Video, Shopping, B...
# 1733                                                NaN
# 1734  Cocktail Bars, Gay Bars, Bars, Lounges, Nightlife
# 1735                                                NaN
# 1736  American (Traditional), Restaurants, Nightlife...
#
#                                                   hours  \
# 1637  {'Monday': '12:0-22:0', 'Tuesday': '12:0-22:0'...
# 1638  {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...
# 1639  {'Tuesday': '17:0-22:0', 'Wednesday': '17:0-22...
# 1640  {'Monday': '11:0-0:0', 'Tuesday': '16:0-23:0',...
# 1641  {'Tuesday': '11:0-21:0', 'Wednesday': '11:0-21...
# ...                                                 ...
# 1732  {'Monday': '5:0-2:0', 'Tuesday': '5:0-2:0', 'W...
# 1733                                                NaN
# 1734     {'Friday': '22:0-2:0', 'Saturday': '22:0-2:0'}
# 1735                                                NaN
# 1736  {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...
#
#                         geometry
# 1637  POINT (-75.15416 39.94208)
# 1638  POINT (-75.23542 39.98012)
# 1639  POINT (-75.15633 39.93888)
# 1640  POINT (-75.16525 39.92808)
# 1641  POINT (-75.57371 39.74637)
# ...                          ...
# 1732  POINT (-75.16174 39.94947)
# 1733                        None
# 1734  POINT (-75.16231 39.94897)
# 1735                        None
# 1736  POINT (-75.16339 39.94915)
#
# [100 rows x 20 columns]

# %%
joinedDf.replace(r'^\s*$', np.nan, regex=True)
# Out:
#                  business_id  \
# 0     wPi7p5fZyGTOjDU28IlTqA
# 1     FhwTEGqdir75uyXZqWqxlw
# 2     ZH41CKIlAZrrQD-DMV2TWA
# 3     4FHXsFTyvvxc-pISdYkoeQ
# 4     IORvbG2rAIVJ-1d148cCmg
# ...                      ...
# 1732  9UD0Smup80sh-c7zc9ySdA
# 1733                  #NAME?
# 1734  9RotEBfTRO5rZl2StsC5Og
# 1735  43_EES4bS7l-jQVZhqx9Pw
# 1736  Qc974_Ezjpqg2wW5uoEUxA
#
#                                                gay_text  gay_text_len  \
# 0     [gay, gay, lgbtq, gay, gay, gay, gay, gay, gay...         222.0
# 1     [gay, gay, gay, gay, gay, gay, gay, gay, gay, ...         169.0
# 2     [drag, drag, drag, drag, drag, drag, drag, dra...         165.0
# 3     [lesbians, lesbian, lesbians, gay, lesbians, l...         105.0
# 4     [drag, gay, gay, queer, gay, gay, gay, gay, qu...          90.0
# ...                                                 ...           ...
# 1732                                                NaN           NaN
# 1733                                                NaN           NaN
# 1734                                                NaN           NaN
# 1735                                                NaN           NaN
# 1736                                                NaN           NaN
#
#                                              gay_counts  gay_unique_count  \
# 0     {'gay': 178, 'lgbtq': 5, 'twinks': 1, 'lesbian...              13.0
# 1     {'gay': 153, 'gays': 5, 'queen': 9, 'homophobi...               5.0
# 2     {'drag': 130, 'queens': 10, 'gay': 12, 'homose...               9.0
# 3     {'lesbians': 16, 'lesbian': 40, 'gay': 31, 'qu...               9.0
# 4     {'drag': 10, 'gay': 54, 'queer': 9, 'queen': 2...              10.0
# ...                                                 ...               ...
# 1732                                                NaN               NaN
# 1733                                                NaN               NaN
# 1734                                                NaN               NaN
# 1735                                                NaN               NaN
# 1736                                                NaN               NaN
#
#       known                            name              address  \
# 0      True                         Woody's        202 S 13th St
# 1     False               Big Gay Ice Cream        1351 South St
# 2      True                 Bob & Barbara's        1509 South St
# 3     False  Sisters Restaurant & Nightclub   1320 Chancellor St
# 4      True                Voyeur Nightclub  1221 Saint James St
# ...     ...                             ...                  ...
# 1732    NaN    Danny's Midnight Confessions        133 S 13th St
# 1733    NaN                             NaN                  NaN
# 1734    NaN                        Rosewood       1302 Walnut St
# 1735    NaN                             NaN                  NaN
# 1736    NaN           Level Up Bar & Lounge       1330 Walnut St
#
#               city state postal_code   latitude  longitude  stars  \
# 0     Philadelphia    PA       19107  39.949064 -75.162410    3.0
# 1     Philadelphia    PA       19147  39.943738 -75.165094    3.5
# 2     Philadelphia    PA       19146  39.944050 -75.167550    4.0
# 3     Philadelphia    PA       19107  39.948499 -75.163109    3.0
# 4     Philadelphia    PA       19107  39.948345 -75.161863    3.0
# ...            ...   ...         ...        ...        ...    ...
# 1732  Philadelphia    PA       19107  39.949469 -75.161737    4.0
# 1733           NaN   NaN         NaN        NaN        NaN    NaN
# 1734  Philadelphia    PA       19107  39.948965 -75.162311    3.0
# 1735           NaN   NaN         NaN        NaN        NaN    NaN
# 1736  Philadelphia    PA       19107  39.949152 -75.163395    3.5
#
#       review_count  is_open  \
# 0            325.0      1.0
# 1            404.0      0.0
# 2            295.0      1.0
# 3             51.0      0.0
# 4            163.0      1.0
# ...            ...      ...
# 1732          34.0      1.0
# 1733           NaN      NaN
# 1734          12.0      1.0
# 1735           NaN      NaN
# 1736           5.0      1.0
#
#                                              attributes  \
# 0     {'BusinessParking': '{'garage': False, 'street...
# 1     {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 2     {'RestaurantsGoodForGroups': 'True', 'BikePark...
# 3     {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 4     {'RestaurantsPriceRange2': '2', 'NoiseLevel': ...
# ...                                                 ...
# 1732  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1733                                                NaN
# 1734  {'OutdoorSeating': 'False', 'Alcohol': 'u'full...
# 1735                                                NaN
# 1736  {'RestaurantsTableService': 'True', 'Restauran...
#
#                                              categories  \
# 0     Restaurants, Bars, American (Traditional), Gay...
# 1     Ice Cream & Frozen Yogurt, Party & Event Plann...
# 2     Lounges, Bars, Nightlife, Dive Bars, Adult Ent...
# 3     Bars, Restaurants, Dance Clubs, Gay Bars, Nigh...
# 4                Nightlife, Dance Clubs, Gay Bars, Bars
# ...                                                 ...
# 1732  Adult, Books, Mags, Music & Video, Shopping, B...
# 1733                                                NaN
# 1734  Cocktail Bars, Gay Bars, Bars, Lounges, Nightlife
# 1735                                                NaN
# 1736  American (Traditional), Restaurants, Nightlife...
#
#                                                   hours  \
# 0     {'Monday': '19:0-2:0', 'Tuesday': '19:0-2:0', ...
# 1     {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 2     {'Wednesday': '16:0-2:0', 'Thursday': '16:0-2:...
# 3                                                  None
# 4     {'Tuesday': '23:45-3:0', 'Wednesday': '23:0-3:...
# ...                                                 ...
# 1732  {'Monday': '5:0-2:0', 'Tuesday': '5:0-2:0', 'W...
# 1733                                                NaN
# 1734     {'Friday': '22:0-2:0', 'Saturday': '22:0-2:0'}
# 1735                                                NaN
# 1736  {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...
#
#                         geometry
# 0     POINT (-75.16241 39.94906)
# 1     POINT (-75.16509 39.94374)
# 2     POINT (-75.16755 39.94405)
# 3     POINT (-75.16311 39.94850)
# 4     POINT (-75.16186 39.94834)
# ...                          ...
# 1732  POINT (-75.16174 39.94947)
# 1733                        None
# 1734  POINT (-75.16231 39.94897)
# 1735                        None
# 1736  POINT (-75.16339 39.94915)
#
# [1737 rows x 20 columns]

# %%
# joinedDf['known'] = joinedDf['known'].fillna(True)
# joinedDf
# This is emptied the NaN values 

# joinedDf['known'] = joinedDf['known'].map({'NaN': True, 'no': False}) 
# # This just turned everything into NaN...the opposite of helpful

joinedDf.known = joinedDf.known.fillna(True)

# %%
joinedDf
# Out:
#                  business_id  \
# 0     wPi7p5fZyGTOjDU28IlTqA
# 1     FhwTEGqdir75uyXZqWqxlw
# 2     ZH41CKIlAZrrQD-DMV2TWA
# 3     4FHXsFTyvvxc-pISdYkoeQ
# 4     IORvbG2rAIVJ-1d148cCmg
# ...                      ...
# 1732  9UD0Smup80sh-c7zc9ySdA
# 1733                  #NAME?
# 1734  9RotEBfTRO5rZl2StsC5Og
# 1735  43_EES4bS7l-jQVZhqx9Pw
# 1736  Qc974_Ezjpqg2wW5uoEUxA
#
#                                                gay_text gay_text_len  \
# 0     [gay, gay, lgbtq, gay, gay, gay, gay, gay, gay...          222
# 1     [gay, gay, gay, gay, gay, gay, gay, gay, gay, ...          169
# 2     [drag, drag, drag, drag, drag, drag, drag, dra...          165
# 3     [lesbians, lesbian, lesbians, gay, lesbians, l...          105
# 4     [drag, gay, gay, queer, gay, gay, gay, gay, qu...           90
# ...                                                 ...          ...
# 1732
# 1733
# 1734
# 1735
# 1736
#
#                                              gay_counts gay_unique_count  \
# 0     {'gay': 178, 'lgbtq': 5, 'twinks': 1, 'lesbian...               13
# 1     {'gay': 153, 'gays': 5, 'queen': 9, 'homophobi...                5
# 2     {'drag': 130, 'queens': 10, 'gay': 12, 'homose...                9
# 3     {'lesbians': 16, 'lesbian': 40, 'gay': 31, 'qu...                9
# 4     {'drag': 10, 'gay': 54, 'queer': 9, 'queen': 2...               10
# ...                                                 ...              ...
# 1732
# 1733
# 1734
# 1735
# 1736
#
#       known                            name              address  \
# 0      True                         Woody's        202 S 13th St
# 1     False               Big Gay Ice Cream        1351 South St
# 2      True                 Bob & Barbara's        1509 South St
# 3     False  Sisters Restaurant & Nightclub   1320 Chancellor St
# 4      True                Voyeur Nightclub  1221 Saint James St
# ...     ...                             ...                  ...
# 1732           Danny's Midnight Confessions        133 S 13th St
# 1733                                    NaN                  NaN
# 1734                               Rosewood       1302 Walnut St
# 1735                                    NaN                  NaN
# 1736                  Level Up Bar & Lounge       1330 Walnut St
#
#               city state postal_code   latitude  longitude  stars  \
# 0     Philadelphia    PA       19107  39.949064 -75.162410    3.0
# 1     Philadelphia    PA       19147  39.943738 -75.165094    3.5
# 2     Philadelphia    PA       19146  39.944050 -75.167550    4.0
# 3     Philadelphia    PA       19107  39.948499 -75.163109    3.0
# 4     Philadelphia    PA       19107  39.948345 -75.161863    3.0
# ...            ...   ...         ...        ...        ...    ...
# 1732  Philadelphia    PA       19107  39.949469 -75.161737    4.0
# 1733           NaN   NaN         NaN        NaN        NaN    NaN
# 1734  Philadelphia    PA       19107  39.948965 -75.162311    3.0
# 1735           NaN   NaN         NaN        NaN        NaN    NaN
# 1736  Philadelphia    PA       19107  39.949152 -75.163395    3.5
#
#       review_count  is_open  \
# 0            325.0      1.0
# 1            404.0      0.0
# 2            295.0      1.0
# 3             51.0      0.0
# 4            163.0      1.0
# ...            ...      ...
# 1732          34.0      1.0
# 1733           NaN      NaN
# 1734          12.0      1.0
# 1735           NaN      NaN
# 1736           5.0      1.0
#
#                                              attributes  \
# 0     {'BusinessParking': '{'garage': False, 'street...
# 1     {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 2     {'RestaurantsGoodForGroups': 'True', 'BikePark...
# 3     {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 4     {'RestaurantsPriceRange2': '2', 'NoiseLevel': ...
# ...                                                 ...
# 1732  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1733                                                NaN
# 1734  {'OutdoorSeating': 'False', 'Alcohol': 'u'full...
# 1735                                                NaN
# 1736  {'RestaurantsTableService': 'True', 'Restauran...
#
#                                              categories  \
# 0     Restaurants, Bars, American (Traditional), Gay...
# 1     Ice Cream & Frozen Yogurt, Party & Event Plann...
# 2     Lounges, Bars, Nightlife, Dive Bars, Adult Ent...
# 3     Bars, Restaurants, Dance Clubs, Gay Bars, Nigh...
# 4                Nightlife, Dance Clubs, Gay Bars, Bars
# ...                                                 ...
# 1732  Adult, Books, Mags, Music & Video, Shopping, B...
# 1733                                                NaN
# 1734  Cocktail Bars, Gay Bars, Bars, Lounges, Nightlife
# 1735                                                NaN
# 1736  American (Traditional), Restaurants, Nightlife...
#
#                                                   hours  \
# 0     {'Monday': '19:0-2:0', 'Tuesday': '19:0-2:0', ...
# 1     {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 2     {'Wednesday': '16:0-2:0', 'Thursday': '16:0-2:...
# 3                                                  None
# 4     {'Tuesday': '23:45-3:0', 'Wednesday': '23:0-3:...
# ...                                                 ...
# 1732  {'Monday': '5:0-2:0', 'Tuesday': '5:0-2:0', 'W...
# 1733                                                NaN
# 1734     {'Friday': '22:0-2:0', 'Saturday': '22:0-2:0'}
# 1735                                                NaN
# 1736  {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...
#
#                         geometry
# 0     POINT (-75.16241 39.94906)
# 1     POINT (-75.16509 39.94374)
# 2     POINT (-75.16755 39.94405)
# 3     POINT (-75.16311 39.94850)
# 4     POINT (-75.16186 39.94834)
# ...                          ...
# 1732  POINT (-75.16174 39.94947)
# 1733                        None
# 1734  POINT (-75.16231 39.94897)
# 1735                        None
# 1736  POINT (-75.16339 39.94915)
#
# [1737 rows x 20 columns]

# %%
#this is it. Generate pickle of visible and invisible queer business
joinedDf.to_pickle('data/completegaybiz.pandas')

# %%
# after running reviewing the results, we discovered that Dairy Queen was being captured by the bag of words
dairyqueens = joinedDf[joinedDf.name=='Dairy Queen']
dairyqueens.info()
# While not outrageous, there are 29 dairy queens included in the data set (more than out visible queer business list)
# Definitiely want to remove these
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 54 to 1703
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   business_id       29 non-null     object
#  1   gay_text          29 non-null     object
#  2   gay_text_len      29 non-null     object
#  3   gay_counts        29 non-null     object
#  4   gay_unique_count  29 non-null     object
#  5   known             29 non-null     object
#  6   name              29 non-null     object
#  7   address           29 non-null     object
#  8   city              29 non-null     object
#  9   state             29 non-null     object
#  10  postal_code       29 non-null     object
#  11  latitude          29 non-null     float64
#  12  longitude         29 non-null     float64
#  13  stars             29 non-null     float64
#  14  review_count      29 non-null     float64
#  15  is_open           29 non-null     float64
#  16  attributes        29 non-null     object
#  17  categories        29 non-null     object
#  18  hours             28 non-null     object
#  19  geometry          29 non-null     geometry
# dtypes: float64(5), geometry(1), object(14)
# memory usage: 4.8+ KB

# %% [markdown]
# Understanding the distribution of Business Types:
# Many of the 'visible' queer spaces were bars. With the larger list, we would like to know what other types of spaces queer people are occupying. To find this we need analyze the categories of each indentified business

# %%
joinedDf.categories[0]
# Out:
# 'Restaurants, Bars, American (Traditional), Gay Bars, Dance Clubs, Nightlife, Pubs'

# %%
list(joinedDf.categories.unique())
# Out:
# ['Restaurants, Bars, American (Traditional), Gay Bars, Dance Clubs, Nightlife, Pubs',
#  'Ice Cream & Frozen Yogurt, Party & Event Planning, Event Planning & Services, Food, Desserts',
#  'Lounges, Bars, Nightlife, Dive Bars, Adult Entertainment',
#  'Bars, Restaurants, Dance Clubs, Gay Bars, Nightlife',
#  'Nightlife, Dance Clubs, Gay Bars, Bars',
#  'Gay Bars, Nightlife, Dance Clubs, Restaurants, Bars, American (New)',
#  'Nightlife, Bars, Lounges, Sports Bars, Gay Bars',
#  'Active Life, Museums, Zoos, Arts & Entertainment',
#  'Dance Clubs, Gay Bars, Bars, Lounges, Nightlife',
#  'Shopping, Local Services, Appliances, Home & Garden, Outlet Stores, Appliances & Repair',
#  'Nightlife, Bars, Gay Bars',
#  'American (New), Bars, Nightlife, Gay Bars, Restaurants',
#  'American (New), Bars, Restaurants, Gay Bars, Nightlife',
#  'Veterinarians, Pets',
#  'Dance Clubs, Gay Bars, Bars, Nightlife',
#  'Italian, Restaurants, Pizza',
#  'Bookstores, Thrift Stores, Shopping, Books, Mags, Music & Video',
#  'Food, Cafes, Bakeries, Southern, Breakfast & Brunch, Barbeque, American (New), Restaurants',
#  'Shopping, Appliances, Local Services, Appliances & Repair, Home & Garden',
#  'Music Venues, Nightlife, Event Planning & Services, Arts & Entertainment, Venues & Event Spaces',
#  'Jazz & Blues, Restaurants, Arts & Entertainment, Piano Bars, Italian, Bars, Nightlife',
#  'Dance Clubs, Lounges, Nightlife, Bars',
#  'Hotels, Event Planning & Services, Hotels & Travel',
#  'American (New), Nightlife, Restaurants, Arts & Entertainment, Comedy Clubs, Performing Arts, Bars',
#  'Gay Bars, Bars, Nightlife',
#  'Event Planning & Services, Hotels & Travel, Venues & Event Spaces, Hotels',
#  'Gyms, Active Life, Trainers, Fitness & Instruction',
#  'Nightlife, Restaurants, Sports Bars, Bars, Ethiopian',
#  'Hair Removal, Nail Salons, Beauty & Spas',
#  'Local Services, Community Service/Non-Profit, Health & Medical, Doctors, Family Practice, Medical Centers, Counseling & Mental Health',
#  'Wedding Planning, Event Planning & Services, Venues & Event Spaces, Hotels & Travel, Hotels',
#  "Toy Stores, Party & Event Planning, Event Planning & Services, Shopping, Kids Activities, Active Life, Accessories, Fashion, Children's Clothing",
#  'American (Traditional), American (New), Gay Bars, Nightlife, Restaurants, Bars',
#  'Gay Bars, Karaoke, Music Venues, Bars, Nightlife, Arts & Entertainment',
#  'Massage, Hair Removal, Skin Care, Beauty & Spas, Nail Salons',
#  'American (New), Nightlife, Greek, Cocktail Bars, Bars, Mediterranean, Restaurants, Pizza, Tapas Bars, Latin American, Tapas/Small Plates, Lounges',
#  'Music Venues, American (New), Arts & Entertainment, Event Planning & Services, Restaurants, Nightlife, Venues & Event Spaces',
#  'Restaurants, Sushi Bars, Food, Chinese',
#  'Nightlife, Gay Bars, Bars, Tapas Bars, Restaurants, Lounges, American (New)',
#  'Sports Bars, Gay Bars, Bars, Karaoke, Nightlife',
#  'Restaurants, Chinese',
#  'Pizza, Beer Hall, American (New), Gastropubs, Restaurants',
#  'Airport Shuttles, Buses, Limos, Transportation, Hotels & Travel',
#  'Coffee & Tea, Food, Comfort Food, American (New), Breakfast & Brunch, Restaurants',
#  'Event Planning & Services, Hotels & Travel, Bed & Breakfast, Hotels',
#  'Dinner Theater, Modern European, Restaurants',
#  'Mediterranean, Restaurants, Seafood, Greek',
#  'Bars, Restaurants, Cajun/Creole, American (Traditional), Breakfast & Brunch, Barbeque, Nightlife',
#  'Breakfast & Brunch, Food Stands, Sandwiches, Restaurants',
#  'Lounges, Bars, Restaurants, Cocktail Bars, Whiskey Bars, Nightlife, Dance Clubs, American (Traditional)',
#  'Ice Cream & Frozen Yogurt, Coffee & Tea, Food, Desserts',
#  'Hotels, Hotels & Travel, Event Planning & Services',
#  'Restaurants, African, Vegetarian, Halal, Nightlife, Bars',
#  'Burgers, Gay Bars, Bars, Nightlife, American (New), Salad, Restaurants',
#  'Ice Cream & Frozen Yogurt, Food, Burgers, Fast Food, Restaurants',
#  'Professional Services, Airports, Local Services, Hotels & Travel',
#  'Sports Bars, American (Traditional), Nightlife, Pubs, Bars, Gay Bars, Restaurants',
#  'Event Planning & Services, Hotels & Travel, Restaurants, Hotels, Seafood',
#  'Breakfast & Brunch, Restaurants, American (New), Bakeries, Cafes, Coffee & Tea, Food',
#  'Restaurants, Seafood, American (New), Nightlife, Steakhouses, Bars, Wine Bars, American (Traditional)',
#  'Local Services, Community Service/Non-Profit',
#  'Fitness & Instruction, Trainers, Gyms, Active Life',
#  'American (Traditional), Breakfast & Brunch, Bars, Restaurants, Nightlife',
#  'Kitchen & Bath, Shopping, Restaurants, Furniture Stores, Nurseries & Gardening, Home Decor, Appliances, Home & Garden',
#  'Restaurants, American (New)',
#  'Nightlife, Dance Clubs, Bars, Gay Bars',
#  'Food, Coffee & Tea, Cafes, Bakeries, Desserts, Restaurants',
#  'Chinese, Restaurants, Dim Sum, Asian Fusion, Shanghainese',
#  'Pet Services, Pet Sitting, Veterinarians, Pets',
#  'Adult Education, Arts & Entertainment, Social Clubs, Education',
#  'Coffee Roasteries, Coffee & Tea, Food, Juice Bars & Smoothies, Bakeries',
#  'Cocktail Bars, Venues & Event Spaces, Lounges, American (New), Mediterranean, Bars, Event Planning & Services, American (Traditional), Food, Restaurants, Nightlife',
#  'Nail Salons, Beauty & Spas, Massage',
#  'British, Restaurants, Gastropubs, Bars, Nightlife',
#  'Hotels, Event Planning & Services, Caterers, Hotels & Travel',
#  'Coffee & Tea, Bagels, Food, Cafes, Bakeries, Restaurants, Sandwiches',
#  'Restaurants, Burgers, American (New), Food, American (Traditional), Nightlife, Bars, Cocktail Bars, Salad',
#  'Event Planning & Services, Hotels & Travel, Venues & Event Spaces, Hotels, Restaurants',
#  'Hotels & Travel, Hotels, Event Planning & Services',
#  'Restaurants, Breakfast & Brunch, Vegan, Bagels, Food, Coffee & Tea',
#  'Shopping, Mattresses, Home & Garden, Furniture Stores',
#  'Specialty Schools, Active Life, Swimming Lessons/Schools, Fitness & Instruction, Education',
#  'Campgrounds, Hotels, Event Planning & Services, Resorts, Hotels & Travel, RV Parks',
#  'Ice Cream & Frozen Yogurt, Restaurants, Bakeries, Fast Food, Food, Burgers',
#  'Hotels & Travel, Event Planning & Services, Venues & Event Spaces, Hotels, Wedding Planning',
#  'Bars, Nightlife, Pubs, American (Traditional), Event Planning & Services, Karaoke, Restaurants, Venues & Event Spaces, Irish Pub, Sports Bars, Irish',
#  'Reflexology, American (New), Health & Medical, Beauty & Spas, Massage, Restaurants, Day Spas, Massage Therapy',
#  'Nightlife, Cuban, Breakfast & Brunch, Latin American, Restaurants, Dance Clubs, Shopping, Bars, Beer, Wine & Spirits, Food',
#  'Beauty & Spas, Hair Salons',
#  'Beauty & Spas, Nail Salons',
#  'Food, Cafes, Turkish, Bakeries, Breakfast & Brunch, Restaurants, Coffee & Tea',
#  'Automotive, Transmission Repair, Auto Repair',
#  'Breakfast & Brunch, Nightlife, Cocktail Bars, American (New), Coffee & Tea, Bars, Food, Restaurants, Desserts',
#  'Candy Stores, Shopping, Department Stores, Fast Food, Beer, Wine & Spirits, Fruits & Veggies, Chinese, Food, Ice Cream & Frozen Yogurt, Desserts, Seafood, Health Markets, Bagels, Cheese Shops, Shopping Centers, Chocolatiers & Shops, Meat Shops, Public Markets, Food Court, Wineries, Local Flavor, Ethnic Food, Restaurants, Specialty Food, Arts & Entertainment, Juice Bars & Smoothies, Seafood Markets, Farmers Market, Coffee & Tea, Bakeries, Food Stands, Dinner Theater, Sporting Goods, Grocery, Fashion',
#  'Italian, American (Traditional), Sandwiches, Fast Food, Restaurants, Local Flavor, Cheesesteaks',
#  'Art Supplies, Shopping, Cards & Stationery, Local Services, Arts & Crafts, Printing Services, Flowers & Gifts, Event Planning & Services',
#  'American (New), Restaurants, Bars, Breakfast & Brunch, Nightlife',
#  'Latin American, Venezuelan, Restaurants',
#  'Restaurants, Mediterranean, Greek, Seafood',
#  'Fish & Chips, Bakeries, Desserts, Food, Fast Food, British, Restaurants, American (Traditional)',
#  'Handyman, Heating & Air Conditioning/HVAC, Local Services, Home Services, Appliances, Home & Garden, Shopping, Appliances & Repair',
#  'Specialty Food, Candy Stores, Food, Chocolatiers & Shops, Desserts',
#  'Food, Specialty Food, Chocolatiers & Shops, Desserts, Candy Stores',
#  'Coffee & Tea, Seafood, Restaurants, Fish & Chips, Food, Mexican, Salad, Breakfast & Brunch, Sandwiches, Comfort Food',
#  'Sandwiches, Cheesesteaks, Steakhouses, Restaurants',
#  'Health & Medical, Massage, Beauty & Spas, Massage Therapy, Day Spas',
#  'Seafood, Mediterranean, Restaurants, Greek',
#  'Performing Arts, Specialty Schools, Arts & Entertainment, Nightlife, Comedy Clubs, Education, Art Schools',
#  'Professional Services, Local Services, Home Services, Masonry/Concrete, Signmaking',
#  'Seafood, Restaurants',
#  'Movers, Packing Services, Home Services',
#  'Bars, American (Traditional), Breakfast & Brunch, Music Venues, Arts & Entertainment, Nightlife, Restaurants',
#  'Fashion, Department Stores, Used, Vintage & Consignment, Shopping, Thrift Stores, Local Services, Community Service/Non-Profit',
#  'Event Planning & Services, Ice Cream & Frozen Yogurt, Food, Party & Event Planning, Burgers, Fast Food, Restaurants',
#  'Arts & Entertainment, Museums',
#  'Ice Cream & Frozen Yogurt, Restaurants, Food Stands, Food, Food Trucks',
#  'Jewelry Repair, Jewelry, Watch Repair, Local Services, Shopping',
#  'American (Traditional), Breakfast & Brunch, Diners, Fast Food, Restaurants',
#  'Ice Cream & Frozen Yogurt, Food, Burgers, Restaurants, Bakeries, Fast Food',
#  'Sandwiches, Delis, Restaurants, Cheesesteaks',
#  'Bagels, Restaurants, Cafes, Food, Coffee & Tea',
#  'Pizza, Sandwiches, Burgers, Restaurants',
#  'Venues & Event Spaces, Hotels, Event Planning & Services, Hotels & Travel',
#  'Arts & Entertainment, Performing Arts, Music Venues, Event Planning & Services, Venues & Event Spaces, Nightlife',
#  'Event Planning & Services, Hotels & Travel, Hotels',
#  'American (Traditional), Food, Salad, Burgers, Bars, Nightlife, Restaurants',
#  'Caterers, Hotels & Travel, Event Planning & Services, Hotels, Venues & Event Spaces',
#  'Mediterranean, Restaurants, Pizza, Italian',
#  'Vegan, Vegetarian, Sandwiches, American (New), Wine Bars, Cocktail Bars, Nightlife, Bars, Restaurants',
#  'Music Venues, American (Traditional), Bars, Arts & Entertainment, Restaurants, Nightlife',
#  'Nightlife, Pubs, Bars, Belgian, Restaurants, Gastropubs',
#  'Hotels & Travel, Bars, American (Traditional), Nightlife, Lounges, Hotels, Event Planning & Services, Restaurants, Venues & Event Spaces',
#  'Food, Restaurants, Pizza',
#  'Food, Health Markets, Grocery, Specialty Food',
#  'Sandwiches, Fashion, Used, Vintage & Consignment, Cheesesteaks, Restaurants, Breakfast & Brunch, Shopping',
#  'Sandwiches, Cafes, Coffee & Tea, Restaurants, Food, Breakfast & Brunch, Mediterranean, American (New)',
#  'Restaurants, Nightlife, American (Traditional), Bars, Burgers, Cocktail Bars, American (New)',
#  'Shopping, Furniture Stores, Home & Garden, Mattresses',
#  'Ice Cream & Frozen Yogurt, Restaurants, Fast Food, Burgers, Food',
#  'Ice Cream & Frozen Yogurt, Burgers, Restaurants, Food, Fast Food',
#  'Tours, Travel Services, Hotels & Travel',
#  'Restaurants, Indian',
#  'Bubble Tea, Specialty Food, Juice Bars & Smoothies, Food, Coffee & Tea',
#  'Desserts, Food',
#  'Doctors, Obstetricians & Gynecologists, Health & Medical, Fertility',
#  'Dance Clubs, Nightlife',
#  'Steakhouses, Seafood, Argentine, Restaurants',
#  'Pet Services, Pet Groomers, Veterinarians, Pets',
#  'Bagels, Food, Restaurants, Event Planning & Services, Caterers, Sandwiches, Coffee & Tea',
#  'Caterers, Cafes, Event Planning & Services, Food, Cupcakes, Bakeries, Restaurants, Desserts',
#  'Wine Bars, Bars, Nightlife, Restaurants, Italian',
#  'Japanese, Restaurants, Sushi Bars',
#  'Nightlife, Restaurants, Dive Bars, Izakaya, Bars, Sushi Bars, Japanese, Pubs',
#  'Restaurants, Nightlife, Arts & Entertainment, Seafood, Music Venues, American (New), Paint & Sip, Dance Clubs, Sandwiches, Bars',
#  'Sandwiches, Diners, Restaurants',
#  'Hair Salons, Beauty & Spas',
#  'Restaurants, American (Traditional), Seafood',
#  'Ice Cream & Frozen Yogurt, Food, Restaurants, Fast Food, Burgers',
#  'Event Planning & Services, Bars, Nightlife, Cocktail Bars, Bartenders',
#  'Beauty & Spas, Spray Tanning, Hair Removal, Nail Salons, Waxing, Tanning',
#  'Restaurants, Hot Dogs, Bars, Burgers, Beer Bar, Nightlife',
#  'Bars, Restaurants, Nightlife, American (Traditional)',
#  'Restaurants, Bars, Nightlife, Pubs, American (Traditional)',
#  'Hotels & Travel, Hotels, Event Planning & Services, Caterers',
#  'Nightlife, Bars, Food, Ethnic Food, Middle Eastern, Vegetarian, Specialty Food, Israeli, Restaurants',
#  'Food, Specialty Food, Organic Stores, Health Markets',
#  'Restaurants, Bars, Breakfast & Brunch, Eatertainment, Vegetarian, Arts & Entertainment, Cafes, Nightlife, Tabletop Games, Vegan, Themed Cafes, Shopping',
#  'Arts & Entertainment, Dance Clubs, Music Venues, Bars, Nightlife',
#  'Caterers, Event Planning & Services, Hotels, Real Estate, Apartments, Hotels & Travel, Venues & Event Spaces, Home Services',
#  'Yoga, Fitness & Instruction, Active Life',
#  'Mattresses, Shopping, Home & Garden',
#  'Restaurants, Seafood',
#  'Massage Therapy, Beauty & Spas, Health & Medical, Day Spas, Reflexology',
#  'Bagels, Coffee & Tea, Restaurants, Food, Breakfast & Brunch',
#  'African, Vegetarian, Halal, Restaurants',
#  "Arts & Crafts, Lingerie, Women's Clothing, Costumes, Fashion, Shopping, Adult",
#  'Food, Breweries, Nightlife, Pubs, Sandwiches, Comfort Food, Bars, Beer Bar, Restaurants, Breakfast & Brunch, American (New), Sports Bars, Gastropubs',
#  'Beauty & Spas, Hair Salons, Hair Stylists',
#  'Pizza, Restaurants',
#  'Lounges, Bars, Nightlife, Breakfast & Brunch, Mexican, Restaurants',
#  'Resorts, Hotels, Venues & Event Spaces, Hotels & Travel, Event Planning & Services',
#  'Ice Cream & Frozen Yogurt, Custom Cakes, Food, Cupcakes, Desserts, Specialty Food, Chocolatiers & Shops',
#  'Food, Ice Cream & Frozen Yogurt, Burgers, Fast Food, Restaurants',
#  'Fitness & Instruction, Nutritionists, Health & Medical, Active Life, Gyms, Trainers',
#  'Vegetarian, Breakfast & Brunch, American (New), Coffee & Tea, American (Traditional), Caterers, Food, Cafes, Event Planning & Services, Restaurants, Diners',
#  'Restaurants, Soul Food, Barbeque, Sandwiches, Burgers, Caterers, Event Planning & Services',
#  'Bars, Nightlife, Whiskey Bars, Burgers, Restaurants, American (New)',
#  'Pubs, Food, Breakfast & Brunch, Dance Clubs, Bars, American (New), American (Traditional), Beer, Wine & Spirits, Restaurants, Nightlife',
#  'Nightlife, Restaurants, American (Traditional), British, Food, Bars, Pubs',
#  'Seafood, Steakhouses, Restaurants, Bars, Nightlife',
#  'Bars, Restaurants, Pizza, Cheesesteaks, Italian, Beer Bar, American (Traditional), Local Flavor, Nightlife, Sandwiches',
#  'Arts & Entertainment, Bars, Jazz & Blues, Dive Bars, Nightlife',
#  'Event Planning & Services, Hotels, Venues & Event Spaces, Hotels & Travel',
#  'American (Traditional), Restaurants, Desserts, Food, Chocolatiers & Shops, American (New), Specialty Food, Breakfast & Brunch',
#  'Lounges, Nightlife, Bars, Cocktail Bars',
#  'Food, Ice Cream & Frozen Yogurt',
#  'Restaurants, Vegetarian, Beer, Wine & Spirits, Vegan, Food',
#  'Hotels & Travel, Venues & Event Spaces, Bed & Breakfast, Event Planning & Services, Vacation Rentals, Resorts, Hotels',
#  'Bars, Nightlife, British, Pubs, Breakfast & Brunch, Restaurants',
#  'Lounges, Nightlife, Bars, Restaurants, Vegan, American (New), Dive Bars, Sandwiches, Cocktail Bars, Burgers, Local Flavor',
#  'Restaurants, Arts & Entertainment, American (Traditional), Eatertainment, Event Planning & Services, Nightlife, Arcades, Bars, Venues & Event Spaces',
#  'Latin American, Argentine, Restaurants, Breakfast & Brunch, Italian, Cuban, Caribbean',
#  'Appliances & Repair, Shopping, Local Services, Outlet Stores, Home & Garden, Appliances',
#  'American (New), Bars, Nightlife, Lounges, Restaurants',
#  'Furniture Stores, Shopping, Mattresses, Home & Garden',
#  'Food, Gluten-Free, Desserts, Bakeries, Restaurants',
#  'French, American (New), Restaurants',
#  'Event Planning & Services, Hotels, Hotels & Travel, Venues & Event Spaces',
#  'Nightlife, Sushi Bars, Cafes, Japanese, Bars, Restaurants',
#  'Restaurants, Mexican',
#  'Obstetricians & Gynecologists, Health & Medical, Doctors, Optometrists',
#  'Transmission Repair, Automotive, Auto Repair',
#  'Bars, Burgers, Chicken Wings, Restaurants, Pubs, Nightlife, American (Traditional), Irish',
#  'Pizza, Restaurants, Food Delivery Services, Food, Italian',
#  'Fitness & Instruction, Active Life, Gyms',
#  'American (New), Cocktail Bars, Bartenders, Nightlife, Bars, Event Planning & Services, Restaurants',
#  'Coffee & Tea, Food',
#  'American (Traditional), Food, Restaurants, Breweries',
#  'Family Practice, Health & Medical, Doctors',
#  'Coffee & Tea, Specialty Food, Desserts, Candy Stores, Food, Local Flavor, Chocolatiers & Shops',
#  'Landmarks & Historical Buildings, Public Services & Government',
#  'Latin American, Nightlife, Cocktail Bars, Caribbean, Cuban, Restaurants, Bars',
#  'Fast Food, Burgers, Restaurants, Ice Cream & Frozen Yogurt, Food',
#  'American (New), Bars, Nightlife, Cocktail Bars, Arts & Entertainment, Lounges, Event Planning & Services, Venues & Event Spaces, Restaurants, Music Venues',
#  'Beer, Wine & Spirits, Food',
#  'Veterinarians, Pets, Pet Services, Pet Sitting, Pet Boarding',
#  'Breweries, Restaurants, Food, Cafes',
#  'Italian, Pizza, Restaurants',
#  'Ski Resorts, Ziplining, Active Life, Hotels & Travel, Climbing',
#  'Breakfast & Brunch, Lounges, Bars, Cocktail Bars, Nightlife, American (Traditional), American (New), Restaurants',
#  'Restaurants, Italian',
#  'Shopping, Comic Books, Hobby Shops, Books, Mags, Music & Video, Toy Stores',
#  'Ice Cream & Frozen Yogurt, Desserts, Food',
#  'Restaurants, Cocktail Bars, American (New), Desserts, American (Traditional), Nightlife, Bars, Food',
#  'Cocktail Bars, Food Delivery Services, Nightlife, Breakfast & Brunch, Food, Bars, Event Planning & Services, Caterers, Restaurants, Indian',
#  'Food, Coffee & Tea',
#  'American (New), Restaurants',
#  'Appliances, Appliances & Repair, Electronics, Home & Garden, Local Services, Mattresses, Shopping',
#  'Food, Sandwiches, Ice Cream & Frozen Yogurt, Comfort Food, Breakfast & Brunch, Diners, Restaurants, Desserts',
#  'Sandwiches, Gluten-Free, Restaurants, Pizza, Salad',
#  'Cocktail Bars, Nightlife, Lounges, Bars',
#  'Restaurants, Fast Food, Food, Burgers, Ice Cream & Frozen Yogurt',
#  'Fast Food, Ice Cream & Frozen Yogurt, Food, Restaurants, Burgers',
#  'Restaurants, Nightlife, Sandwiches, Music Venues, Arts & Entertainment, American (New), Cafes, Burgers, American (Traditional)',
#  'American (Traditional), Restaurants, Venues & Event Spaces, Hotels, Event Planning & Services, Hotels & Travel',
#  'Restaurants, Bars, Nightlife, American (New)',
#  'Food, Fast Food, Restaurants, Burgers, Ice Cream & Frozen Yogurt, Bakeries',
#  'Restaurants, Steakhouses, Seafood',
#  'Event Planning & Services, Performing Arts, Party & Event Planning, Arts & Entertainment, Music Venues, Nightlife, Venues & Event Spaces',
#  'Seafood, Steakhouses, Brazilian, Restaurants',
#  'Bars, Nightlife, Dive Bars, Restaurants',
#  'Coffee & Tea, Desserts, Food, Restaurants, Cafes',
#  'Restaurants, Vegetarian, Chinese, Seafood',
#  'Social Clubs, Bars, Venues & Event Spaces, Performing Arts, Event Planning & Services, Nightlife, Arts & Entertainment, Comedy Clubs, Local Flavor',
#  'Tex-Mex, Restaurants, Food, Nightlife, Beer, Wine & Spirits, Pubs, Bars, Mexican',
#  'Bars, Restaurants, Greek, Nightlife, Mediterranean',
#  'Bars, Nightlife, American (New), Gastropubs, Food Trucks, Parks, Restaurants, Beer Gardens, Active Life, Barbeque, Food, Beer, Wine & Spirits, American (Traditional)',
#  'Restaurants, Middle Eastern, Breakfast & Brunch, Turkish, Mediterranean, Halal',
#  'Burgers, Caterers, Restaurants, Nightlife, American (Traditional), Bars, Event Planning & Services',
#  'Chinese, Asian Fusion, Japanese, Restaurants',
#  'Bookstores, Shopping, Flea Markets, Newspapers & Magazines, Books, Mags, Music & Video, Thrift Stores',
#  'Spanish, Puerto Rican, Restaurants, American (New), French, American (Traditional), Caribbean',
#  'Hotels & Travel, Hotels, Event Planning & Services, Venues & Event Spaces',
#  'Caterers, Hotels & Travel, Mediterranean, Hotels, Event Planning & Services, American (New), Bars, Nightlife, Whiskey Bars, Restaurants, Seafood, Bed & Breakfast, Venues & Event Spaces',
#  'Ice Cream & Frozen Yogurt, Burgers, Food, Restaurants, Fast Food',
#  'Italian, American (New), Restaurants',
#  'Food, Shopping, Specialty Food, Candy Stores, Chocolatiers & Shops',
#  'Venues & Event Spaces, Event Planning & Services, Hotels, Hotels & Travel',
#  'American (New), Dive Bars, Bars, Arts & Entertainment, Music Venues, Restaurants, Nightlife',
#  'Desserts, Ice Cream & Frozen Yogurt, Food',
#  'Italian, Food, Restaurants',
#  'Barbers, Hair Salons, Beauty & Spas',
#  'Shopping, Farmers Market, Food, Arts & Crafts',
#  'Nightlife, Bars, Restaurants, German',
#  'Automotive, Towing, Auto Repair, Transmission Repair',
#  'Breakfast & Brunch, Restaurants, Vegetarian, Cafes, American (New), Food, Diners, American (Traditional)',
#  'Health Markets, Specialty Food, Grocery, Organic Stores, Food',
#  'Mediterranean, Hookah Bars, Nightlife, Middle Eastern, Restaurants, Bars',
#  'Music & DVDs, Books, Mags, Music & Video, Shopping, Vinyl Records',
#  'Hotels & Travel, Event Planning & Services, Hotels',
#  'Chinese, Restaurants',
#  'Arts & Entertainment, Hotels & Travel, Hotels, Event Planning & Services, American (New), Casinos, Restaurants',
#  'Food, Seafood, Sardinian, Gelato, Restaurants, Pizza, Italian',
#  'Ethiopian, Imported Food, Restaurants, Coffee & Tea, American (Traditional), Ethnic Food, Specialty Food, Food',
#  'Stadiums & Arenas, Arts & Entertainment',
#  'Tea Rooms, Event Planning & Services, Venues & Event Spaces, Bakeries, Food, Coffee & Tea, Desserts, Party & Event Planning',
#  "Formal Wear, Men's Clothing, Fashion, Shopping, Accessories",
#  'Restaurants, Sushi Bars, Japanese',
#  'Medical Centers, Health & Medical, Hospitals',
#  'Beauty & Spas, Hair Salons, Nail Salons, Hair Extensions, Makeup Artists, Hair Stylists',
#  "Men's Clothing, Shopping, Local Services, Fashion, Personal Shopping",
#  'Ice Cream & Frozen Yogurt, Food, Burgers, Restaurants, Fast Food',
#  'Florists, Event Planning & Services, Party & Event Planning, Flowers & Gifts, Shopping, Floral Designers',
#  'Bars, Gay Bars, Nightlife',
#  'Mexican, Food, Desserts, Restaurants, Tacos',
#  'Food, Tea Rooms',
#  'Food, Candy Stores, Chocolatiers & Shops, Specialty Food',
#  'Bakeries, Restaurants, Fast Food, Burgers, Food, Ice Cream & Frozen Yogurt',
#  'Restaurants, Vietnamese, Sandwiches, Local Flavor, Food Stands',
#  'Breakfast & Brunch, American (Traditional), Food, American (New), Sandwiches, Restaurants, Beer, Wine & Spirits',
#  'Bakeries, Food, Desserts',
#  'Active Life, Baseball Fields, Stadiums & Arenas, Arts & Entertainment',
#  'Cafes, Food, Coffee & Tea, Bakeries, Coffee Roasteries, Restaurants',
#  'Restaurants, Pizza',
#  'Nightlife, Arts & Entertainment, Restaurants, Music Venues, American (New), Bars, Jazz & Blues',
#  'Caterers, American (New), Breakfast & Brunch, Event Planning & Services, Diners, Restaurants',
#  'Seafood, Restaurants, American (Traditional)',
#  'Hotels, Venues & Event Spaces, Event Planning & Services, Hotels & Travel',
#  'American (Traditional), Restaurants, Bars, Nightlife, Burgers, Sandwiches, Soup, Pubs',
#  'Active Life, Parks, Dog Parks',
#  'Restaurants, Noodles, Dim Sum, Hong Kong Style Cafe, Cantonese, Food, Barbeque, Juice Bars & Smoothies, Chinese',
#  'Sandwiches, Burgers, Restaurants, Pets, Bars, Nightlife, Vegan, Pubs, Gastropubs',
#  'Pets, Veterinarians, Health & Medical, Pet Cremation Services, Hospitals, Pet Services, Pet Hospice',
#  'Restaurants, French, Wine Bars, Nightlife, American (New), Bars, Cafes, Breakfast & Brunch',
#  'Chinese, Food Stands, Food, Food Trucks, Restaurants',
#  'Restaurants, Food, Vegetarian, Organic Stores, Health Markets, Bakeries, Specialty Food, Grocery',
#  'Breweries, Restaurants, Food, American (New)',
#  'Lounges, Bars, Restaurants, Nightlife, Cafes, Cocktail Bars',
#  "Fashion, Shopping, Men's Clothing, Department Stores, Women's Clothing, Shoe Stores",
#  'Arts & Entertainment, Festivals',
#  'Hair Removal, Nail Salons, Spray Tanning, Beauty & Spas, Waxing, Tanning, Eyelash Service',
#  'Mattresses, Home & Garden, Shopping',
#  'Doctors, Health & Medical, Neurologist, Osteopathic Physicians',
#  'Spanish, Restaurants, Breakfast & Brunch, Tapas Bars, Iberian',
#  'Nightlife, Bars, American (New), Restaurants, Italian, Cocktail Bars, Mediterranean, Seafood',
#  'Venues & Event Spaces, Event Planning & Services, Hotels & Travel, Hotels',
#  'Drugstores, Shopping',
#  'Cinema, Museums, Venues & Event Spaces, Event Planning & Services, Arts & Entertainment, Community Service/Non-Profit, Local Services',
#  'Cinema, Arts & Entertainment, Performing Arts',
#  'Nightlife, Restaurants, Bars, Dive Bars',
#  'Sushi Bars, Japanese, Restaurants',
#  'Restaurants, Korean, American (Traditional), Breakfast & Brunch, Donuts, Food, Coffee & Tea',
#  'Home Services, Appliances & Repair, Local Services',
#  'Health Markets, Juice Bars & Smoothies, Food, Specialty Food',
#  'Movers, Professional Services, Home Services, Self Storage, Local Services',
#  'Restaurants, Bars, Arcades, Tacos, Nightlife, Mexican, Arts & Entertainment',
#  'Food, Tea Rooms, British, Restaurants',
#  'Ice Cream & Frozen Yogurt, Food',
#  'Hobby Shops, Toy Stores, Shopping',
#  'Mexican, Restaurants',
#  'Mexican, Juice Bars & Smoothies, Restaurants, Food, Breakfast & Brunch, Acai Bowls',
#  'Home & Garden, Baby Gear & Furniture, Mattresses, Shopping, Home Decor, Furniture Stores',
#  'Auto Repair, Automotive',
#  'Breakfast & Brunch, Lounges, Seafood, Bars, Nightlife, Restaurants, Italian, Tapas Bars',
#  'Fast Food, Burgers, Restaurants, Food, Ice Cream & Frozen Yogurt',
#  'Event Planning & Services, Food Delivery Services, Restaurants, Italian, Food, Caterers, Pizza, Desserts',
#  'Dive Bars, Nightlife, Bars',
#  'Mexican, Peruvian, Restaurants, Food, Desserts',
#  'Pizza, Italian, Restaurants, Gluten-Free',
#  'Hotels, Hotels & Travel, Event Planning & Services, Venues & Event Spaces, American (Traditional), Bed & Breakfast, Restaurants',
#  'Coffee & Tea, Food, American (Traditional), Restaurants',
#  'Auto Repair, Car Dealers, Auto Parts & Supplies, Automotive',
#  'Southern, Restaurants, American (Traditional)',
#  'Bars, Pubs, American (Traditional), Nightlife, Gastropubs, Restaurants',
#  'Hotels & Travel, Dry Cleaning & Laundry, Local Services, Restaurants, Shopping, Accessories, Shopping Centers, American (Traditional), Local Flavor, Fashion',
#  'Dance Clubs, Bars, Diners, Breakfast & Brunch, Lounges, Restaurants, Nightlife, American (New)',
#  'Makeup Artists, Laser Hair Removal, Cosmetics & Beauty Supply, Hair Removal, Day Spas, Medical Spas, Shopping, Beauty & Spas, Skin Care, Massage Therapy, Hair Salons, Health & Medical',
#  'American (Traditional), Restaurants, Event Planning & Services, Fast Food, Caterers, Chicken Shop',
#  'Restaurants, Ethiopian, Bars, African, American (New), Nightlife',
#  'Nightlife, Dance Clubs',
#  'Restaurants, Food, Pizza, Cafes, Bakeries, Desserts, Breakfast & Brunch, American (New), Italian, Coffee & Tea',
#  'Hair Stylists, Hair Salons, Barbers, Beauty & Spas',
#  'Waxing, Beauty & Spas, Nail Salons, Hair Removal, Day Spas',
#  'Education, Colleges & Universities',
#  'Auto Parts & Supplies, Car Dealers, Auto Repair, Automotive',
#  'American (New), Breakfast & Brunch, Desserts, Caterers, Event Planning & Services, Food, Sandwiches, Restaurants, Custom Cakes',
#  'Airlines, Transportation, Hotels & Travel',
#  'Beauty & Spas, Hair Removal, Nail Salons, Permanent Makeup, Hair Salons, Waxing',
#  'Ramen, Japanese, Restaurants',
#  'Taiwanese, Restaurants, Noodles, Szechuan, Chinese',
#  'American (Traditional), Seafood, Nightlife, Event Planning & Services, Cocktail Bars, Wine Bars, Restaurants, Venues & Event Spaces, American (New), Bars',
#  'Food, Arts & Entertainment, Beer, Wine & Spirits, Nightlife, American (Traditional), Restaurants, Music Venues, Bars, American (New)',
#  'Szechuan, Chinese, Restaurants, Noodles, Soup',
#  'Sandwiches, Vegetarian, Pizza, Food, Coffee & Tea, Delis, Restaurants, American (New)',
#  'Local Services, Public Services & Government, Landmarks & Historical Buildings, Local Flavor',
#  'Bars, Nightlife, Event Planning & Services, Hotels & Travel, Hotels, Lounges, Caterers',
#  'Bars, Nightlife, Lounges, Steakhouses, Restaurants',
#  'Nightlife, Bars, American (New), American (Traditional), Restaurants',
#  'Nightlife, Lounges, Restaurants, Bars',
#  'Nail Salons, Beauty & Spas',
#  'Basque, Tapas Bars, Iberian, Bars, Wine Bars, Restaurants, Lounges, Nightlife, Spanish',
#  'Thai, American (New), Restaurants, Chinese, Asian Fusion, Tapas/Small Plates, Pan Asian',
#  'Home Decor, Home & Garden, Furniture Stores, Baby Gear & Furniture, Shopping, Mattresses',
#  'Chocolatiers & Shops, Coffee & Tea, Specialty Food, Candy Stores, Restaurants, Desserts, Bakeries, Food',
#  'Beauty & Spas, Nail Salons, Professional Services',
#  'Restaurants, Mediterranean, Moroccan',
#  'Active Life, Performing Arts, Dance Studios, Fitness & Instruction, Event Planning & Services, Caterers, Education, Arts & Entertainment, Dance Schools, Specialty Schools',
#  'Appliances & Repair, Home & Garden, Home Services, Heating & Air Conditioning/HVAC, Appliances, Shopping, Local Services',
#  'Restaurants, Thai, Vegetarian, Vegan',
#  'American (New), Restaurants, Bars, Pubs, Nightlife',
#  'Restaurants, Bakeries, Diners, Food',
#  'Bars, Restaurants, Nightlife, Pubs, Irish, Seafood, American (Traditional)',
#  'Restaurants, Nightlife, American (New), Food, Sports Bars, Bars, Breweries, Beer, Wine & Spirits',
#  'Restaurants, American (Traditional), Nightlife, Bars, Pubs',
#  'Cheese Shops, Bagels, Coffee & Tea, Desserts, Juice Bars & Smoothies, Food, Specialty Food, Grocery',
#  'Cocktail Bars, Caribbean, Restaurants, Korean, Nightlife, Breakfast & Brunch, Bars, Asian Fusion, American (New)',
#  'Active Life, Beer Gardens, Grocery, Middle Eastern, Specialty Food, American (New), Parks, Cafes, Food, Nightlife, Restaurants, Coffee & Tea, Lebanese',
#  'Burgers, Fast Food, Restaurants, Food, Ice Cream & Frozen Yogurt',
#  'Burmese, Restaurants',
#  'Restaurants, American (New), American (Traditional)',
#  'American (New), Wine Bars, Cafes, Restaurants, Coffee & Tea, Food, Nightlife, Bars, Breakfast & Brunch',
#  'Pet Groomers, Pet Stores, Pet Training, Dog Walkers, Pet Services, Pets, Pet Sitting',
#  'Japanese, Sushi Bars, Restaurants',
#  'Restaurants, Food, Beer, Wine & Spirits, Breweries, Mexican',
#  'Bars, Nightlife, American (New), Pubs, Restaurants',
#  'Restaurants, American (New), Southern, Breakfast & Brunch',
#  'Fast Food, Pizza, Restaurants',
#  'Massage Therapy, Hair Salons, Makeup Artists, Beauty & Spas, Hair Stylists, Massage, Health & Medical',
#  'Mediterranean, Middle Eastern, Restaurants',
#  'Pet Services, Pets, Pet Adoption, Pet Groomers, Pet Stores',
#  'Restaurants, Malaysian, Burmese, Asian Fusion, Thai',
#  'Pet Groomers, Pets, Dog Walkers, Pet Services',
#  'American (New), French, Restaurants',
#  'Health & Medical, Pediatricians, Doctors',
#  'Nightlife, Irish, Restaurants, Bars, Gastropubs, Pubs',
#  'Desserts, Chocolatiers & Shops, Food, Restaurants, Bakeries, Specialty Food, Coffee & Tea',
#  'Arts & Entertainment, Beauty & Spas, Tattoo',
#  'Ice Cream & Frozen Yogurt, Food, Specialty Food, Chocolatiers & Shops',
#  'Health & Medical, General Dentistry, Pediatric Dentists, Cosmetic Dentists, Dentists',
#  'Home Organization, Movers, Home Services, Shopping, Local Services, Junk Removal & Hauling, Packing Supplies',
#  'Restaurants, Delis, Breakfast & Brunch, American (Traditional), Diners, Bagels, Food',
#  'Restaurants, Patisserie/Cake Shop, Cafes, Breakfast & Brunch, Coffee & Tea, Food, American (Traditional)',
#  'Restaurants, Greek, Mediterranean, Seafood',
#  'Mediterranean, Italian, Restaurants',
#  'Health & Medical, Hospitals',
#  'Beer, Wine & Spirits, Restaurants, Breweries, Pizza, Local Flavor, American (New), Vegetarian, Food, Brewpubs',
#  'Tapas/Small Plates, Restaurants, American (New), Nightlife, Breakfast & Brunch, Bars',
#  'Restaurants, Chinese, Fast Food',
#  'Gastropubs, Restaurants',
#  'Talent Agencies, Hotels & Travel, Tours, Travel Services, Professional Services',
#  'American (New), Breakfast & Brunch, Gastropubs, Restaurants',
#  'Restaurants, Coffee & Tea, Sandwiches, Desserts, Food, Breakfast & Brunch',
#  'Shopping Centers, Fashion, Department Stores, Shopping',
#  'Breakfast & Brunch, Bagels, American (Traditional), Cafes, Coffee & Tea, Sandwiches, Restaurants, Food',
#  'Restaurants, Bars, Wine Bars, Mediterranean, Italian, Nightlife',
#  'Cafes, Breakfast & Brunch, American (Traditional), American (New), Restaurants, Vegetarian',
#  'Nightlife, Wine Bars, Breakfast & Brunch, Bars, Restaurants, Cocktail Bars, Brasseries, French',
#  'Thai, Restaurants',
#  'Home Services, Appliances, Local Services, Electronics, Shopping, Home & Garden, Mattresses, Grilling Equipment, Appliances & Repair',
#  'Event Planning & Services, Fast Food, Caterers, Restaurants, Chicken Shop',
#  'Donuts, Sandwiches, Soul Food, Food, Coffee & Tea, Restaurants, Chicken Wings',
#  'Food, Specialty Food, Ice Cream & Frozen Yogurt, Candy Stores',
#  'Veterinarians, Pet Groomers, Pets, Pet Sitting, Pet Services',
#  'Hotels & Travel, Event Planning & Services, Hotels, Venues & Event Spaces',
#  'Food, Breakfast & Brunch, Cafes, Restaurants, Coffee & Tea, American (Traditional)',
#  'Italian, Specialty Food, Pizza, Food, Restaurants, Nightlife, Bars, Juice Bars & Smoothies',
#  'Active Life, Playgrounds',
#  'Food, Specialty Food, Vietnamese, Ethnic Food, Restaurants',
#  'Cafes, Specialty Food, Bakeries, American (New), Restaurants, Food, Italian',
#  'Automotive, Auto Repair, Car Dealers',
#  'Caterers, Water Parks, Event Planning & Services, Local Flavor, Active Life, Amusement Parks',
#  'American (New), French, Restaurants, American (Traditional)',
#  'Event Planning & Services, Hotels, Hotels & Travel',
#  'Restaurants, Chinese, Sushi Bars, Asian Fusion',
#  'Parks, Active Life',
#  'Piercing, Tattoo, Beauty & Spas',
#  'Burgers, Beer, Wine & Spirits, Nightlife, Restaurants, Cocktail Bars, Food, Bars, Juice Bars & Smoothies, Salad',
#  'Cocktail Bars, Tapas Bars, Bars, Nightlife, Restaurants',
#  'Mattresses, Shopping, Furniture Stores, Home & Garden, Home Decor, Shades & Blinds, Home Services',
#  'Korean, Barbeque, Hot Pot, Restaurants',
#  'Hotels & Travel, Event Planning & Services, Venues & Event Spaces, Hotels',
#  'Breakfast & Brunch, Nightlife, Bars, American (Traditional), Restaurants',
#  'Ice Cream & Frozen Yogurt, Food, Fast Food, Restaurants, Burgers',
#  'Health & Medical, Colonics, Weight Loss Centers, Professional Services, Beauty & Spas, Medical Spas, Life Coach, Naturopathic/Holistic, Doctors',
#  'Electronics, Appliances, Home & Garden, Shopping, Appliances & Repair, Local Services',
#  'Italian, Restaurants',
#  'Nightlife, Bars, American (Traditional), Pubs, Breakfast & Brunch, Restaurants, Beer Bar',
#  'Bars, Restaurants, Nightlife, Seafood',
#  'Nightlife, Breweries, Pubs, Bars, Food, American (New), Restaurants',
#  'Breakfast & Brunch, Restaurants, Sandwiches, American (New), Cafes, CSA, Food',
#  'Gastropubs, Beer, Wine & Spirits, Bars, Nightlife, American (New), Beer Bar, Food, Restaurants',
#  'Nightlife, Event Planning & Services, Local Flavor, Bars, American (Traditional), Restaurants, Unofficial Yelp Events',
#  'Lounges, Restaurants, Asian Fusion, Mexican, Latin American, Nightlife, Bars',
#  'Transmission Repair, Oil Change Stations, Automotive, Auto Repair',
#  'Burgers, Pasta Shops, Pizza, Pubs, Specialty Food, Restaurants, Food, Nightlife, American (New), Bars, Italian',
#  'Food, Juice Bars & Smoothies, Ice Cream & Frozen Yogurt, Burgers, Fast Food, Restaurants',
#  'Water Parks, Event Planning & Services, Arcades, Amusement Parks, Local Services, Active Life, Party & Event Planning, Arts & Entertainment',
#  'Event Planning & Services, Hotels & Travel, Restaurants, Hotels',
#  'Vegetarian, Asian Fusion, Thai, Restaurants',
#  'Gastropubs, Restaurants, Breweries, Food',
#  'Restaurants, Breakfast & Brunch, Brazilian, American (New), French, Asian Fusion',
#  'Event Planning & Services, Arts & Entertainment, Arcades, Venues & Event Spaces, Active Life, Hotels, Amusement Parks, Water Parks, Hotels & Travel',
#  'Nightlife, Pubs, Bars',
#  'Pubs, Restaurants, Bars, Nightlife, Irish, Irish Pub',
#  'Hotels & Travel, Event Planning & Services, Hotels, Caterers',
#  'Gastropubs, Beer Bar, Restaurants, Nightlife, American (Traditional), Bars',
#  'Buffets, Pakistani, Restaurants, Indian, Vegan, Vegetarian',
#  'Restaurants, Specialty Food, Caribbean, Trinidadian, Food, Imported Food, Ethnic Food',
#  'Hair Removal, Beauty & Spas, Waxing, Eyebrow Services, Eyelash Service, Specialty Schools, Education',
#  'Pet Services, Pet Stores, Pet Groomers, Pets',
#  'Fashion, Shopping, Bridal, Flowers & Gifts',
#  'German, Beer Bar, Food, Bars, Nightlife, Restaurants, Beer, Wine & Spirits, Beer Gardens',
#  'Bars, Food, American (New), Restaurants, Nightlife, Beer, Wine & Spirits',
#  'Mexican, Restaurants, Salad, Sandwiches',
#  'Nail Salons, Beauty & Spas, Waxing, Hair Removal',
#  'Arts & Entertainment, Active Life, Shopping, Art Galleries, Venues & Event Spaces, Event Planning & Services, Art Classes, Education, Summer Camps',
#  'Event Planning & Services, Hotels & Travel, Arts & Entertainment, Zoos, Museums, Active Life, Tours, Parks, Venues & Event Spaces',
#  'Veterinarians, Pet Services, Pets',
#  'Adult Entertainment, Nightlife',
#  'Auto Parts & Supplies, Auto Repair, Automotive, Transmission Repair',
#  'American (New), Bars, Sports Bars, Restaurants, Nightlife',
#  'Restaurants, Gastropubs, Nightlife, Bars',
#  'Japanese, Sushi Bars, Karaoke, Nightlife, Restaurants',
#  'Tea Rooms, Korean, Asian Fusion, Chicken Wings, Food, Restaurants, Specialty Food',
#  'Transmission Repair, Auto Repair, Automotive',
#  'Seafood, Salad, Restaurants, Steakhouses',
#  'Sandwiches, American (New), Beer Bar, Restaurants, Bars, Pubs, Nightlife, Burgers, Gastropubs, Comfort Food',
#  'Restaurants, Lounges, Asian Fusion, Nightlife, Sushi Bars, Bars',
#  "Shopping, Children's Clothing, Women's Clothing, Fashion, Men's Clothing",
#  'Restaurants, Burgers, Fish & Chips, Irish',
#  'Cocktail Bars, American (New), Bars, Restaurants, Steakhouses, Seafood, Nightlife',
#  'Eyelash Service, Beauty & Spas, Day Spas, Health & Medical, Massage Therapy, Nail Salons',
#  'Chinese, Japanese, Dim Sum, Sushi Bars, Restaurants, Szechuan',
#  'Nightlife, Arts & Entertainment, Caterers, Diners, Event Planning & Services, Restaurants, Coffee & Tea, Desserts, Food, Music Venues, Breakfast & Brunch, American (New), Cafes, Comfort Food',
#  'Pizza, Food, Italian, Sandwiches, Restaurants',
#  'Food, Ice Cream & Frozen Yogurt, Restaurants, Delis',
#  'Day Spas, Beauty & Spas',
#  'Coffee & Tea, Gelato, Ice Cream & Frozen Yogurt, Food',
#  'Soul Food, Restaurants',
#  'Hotels, Hotels & Travel, Venues & Event Spaces, Event Planning & Services',
#  'Hotels & Travel, Event Planning & Services, Restaurants, Hotels',
#  'Hotels & Travel, Hostels, Hotels, Event Planning & Services',
#  'Sandwiches, Restaurants, Adult Entertainment, Bars, Italian, Nightlife',
#  'Videos & Video Game Rental, Books, Mags, Music & Video, Adult Entertainment, Nightlife, Shopping, Adult',
#  'Modern European, American (New), Restaurants',
#  'Active Life, Botanical Gardens, Performing Arts, Parks, Music Venues, Arts & Entertainment, Nightlife',
#  'Car Dealers, Auto Repair, Automotive, Body Shops',
#  'Restaurants, Food, Ice Cream & Frozen Yogurt, Fast Food, Burgers',
#  'Pets, Veterinarians, Health & Medical, Pet Stores, Urgent Care, Pet Services, Emergency Pet Hospital',
#  'Asian Fusion, Restaurants, American (New), Thai, Szechuan, Chinese',
#  'Auto Repair, Oil Change Stations, Automotive, Towing, Tires',
#  'Beer Bar, Bars, American (New), Tapas/Small Plates, Gastropubs, Music Venues, Arts & Entertainment, Breakfast & Brunch, Nightlife, Vegetarian, Restaurants',
#  'Breakfast & Brunch, Restaurants, Diners',
#  'Automotive, Motorcycle Dealers, Motorcycle Repair',
#  'Bars, Beer, Wine & Spirits, Food, Breweries, Nightlife, American (New), Restaurants, Pubs, Gastropubs',
#  'Food, Ice Cream & Frozen Yogurt, Fast Food, Restaurants, Burgers',
#  'Cheesesteaks, Burgers, Restaurants, Pizza, Caterers, Food Delivery Services, Food, Event Planning & Services',
#  'American (Traditional), Breakfast & Brunch, Nightlife, Restaurants, Food, Specialty Food, Seafood, Bars',
#  'American (New), Nightlife, Bars, Seafood, Beer, Wine & Spirits, Food Delivery Services, Food, American (Traditional), Sports Bars, Restaurants',
#  'Nightlife, Food, American (New), Pizza, Pubs, Bars, Breweries, Restaurants',
#  'Hair Salons, Beauty & Spas, Barbers',
#  'Coffee Roasteries, Pasta Shops, Candy Stores, Herbs & Spices, Food, Coffee & Tea, Specialty Food',
#  'Nightlife, Bars, Beer, Wine & Spirits, Pubs, Irish, Food, Restaurants',
#  'Movers, Home Services, Furniture Assembly, Packing Services, Local Services, Self Storage',
#  'Hotels & Travel, Hotels, Event Planning & Services, Resorts, Venues & Event Spaces',
#  'Event Planning & Services, Arts & Entertainment, Nightlife, Bars, Caterers, Music Venues, American (New), Restaurants',
#  'Ice Cream & Frozen Yogurt, Food, Bakeries, Restaurants, Burgers, Fast Food',
#  'Hotels, Venues & Event Spaces, Hotels & Travel, Party & Event Planning, Event Planning & Services',
#  'American (New), Bars, Food, Beer, Wine & Spirits, Restaurants, Local Flavor, Nightlife, American (Traditional)',
#  'American (Traditional), Sandwiches, Restaurants, Bars, Cheesesteaks, Nightlife',
#  'Guest Houses, Event Planning & Services, Bed & Breakfast, Hotels, Restaurants, Hotels & Travel',
#  'Skin Care, Hair Salons, Beauty & Spas, Makeup Artists, Massage',
#  'Event Planning & Services, DJs',
#  'Performing Arts, Nightlife, Arts & Entertainment, Active Life, Local Flavor, Haunted Houses, Amusement Parks',
#  'Art Galleries, Education, Arts & Entertainment, Shopping, Art Classes, Museums, Art Museums',
#  'Restaurants, Vegetarian, Grocery, Specialty Food, Sandwiches, Food',
#  'Restaurants, American (Traditional), Food, Ice Cream & Frozen Yogurt',
#  'Shopping Centers, Shopping',
#  'Food, Coffee & Tea, Cafes, Restaurants',
#  'Bars, Restaurants, Italian, Wine Bars, American (New), Breakfast & Brunch, Nightlife',
#  'Restaurants, Mexican, New Mexican Cuisine',
#  'Arts & Entertainment, Steakhouses, Active Life, Restaurants, Dance Clubs, Nightlife, Adult Entertainment, Buffets, Horse Racing, Casinos',
#  'American (Traditional), American (New), Latin American, Restaurants, Nightlife, Bars',
#  'Barbeque, Restaurants',
#  'Ice Cream & Frozen Yogurt, Gelato, Food',
#  'Cinema, Arts & Entertainment',
#  'Local Services, Appliances & Repair, Appliances, Shopping, Home & Garden',
#  'Restaurants, Cafes',
#  'Coffee & Tea, Beauty & Spas, Cosmetics & Beauty Supply, Shopping, Arts & Crafts, Costumes, Restaurants, Vietnamese, Food',
#  'Tea Rooms, Coffee & Tea, Food',
#  'Hot Dogs, Burgers, Food, Restaurants, Ice Cream & Frozen Yogurt, American (Traditional)',
#  'American (New), Bars, Tapas/Small Plates, Restaurants, Nightlife',
#  'Beer, Wine & Spirits, Shopping, Grocery, Florists, Food, Flowers & Gifts, Specialty Food',
#  'Home & Garden, Home Services, Office Equipment, Mattresses, Interior Design, Home Decor, Appliances, Outdoor Furniture Stores, Lighting Fixtures & Equipment, Shopping, Furniture Stores',
#  'Event Planning & Services, Music Venues, Dance Clubs, Venues & Event Spaces, Arts & Entertainment, Bars, Nightlife',
#  'Event Planning & Services, Caterers, Restaurants, Chicken Shop, Chicken Wings, Fast Food',
#  'Seafood, Sicilian, Restaurants, Italian',
#  'Asian Fusion, Nightlife, Restaurants, Dance Clubs, Lounges, Bars',
#  'Home & Garden, Event Planning & Services, Shopping, Venues & Event Spaces, Nurseries & Gardening, Flowers & Gifts, Tea Rooms, Coffee & Tea, Food, Gift Shops',
#  'Breakfast & Brunch, Restaurants',
#  'Massage Therapy, Day Spas, Massage, Hair Salons, Hair Removal, Beauty & Spas, Health & Medical',
#  'Food, Pubs, Bars, Irish Pub, Beer, Wine & Spirits, Nightlife, Sports Bars, Irish, Restaurants',
#  'Beer, Wine & Spirits, Chinese, Restaurants, Food, Szechuan, Noodles, Soup',
#  'Malaysian, Asian Fusion, Cambodian, Chinese, Restaurants, Thai',
#  'Hotels & Travel, Walking Tours, Tours, Food Tours',
#  'Restaurants, Seafood, Vietnamese',
#  'Home & Garden, Active Life, Pumpkin Patches, Shopping, Haunted Houses, Amusement Parks, Arts & Entertainment',
#  'Beauty & Spas, Skin Care, Waxing, Eyelash Service, Hair Removal',
#  'Restaurants, Gluten-Free, Thai, Vegan',
#  'Shopping, Home Decor, Furniture Stores, Home & Garden, Mattresses',
#  'Caterers, Event Planning & Services, American (Traditional), Pubs, Nightlife, Bars, Restaurants',
#  'Shopping, Home & Garden, Mattresses, Home Services, Home Decor, Shades & Blinds, Furniture Stores',
#  'Nightlife, German, Pubs, Bars, Restaurants',
#  'Shopping, Arts & Crafts, Costumes',
#  'Ice Cream & Frozen Yogurt, Food, Desserts',
#  'Mexican, Tex-Mex, Restaurants, Barbeque',
#  'Real Estate, Hotels & Travel, Apartments, Event Planning & Services, Hotels, Home Services',
#  'Venues & Event Spaces, Event Planning & Services',
#  'Food, Restaurants, Desserts, Local Flavor',
#  'Restaurants, Italian, Pizza',
#  'Italian, Wine Bars, Bars, Mediterranean, Pizza, Restaurants, Nightlife',
#  'Bakeries, Food, Mediterranean, Breakfast & Brunch, Middle Eastern, Restaurants, Lebanese, Coffee & Tea, Halal',
#  'Education, Specialty Schools, Art Classes, Event Planning & Services, Venues & Event Spaces, Summer Camps, Art Schools, Active Life',
#  'Bars, Restaurants, Nightlife, American (Traditional), Tex-Mex',
#  'Mexican, Restaurants, Vegetarian, Coffee & Tea, Juice Bars & Smoothies, Cafes, Desserts, Bakeries, Food, Breakfast & Brunch',
#  'American (Traditional), Nightlife, Restaurants, Pubs, Bars',
#  'Skin Care, Shopping, Day Spas, Cosmetics & Beauty Supply, Hair Removal, Beauty & Spas, Massage',
#  'Restaurants, Chinese, Vietnamese',
#  'Home Services, Used, Vintage & Consignment, Furniture Stores, Fashion, Local Services, Flooring, Building Supplies, Thrift Stores, Furniture Reupholstery, Interior Design, Home & Garden, Antiques, Shopping',
#  'Restaurants, American (Traditional), American (New), Sports Bars, Nightlife, Beer Gardens, Bars',
#  'Food, Shopping, Drugstores, Convenience Stores, Pharmacy, Health & Medical',
#  'Hotels, Hotels & Travel, Event Planning & Services, Venues & Event Spaces',
#  'Steakhouses, Comfort Food, Butcher, Bars, Specialty Food, Food, Nightlife, Whiskey Bars, Restaurants, Gastropubs',
#  'Restaurants',
#  'Fashion, Shopping, Shoe Stores',
#  'Pet Stores, Veterinarians, Pet Services, Pets, Pet Cremation Services',
#  'Churches, Event Planning & Services, Venues & Event Spaces, Religious Organizations',
#  'Hair Removal, Hair Salons, Beauty & Spas, Waxing',
#  'American (New), Cafes, Breakfast & Brunch, Restaurants, Sandwiches',
#  'Breakfast & Brunch, Steakhouses, Restaurants, American (Traditional), Diners, Food',
#  'Vietnamese, Sandwiches, Southern, Restaurants, American (New)',
#  'Breakfast & Brunch, American (New), Restaurants',
#  'Restaurants, Steakhouses, Brazilian',
#  'Herbs & Spices, Honey, Specialty Food, Organic Stores, Candy Stores, Food',
#  'Jewelry, Shopping',
#  'Cheese Shops, Food, Specialty Food, Sandwiches, Cafes, Restaurants, Pizza, American (New), Beer, Wine & Spirits, Butcher, Modern European, Italian, Bars, Nightlife',
#  'Dry Cleaning & Laundry, Local Services, Laundry Services, Laundromat',
#  'Barbeque, Pubs, Event Planning & Services, Nightlife, Sports Bars, Restaurants, Bars, Caterers, Burgers, Venues & Event Spaces, American (Traditional)',
#  'Sandwiches, Seafood, Restaurants',
#  'Churches, Religious Organizations',
#  'Chinese, Szechuan, Restaurants, Taiwanese',
#  'Shopping, Art Supplies, Arts & Crafts',
#  'Food, Cafes, Coffee & Tea, Restaurants',
#  'Home & Garden, Shopping, Appliances',
#  'American (Traditional), Nightlife, Restaurants, Bars',
#  'Hotels, Hotels & Travel, Bed & Breakfast, Venues & Event Spaces, Event Planning & Services',
# ...
#  'Food, Restaurants, Seafood, Specialty Food, Steakhouses, American (Traditional)',
#  'Greek, Restaurants',
#  'Nightlife, Tapas/Small Plates, American (New), Bars, Restaurants',
#  'Thai, Vietnamese, Restaurants',
#  'Ski & Snowboard Shops, Fashion, Shopping, Sports Wear, Outdoor Gear, Bikes, Sporting Goods',
#  'Department Stores, Furniture Stores, Food, Grocery, Shopping, Fashion, Home & Garden, Electronics',
#  'Dance Clubs, Bars, Adult Entertainment, Nightlife',
#  'Brazilian, Venues & Event Spaces, Breakfast & Brunch, Restaurants, Event Planning & Services',
#  'Asian Fusion, Nightlife, Restaurants, American (New), Bars, Pubs',
#  'Beauty & Spas, Waxing, Hair Removal, Hair Salons',
#  'Breakfast & Brunch, American (New), Diners, Restaurants',
#  'Restaurants, Seafood, Mediterranean, American (New), Breakfast & Brunch, Event Planning & Services, Caterers',
#  'Arts & Entertainment, Performing Arts, Cinema',
#  'Furniture Reupholstery, Fabric Stores, Arts & Crafts, Home Decor, Home & Garden, Shades & Blinds, Shopping, Home Services, Local Services',
#  'Local Flavor, Nightlife, Bars, American (New), Restaurants, Breakfast & Brunch, Sports Bars, Pubs',
#  'Restaurants, Tapas/Small Plates, Italian, Szechuan, Cocktail Bars, Pizza, Chinese, Bars, Nightlife',
#  'Home Services, Gardeners, Tree Services, Landscaping',
#  'Vietnamese, Soup, Sandwiches, Restaurants',
#  'Coffee & Tea, Restaurants, Food, Cafes',
#  'Bakeries, Food, Restaurants, Donuts, Gluten-Free',
#  'Pizza, Food, Bagels, Sandwiches, Comfort Food, Breakfast & Brunch, Burgers, American (New), Nightlife, Bars, Wine Bars, Restaurants',
#  'Restaurants, Ice Cream & Frozen Yogurt, Cheesesteaks, Food, Sandwiches, American (Traditional)',
#  'Social Clubs, Lounges, Bars, Nightlife, Food, Cafes, Tea Rooms, Hookah Bars, Restaurants, Arts & Entertainment',
#  'Beauty & Spas, Hair Removal, Skin Care, Waxing',
#  'Shopping, Art Galleries, Beauty & Spas, Hair Salons, Arts & Entertainment',
#  'Nightlife, Vietnamese, Bars, Beer Bar, Restaurants, Cocktail Bars, Food, Beer, Wine & Spirits',
#  'Breakfast & Brunch, Diners, Restaurants',
#  'Restaurants, Bars, Nightlife, Mediterranean, Venues & Event Spaces, Event Planning & Services, American (New), Tiki Bars, American (Traditional)',
#  'Cocktail Bars, Food, American (Traditional), Hotels & Travel, Event Planning & Services, Hotels, Breakfast & Brunch, Nightlife, Buffets, Desserts, Bars, Restaurants',
#  'Financial Services, Health & Medical, Insurance, Health Insurance Offices',
#  "Fashion, Home Decor, Women's Clothing, Home & Garden, Jewelry, Men's Clothing, Shopping",
#  'Bars, American (New), Restaurants, Comfort Food, Nightlife, American (Traditional), Cocktail Bars',
#  'Sushi Bars, American (New), Bars, Pizza, American (Traditional), Restaurants, Nightlife, Breweries, Food',
#  'Nightlife, Restaurants, Seafood, Bars',
#  'Bars, Event Planning & Services, Hotels, Restaurants, Hotels & Travel, Bed & Breakfast, Nightlife, American (Traditional), Pubs',
#  'American (Traditional), Music Venues, Arts & Entertainment, Pizza, Caterers, Food, Sandwiches, Restaurants, Nightlife, Beer, Wine & Spirits, Italian, Bars, Gluten-Free, Event Planning & Services, Sports Bars',
#  'Pet Services, Pet Sitting, Pet Groomers, Pets',
#  'Nightlife, Sandwiches, Restaurants, Bars, American (Traditional), Pubs, Food, Cheesesteaks, Beer, Wine & Spirits',
#  'Nightlife, Adult Entertainment, Steakhouses, Restaurants',
#  'Beauty & Spas, Day Spas, Skin Care, Eyelash Service, Cosmetics & Beauty Supply, Shopping',
#  'Wedding Planning, Art Supplies, Home Decor, Art Classes, Shopping, Home & Garden, Arts & Crafts, Event Planning & Services, Education',
#  'Hair Salons, Jewelry, Day Spas, Beauty & Spas, Shopping, Massage, Fashion',
#  'Restaurants, Burgers, Fast Food',
#  'Restaurants, American (Traditional)',
#  'Restaurants, Delis, Sandwiches, Salad',
#  'Food, Delis, Restaurants, Convenience Stores',
#  'Fast Food, Halal, Ethnic Food, Indian, Restaurants, Specialty Food, Food',
#  'Shades & Blinds, Mattresses, Furniture Stores, Shopping, Home Decor, Home & Garden, Home Services',
#  'American (New), Restaurants, Bars, Nightlife',
#  'Jewelry, Gold Buyers, Bridal, Shopping',
#  'Emergency Pet Hospital, Pets, Pet Services, Veterinarians, Orthopedists, Health & Medical, Doctors',
#  'Indian, Restaurants',
#  'Breakfast & Brunch, American (New), Venues & Event Spaces, Event Planning & Services, Restaurants, Gluten-Free, Burgers, Food, Seafood',
#  'Specialty Food, Grocery, Food, Drugstores, Meat Shops, Pizza, Restaurants, Shopping, Caterers, Event Planning & Services',
#  'Event Planning & Services, Hotels & Travel, Rest Stops, Hotels',
#  'Japanese, Restaurants, Sushi Bars, Steakhouses',
#  'Sushi Bars, Restaurants, Lounges, Ramen, Japanese, Nightlife, Bars',
#  'Auto Repair, Auto Parts & Supplies, Smog Check Stations, Automotive, Transmission Repair, Towing, Tires',
#  'Bars, Lounges, Adult Entertainment, Nightlife, Dive Bars',
#  'Restaurants, Italian, Pizza, Breakfast & Brunch',
#  'Nightlife, Arts & Entertainment, Event Planning & Services, Venues & Event Spaces, Music Venues, Performing Arts',
#  'Restaurants, American (Traditional), American (New)',
#  'Flowers & Gifts, Florists, Gift Shops, Shopping',
#  'Thrift Stores, Shopping',
#  'Pet Services, Veterinarians, Pets',
#  'Dentists, Health & Medical, General Dentistry',
#  'Fashion, Desserts, Home Decor, Accessories, Home & Garden, Ice Cream & Frozen Yogurt, Shopping, Food',
#  'Real Estate, Home Services, Mortgage Brokers, Financial Services, Mortgage Lenders',
#  'Barbeque, American (New), Beer Gardens, Nightlife, Restaurants',
#  'Specialty Food, Noodles, Ethnic Food, Chinese, Comfort Food, Restaurants, Food',
#  'Hair Salons, Hair Stylists, Beauty & Spas',
#  'Restaurants, American (Traditional), Event Planning & Services, American (New), Seafood, Venues & Event Spaces',
#  'Restaurants, Spanish, American (New), Italian',
#  'Pet Services, Pet Sitting, Dog Walkers, Pets',
#  'Beer Bar, American (Traditional), American (New), Breweries, Bars, Nightlife, Restaurants, Wine Bars, Food',
#  'Restaurants, Sandwiches',
#  'Restaurants, Diners',
#  'Laundry Services, Local Services, Dry Cleaning & Laundry, Sewing & Alterations',
#  'Mattresses, Furniture Stores, Home & Garden, Shopping',
#  'Sandwiches, Pizza, Salad, Restaurants',
#  'Home Decor, Shopping, Mattresses, Furniture Stores, Home & Garden',
#  'Hotels & Travel, Event Planning & Services, Hotels, Restaurants, Breakfast & Brunch, Venues & Event Spaces',
#  'Auto Parts & Supplies, Tires, Automotive, Car Dealers',
#  'Wine Bars, Desserts, Bars, Nightlife, American (Traditional), Food, American (New), Restaurants, Salad',
#  'Home Decor, Home & Garden, Mattresses, Shopping, Furniture Stores, Rugs',
#  'American (New), Breakfast & Brunch, Bars, Nightlife, Restaurants',
#  "Beauty & Spas, Men's Hair Salons, Barbers, Hair Stylists, Hair Salons",
#  'Dive Bars, Bars, Nightlife',
#  'Soul Food, Coffee & Tea, Restaurants, Cuban, Food',
#  'American (New), Gastropubs, Cocktail Bars, Irish Pub, Bars, Nightlife, Restaurants, Pubs',
#  'Japanese, Arts & Crafts, Caterers, Restaurants, Shopping, Event Planning & Services, Cooking Classes',
#  'Restaurants, Food, Desserts, Beer, Wine & Spirits, American (Traditional)',
#  'American (Traditional), American (New), Hotels & Travel, Breakfast & Brunch, Bed & Breakfast, Event Planning & Services, Caterers, Venues & Event Spaces, Hotels, Restaurants',
#  'Restaurants, International Grocery, Korean, Seafood Markets, Ethnic Food, Food, Pan Asian, Specialty Food, Grocery',
#  'Home Decor, Shopping, Arts & Entertainment, Flowers & Gifts, Venues & Event Spaces, Home & Garden, Arts & Crafts, Event Planning & Services, Party Supplies, Gift Shops, Accessories, Festivals, Fashion',
#  'Performing Arts, Comedy Clubs, Nightlife, Arts & Entertainment',
#  'Event Planning & Services, Butcher, American (Traditional), American (New), Cooking Classes, Venues & Event Spaces, Arts & Crafts, Shopping, Restaurants, Food',
#  'American (Traditional), Restaurants',
#  'Coffee & Tea, Restaurants, Cafes, American (New), Cocktail Bars, Breakfast & Brunch, Vegan, Bars, Nightlife, Food, Juice Bars & Smoothies, Beer Gardens',
#  'Beer, Wine & Spirits, Middle Eastern, Restaurants, Food',
#  'Seafood, Vegetarian, Restaurants, Indian',
#  'Cafes, Bars, Restaurants, Nightlife',
#  'Home Services, Gardeners, Nurseries & Gardening, Home & Garden, Shopping',
#  'Donuts, Food, Coffee & Tea',
#  'Brewpubs, Restaurants, Food, American (Traditional), Breweries',
#  'Local Flavor, Restaurants, Festivals, Diners, Arts & Entertainment',
#  'Automotive, Auto Repair',
#  'Veterinarians, Pet Sitting, Emergency Pet Hospital, Pet Services, Pets, Pet Groomers',
#  'Automotive, Body Shops',
#  'Bars, Pubs, Nightlife, Dive Bars',
#  'Latin American, American (New), Caribbean, Dance Clubs, Bars, Restaurants, Cuban, Nightlife',
#  'American (Traditional), Nightlife, Bars, Restaurants, Pubs, Breakfast & Brunch, Beer Bar',
#  'Food, Restaurants, American (New), American (Traditional)',
#  'Ice Cream & Frozen Yogurt, Cafes, Juice Bars & Smoothies, Coffee & Tea, Food, Restaurants, Desserts',
#  'Real Estate, Apartments, Home Services',
#  'Bars, Restaurants, American (Traditional), Nightlife, Sports Bars',
#  'Bars, Nightlife, Restaurants, Pizza, Beer Bar, Italian',
#  'Restaurants, American (New), Steakhouses',
#  'Restaurants, Gluten-Free, Bars, Nightlife, American (Traditional)',
#  "Fashion, Shopping, Home Decor, Home & Garden, Used, Vintage & Consignment, Jewelry, Accessories, Women's Clothing",
#  'Restaurants, Bars, American (Traditional), Sports Bars, Nightlife',
#  'Bars, Event Planning & Services, Nightlife, Venues & Event Spaces, Restaurants, Hookah Bars, Moroccan',
#  'Pubs, Lounges, Nightlife, Steakhouses, Adult Entertainment, Restaurants, Strip Clubs, Bars',
#  'Mediterranean, Middle Eastern, Halal, Pakistani, Turkish, Restaurants, Kebab, Indian',
#  'Bridal, Jewelry, Fashion, Bespoke Clothing, Formal Wear, Shopping',
#  'Breakfast & Brunch, American (Traditional), Restaurants, Comfort Food, Diners',
#  'Active Life, Arts & Entertainment, Cinema, Amusement Parks, Performing Arts',
#  'Oil Change Stations, Automotive, Windshield Installation & Repair, Auto Repair, Auto Parts & Supplies',
#  'Food, Bakeries',
#  'Sports Bars, Pubs, Nightlife, Bars, Burgers, Sandwiches, American (Traditional), Dive Bars, Restaurants',
#  'Food, Beer, Wine & Spirits, Pizza, Nightlife, American (Traditional), Bars, Italian, Restaurants',
#  'Bakeries, Restaurants, Sandwiches, Diners, Food',
#  'Food, Health Markets, Restaurants, Specialty Food, Vegetarian, Kosher, Chinese, Ukrainian, Vegan',
#  'Hotels, Event Planning & Services, Bed & Breakfast, Hotels & Travel',
#  'Hair Salons, Medical Spas, Day Spas, Health & Medical, Nail Salons, Local Services, Beauty & Spas',
#  'Breakfast & Brunch, Creperies, French, Restaurants',
#  'Tacos, Sports Bars, Chicken Wings, Mexican, Bars, Restaurants, Nightlife',
#  'Hookah Bars, Nightlife, Bars, Moroccan, Restaurants',
#  'Irish, Gastropubs, Pubs, American (Traditional), Nightlife, Bars, Restaurants',
#  'Nightlife, Restaurants, Bars, Asian Fusion, Chicken Wings, Korean',
#  'Auto Repair, Automotive, Oil Change Stations, Tires',
#  'Auto Repair, Body Shops, Wheel & Rim Repair, Automotive, Car Window Tinting, Auto Detailing, Auto Glass Services',
#  'Auto Repair, Transmission Repair, Automotive, Auto Parts & Supplies, Towing',
#  'Pet Groomers, Pet Services, Pet Stores, Pets, Pet Boarding, Dog Walkers, Pet Sitting',
#  'Used Bookstore, Hobby Shops, Bookstores, Books, Mags, Music & Video, Shopping, Music & DVDs',
#  'Restaurants, Karaoke, Bars, Nightlife, Japanese, Sushi Bars',
#  'American (New), Restaurants, Event Planning & Services, Venues & Event Spaces, Mediterranean',
#  'Food, Bakeries, Coffee & Tea, Restaurants',
#  'Waxing, Beauty & Spas, Hair Removal, Tanning, Nail Salons',
#  'Restaurants, Sushi Bars, Japanese, Noodles',
#  'Bartenders, Venues & Event Spaces, Lounges, American (New), Restaurants, Event Planning & Services, Nightlife, Bars',
#  'Sandwiches, Salad, American (Traditional), Cheesesteaks, Breakfast & Brunch, Active Life, American (New), Beaches, Restaurants',
#  'Food, Shaved Ice, Desserts, Bubble Tea',
#  'Doctors, Laser Eye Surgery/Lasik, Health & Medical, Optometrists, Ophthalmologists',
#  'American (New), Steakhouses, Restaurants',
#  'Comfort Food, Middle Eastern, Vegetarian, Kosher, Restaurants',
#  'Coffee & Tea, Food, American (New), Arts & Entertainment, Nightlife, Music Venues, Restaurants, Bars',
#  'Makeup Artists, Beauty & Spas, Nail Salons, Skin Care, Hair Salons, Waxing, Day Spas, Hair Removal',
#  'Nightlife, Restaurants, American (New), Bars',
#  'Fast Food, Food, Desserts, Burgers, Ice Cream & Frozen Yogurt, Hot Dogs, Restaurants, Sandwiches, American (Traditional), Breakfast & Brunch',
#  'Gyms, Interval Training Gyms, Trainers, Fitness & Instruction, Active Life',
#  'Food, Grocery',
#  'Food, American (Traditional), Bars, Restaurants, Nightlife',
#  'Pediatricians, Health & Medical, Doctors',
#  'Auto Repair, Oil Change Stations, Automotive',
#  'Nightlife, Restaurants, Steakhouses, Lounges, Seafood, Bars',
#  'Fitness & Instruction, Active Life, Trainers, Gyms, Nutritionists, Health & Medical',
#  'Shopping, Fashion, Used, Vintage & Consignment, Thrift Stores',
#  'Restaurants, Seafood, Cajun/Creole',
#  'American (New), Restaurants, American (Traditional), Asian Fusion, Noodles, Dim Sum, Fast Food, Chinese',
#  'Bars, Food, Beer, Wine & Spirits, Nightlife, Pubs, Restaurants, Burgers, American (New)',
#  'Driving Schools, Education, Specialty Schools',
#  'Food, Gelato, Ice Cream & Frozen Yogurt',
#  'Automotive, Car Rental, Truck Rental, Parking, Hotels & Travel',
#  'Auto Detailing, Automotive, Car Wash, Hotels & Travel, Transportation, Airport Shuttles, Parking',
#  'Food, Restaurants, Coffee & Tea, Breakfast & Brunch, Cafes',
#  'Auto Parts & Supplies, Body Shops, Car Dealers, Hotels & Travel, Auto Repair, Automotive, Car Rental',
#  'Venues & Event Spaces, Music Venues, Event Planning & Services, Arts & Entertainment, Performing Arts, Nightlife, Cinema',
#  'Restaurants, Bars, Sports Bars, Nightlife, American (Traditional), Caterers, Event Planning & Services',
#  'Antiques, Shopping, Jewelry',
#  'Restaurants, Middle Eastern, Mediterranean, Syrian',
#  'Health & Medical, Dentists, Cosmetic Dentists, General Dentistry, Periodontists',
#  'Sandwiches, Cafes, Burgers, Restaurants, Breakfast & Brunch',
#  'Pizza, Restaurants, Italian, Salad',
#  'Fitness & Instruction, Pilates, Yoga, Active Life, Meditation Centers, Barre Classes',
#  'Steakhouses, Restaurants, Barbeque, American (Traditional)',
#  'Breweries, Beer, Wine & Spirits, Food, Restaurants, American (New)',
#  'Diners, American (Traditional), Restaurants, Wraps',
#  'Dentists, Health & Medical, Cosmetic Dentists, Periodontists, General Dentistry, Endodontists',
#  'Vietnamese, Restaurants, Sandwiches, Specialty Food, Ethnic Food, Food',
#  'Town Car Service, Transportation, Limos, Hotels & Travel, Airport Shuttles',
#  'Local Flavor, American (Traditional), Restaurants, Burgers, Desserts, Breakfast & Brunch, Food, American (New), Gastropubs, Beer, Wine & Spirits, Nightlife, Bars, Pubs',
#  'Beer, Wine & Spirits, Gluten-Free, Salad, Vegan, Nightlife, Desserts, Event Planning & Services, Halal, Caterers, Pakistani, Bars, Food, Restaurants, Indian, Vegetarian, Cocktail Bars',
#  'Shopping, Home & Garden, Grilling Equipment, Kitchen & Bath, Appliances, Mattresses, Appliances & Repair, Local Services',
#  'Pizza, Departments of Motor Vehicles, Public Services & Government, Restaurants',
#  'Convenience Stores, Salad, Food, Delis, Caterers, Event Planning & Services, Kosher, Sandwiches, Restaurants',
#  'Event Planning & Services, Hotels & Travel, Beer, Wine & Spirits, Hotels, Food',
#  'Italian, Restaurants, Gluten-Free',
#  'Food, Steakhouses, American (Traditional), Irish, Beer, Wine & Spirits, Bars, Pubs, Irish Pub, Nightlife, Restaurants',
#  'Bars, Sports Bars, Nightlife',
#  'Packing Supplies, Movers, Home Services, Shopping, Packing Services',
#  'Beer, Wine & Spirits, Wine Bars, Modern European, American (New), Cheese Shops, Specialty Food, Food, Restaurants, Bars, Nightlife',
#  ...]

# %%
joinedDf.drop(index=1722, inplace=True)

# %%
joinedDf.tail(20)
# Out:
#                  business_id        gay_text gay_text_len  \
# 1716  zmkxrle9HcANQ3oL41qciA  [queens, bear]            2
# 1717  0oSSjekU-3GR8gselReWnA    [bear, bear]            2
# 1718  EreYgrQPuR7Sk_FKeZZg9g    [bear, bear]            2
# 1719  oIr50siZDtDYCE_p5K8nYA
# 1720  l8VedGQFMLtTz2zRmpTlxA
# 1721  wSuEwNNOTSH8LJcH1PJAYg
# 1723  49Gyz-LD9MxTh1yzbYiOhw
# 1724  dbfm8H0KQRrxT_QSXrQZ-A
# 1725  2CvbV_ChCveXzg076b4TMA
# 1726  1g9l21XtPm_t0erf_Tt4AA
# 1727  9puopNSFDtjiRbkbsucVOg
# 1728  Z3rkYXXEmQ5o9WJwznQrQA
# 1729  7k3C4P2YsNgwGIhvh95RjA
# 1730  qJxOT7bo-PdW1-xx3nK8SQ
# 1731  Qc974_Ezjpqg2wW5uoEUxA
# 1732  9UD0Smup80sh-c7zc9ySdA
# 1733                  #NAME?
# 1734  9RotEBfTRO5rZl2StsC5Og
# 1735  43_EES4bS7l-jQVZhqx9Pw
# 1736  Qc974_Ezjpqg2wW5uoEUxA
#
#                     gay_counts gay_unique_count  known  \
# 1716  {'queens': 1, 'bear': 1}                2  False
# 1717               {'bear': 2}                1  False
# 1718               {'bear': 2}                1  False
# 1719
# 1720
# 1721
# 1723
# 1724
# 1725
# 1726
# 1727
# 1728
# 1729
# 1730
# 1731
# 1732
# 1733
# 1734
# 1735
# 1736
#
#                                      name                  address  \
# 1716                          Burns Honda             325 N Rte 73
# 1717                   Butcher and Singer           1500 Walnut St
# 1718                       Talula's Daily  208 W Washington Square
# 1719                               Winkel           1119 Locust St
# 1720  Hardena/Waroeng Surabaya Restaurant          1754 S Hicks St
# 1721                         Mina's World            511 S 52nd St
# 1723                     Menagerie Coffee              18 S 3rd St
# 1724                       Darnel’s Cakes             444 N 3rd St
# 1725                     V Marks the Shop           1515 McKean St
# 1726                      Philly Sugaring    525 S 4th St, Ste 363
# 1727                                  NaN                      NaN
# 1728                                  NaN                      NaN
# 1729                                  NaN                      NaN
# 1730                       JJ Bootleggers              35 S 2nd St
# 1731                Level Up Bar & Lounge           1330 Walnut St
# 1732         Danny's Midnight Confessions            133 S 13th St
# 1733                                  NaN                      NaN
# 1734                             Rosewood           1302 Walnut St
# 1735                                  NaN                      NaN
# 1736                Level Up Bar & Lounge           1330 Walnut St
#
#               city state postal_code   latitude  longitude  stars  \
# 1716       Marlton    NJ       08053  39.898006 -74.931903    2.5
# 1717  Philadelphia    PA       19102  39.949334 -75.166176    4.5
# 1718  Philadelphia    PA       19106  39.947283 -75.153628    4.5
# 1719  Philadelphia    PA       19107  39.947791 -75.160339    4.5
# 1720  Philadelphia    PA       19145  39.928436 -75.171266    4.5
# 1721  Philadelphia    PA       19143  39.951598 -75.226381    4.5
# 1723  Philadelphia    PA       19106  39.949673 -75.145919    4.5
# 1724  Philadelphia    PA       19123  39.958318 -75.144936    4.0
# 1725  Philadelphia    PA       19145  39.926033 -75.171741    5.0
# 1726  Philadelphia    PA       19147  39.941904 -75.148874    5.0
# 1727           NaN   NaN         NaN        NaN        NaN    NaN
# 1728           NaN   NaN         NaN        NaN        NaN    NaN
# 1729           NaN   NaN         NaN        NaN        NaN    NaN
# 1730  Philadelphia    PA       19106  39.948986 -75.143770    3.5
# 1731  Philadelphia    PA       19107  39.949152 -75.163395    3.5
# 1732  Philadelphia    PA       19107  39.949469 -75.161737    4.0
# 1733           NaN   NaN         NaN        NaN        NaN    NaN
# 1734  Philadelphia    PA       19107  39.948965 -75.162311    3.0
# 1735           NaN   NaN         NaN        NaN        NaN    NaN
# 1736  Philadelphia    PA       19107  39.949152 -75.163395    3.5
#
#       review_count  is_open  \
# 1716         128.0      1.0
# 1717        1290.0      1.0
# 1718         368.0      1.0
# 1719         246.0      1.0
# 1720         383.0      1.0
# 1721          19.0      1.0
# 1723         390.0      1.0
# 1724           5.0      1.0
# 1725          15.0      1.0
# 1726          22.0      1.0
# 1727           NaN      NaN
# 1728           NaN      NaN
# 1729           NaN      NaN
# 1730         251.0      1.0
# 1731           5.0      1.0
# 1732          34.0      1.0
# 1733           NaN      NaN
# 1734          12.0      1.0
# 1735           NaN      NaN
# 1736           5.0      1.0
#
#                                              attributes  \
# 1716  {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
# 1717  {'RestaurantsPriceRange2': '4', 'HasTV': 'Fals...
# 1718  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 1719  {'WheelchairAccessible': 'True', 'NoiseLevel':...
# 1720  {'RestaurantsGoodForGroups': 'True', 'Business...
# 1721  {'Caters': 'True', 'WheelchairAccessible': 'Tr...
# 1723  {'BusinessParking': '{'valet': False, 'garage'...
# 1724                                               None
# 1725  {'WheelchairAccessible': 'False', 'Caters': 'F...
# 1726  {'WiFi': 'u'no'', 'BikeParking': 'True', 'Whee...
# 1727                                                NaN
# 1728                                                NaN
# 1729                                                NaN
# 1730  {'BikeParking': 'True', 'Caters': 'True', 'Coa...
# 1731  {'RestaurantsTableService': 'True', 'Restauran...
# 1732  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1733                                                NaN
# 1734  {'OutdoorSeating': 'False', 'Alcohol': 'u'full...
# 1735                                                NaN
# 1736  {'RestaurantsTableService': 'True', 'Restauran...
#
#                                              categories  \
# 1716  Auto Repair, Car Dealers, Automotive, Used Car...
# 1717   Restaurants, Steakhouses, American (Traditional)
# 1718  American (Traditional), Food, Bakeries, Specia...
# 1719  Breakfast & Brunch, Food, Sandwiches, Salad, C...
# 1720  Indonesian, Singaporean, Restaurants, Asian Fu...
# 1721  Bakeries, Vegan, Coffee & Tea, Food, Cafes, Re...
# 1723                                 Coffee & Tea, Food
# 1724                       Food, Bakeries, Coffee & Tea
# 1725  Specialty Food, Food, Grocery, Convenience Stores
# 1726              Sugaring, Hair Removal, Beauty & Spas
# 1727                                                NaN
# 1728                                                NaN
# 1729                                                NaN
# 1730  Nightlife, Food, Sports Bars, Comfort Food, Be...
# 1731  American (Traditional), Restaurants, Nightlife...
# 1732  Adult, Books, Mags, Music & Video, Shopping, B...
# 1733                                                NaN
# 1734  Cocktail Bars, Gay Bars, Bars, Lounges, Nightlife
# 1735                                                NaN
# 1736  American (Traditional), Restaurants, Nightlife...
#
#                                                   hours  \
# 1716  {'Monday': '0:0-0:0', 'Tuesday': '9:0-21:0', '...
# 1717  {'Monday': '0:0-0:0', 'Tuesday': '17:0-22:0', ...
# 1718  {'Monday': '8:0-19:0', 'Tuesday': '8:0-19:0', ...
# 1719  {'Monday': '0:0-0:0', 'Thursday': '8:0-15:0', ...
# 1720  {'Wednesday': '12:0-20:0', 'Thursday': '12:0-2...
# 1721  {'Tuesday': '9:0-16:0', 'Wednesday': '9:0-16:0...
# 1723  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 1724                                               None
# 1725  {'Monday': '0:0-0:0', 'Tuesday': '10:0-19:0', ...
# 1726  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...
# 1727                                                NaN
# 1728                                                NaN
# 1729                                                NaN
# 1730  {'Monday': '12:0-2:0', 'Tuesday': '12:0-2:0', ...
# 1731  {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...
# 1732  {'Monday': '5:0-2:0', 'Tuesday': '5:0-2:0', 'W...
# 1733                                                NaN
# 1734     {'Friday': '22:0-2:0', 'Saturday': '22:0-2:0'}
# 1735                                                NaN
# 1736  {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...
#
#                         geometry
# 1716  POINT (-74.93190 39.89801)
# 1717  POINT (-75.16618 39.94933)
# 1718  POINT (-75.15363 39.94728)
# 1719  POINT (-75.16034 39.94779)
# 1720  POINT (-75.17127 39.92844)
# 1721  POINT (-75.22638 39.95160)
# 1723  POINT (-75.14592 39.94967)
# 1724  POINT (-75.14494 39.95832)
# 1725  POINT (-75.17174 39.92603)
# 1726  POINT (-75.14887 39.94190)
# 1727                        None
# 1728                        None
# 1729                        None
# 1730  POINT (-75.14377 39.94899)
# 1731  POINT (-75.16339 39.94915)
# 1732  POINT (-75.16174 39.94947)
# 1733                        None
# 1734  POINT (-75.16231 39.94897)
# 1735                        None
# 1736  POINT (-75.16339 39.94915)

# %%
queercats = joinedDf.categories.dropna()

# %%
type(queercats)
# Out:
# pandas.core.series.Series

# %%
s = ""
for i in range(len(queercats)):
    s+=queercats[i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1722
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 s = ""
#       2 for i in range(len(queercats)):
# ----> 3     s+=queercats[i]
#
# File ~/opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 1722
