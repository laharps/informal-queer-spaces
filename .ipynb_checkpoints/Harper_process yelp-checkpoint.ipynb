# %% [markdown]
# # Cleaned Yelp Dataset

# %% [markdown]
# This noteboook extracts business in Philly from the business.json and then extracts all the reviews. It does the same only for establish gay businesses in Philly.

# %%
import pandas as pd
import geopandas as gpd
import requests
import json
from bs4 import BeautifulSoup
import os
import matplotlib.pyplot as plt
import contextily as ctx

# %% [markdown]
# # All Businesses in Philadelphia

# %% [markdown]
# ## Filter Business JSON for Philadelphia Area

# %%
# load data
biz = pd.read_json('/Users/harper/Documents/GitHub/yelp_dataset/yelp_academic_dataset_business.json',lines=True)

# create geodataframe
bizGdf = gpd.GeoDataFrame(biz, geometry=gpd.points_from_xy(biz.longitude, biz.latitude), crs='EPSG:4326')

# filter for Philadelphia metro area
bizPhil = bizGdf[(bizGdf.state == 'PA') | (bizGdf.state == 'NJ') | (bizGdf.state == 'DE')]

# %%
list(bizPhil.categories.unique())
# Out:
# ['Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries',
#  'Brewpubs, Breweries, Food',
#  'Sushi Bars, Restaurants, Japanese',
#  'Korean, Restaurants',
#  'Pet Services, Pet Groomers, Pets, Veterinarians',
#  'Cocktail Bars, Bars, Italian, Nightlife, Restaurants',
#  'Pizza, Restaurants, Salad, Soup',
#  "Dance Wear, Sports Wear, Children's Clothing, Arts & Entertainment, Social Clubs, Performing Arts, Sporting Goods, Shoe Stores, Fashion, Shopping",
#  'Pizza, Restaurants',
#  'Eatertainment, Arts & Entertainment, Brewpubs, American (Traditional), Bakeries, Breweries, Food, Restaurants',
#  'Restaurants, Burgers',
#  'Mobile Phones, Telecommunications, Electronics, Mobile Phone Accessories, Local Services, Shopping, IT Services & Computer Repair',
#  'DUI Law, Professional Services, Lawyers, Criminal Defense Law',
#  'Health & Medical, Beauty & Spas, Laser Hair Removal, Doctors, Hair Removal, Chiropractors, Weight Loss Centers, Sports Medicine, Medical Spas, Skin Care',
#  'Fashion, Shopping, Department Stores, Furniture Stores, Candle Stores, Home & Garden, Home Decor',
#  'Restaurants, Italian',
#  'Hotels, Hotels & Travel, Event Planning & Services',
#  'Ophthalmologists, Eyewear & Opticians, Health & Medical, Shopping, Doctors, Optometrists',
#  'Seafood, Restaurants, Bars, Nightlife, Cocktail Bars, American (New), Pubs',
#  'Banks & Credit Unions, Financial Services',
#  'American (Traditional), Bars, Nightlife, Sports Bars, Restaurants',
#  'American (Traditional), Sports Bars, Restaurants, Bars, Nightlife, Steakhouses, Salad, Beer Bar',
#  'Food, Grocery',
#  'Restaurants, Automotive, Delis, Gas Stations, Food, Coffee & Tea, Sandwiches, Convenience Stores',
#  'Restaurants, Japanese, Sushi Bars, Asian Fusion',
#  'Keys & Locksmiths, Home Services, Local Services',
#  'Juice Bars & Smoothies, Restaurants, Fruits & Veggies, Salad, Specialty Food, Food',
#  'Masonry/Concrete, Gardeners, Lawn Services, Tree Services, Landscape Architects, Home Services, Contractors, Landscaping',
#  'Fitness & Instruction, Physical Therapy, Health & Medical, Active Life, Trainers',
#  'Mexican, Restaurants',
#  'Flooring, Handyman, Contractors, Home Services',
#  'Pest Control, Local Services',
#  'Shopping, Auction Houses, Active Life',
#  'Eyewear & Opticians, Health & Medical, Shopping, Doctors, Optometrists, Ophthalmologists',
#  'Eyewear & Opticians, Shopping',
#  'Grocery, Food',
#  'Barbers, Beauty & Spas',
#  'Nightlife, Chicken Wings, Pubs, Bars, American (Traditional), Restaurants',
#  'Restaurants, Chinese',
#  'Car Wash, Auto Detailing, Automotive',
#  'Real Estate, Home Services, Real Estate Agents',
#  'Buses, Transportation, Bus Tours, Hotels & Travel, Travel Agents, Travel Services, Airport Shuttles, Tours, Public Transportation',
#  "Fashion, Shopping, Men's Clothing",
#  'Seafood, Restaurants, Sushi Bars, Japanese',
#  'Art Classes, Shopping, Education, Arts & Crafts, Appliances & Repair, Knitting Supplies, Art Supplies, Local Services',
#  'Gas Stations, Automotive, Towing',
#  'Italian, Restaurants',
#  'Home Cleaning, Home Services, Office Cleaning, Professional Services, Window Washing',
#  'Beauty & Spas, Hair Stylists, Hair Extensions, Hair Salons',
#  'Dog Parks, Active Life, Parks',
#  'Food, Ice Cream & Frozen Yogurt, Desserts, Shaved Ice',
#  'Shopping, Department Stores, Grocery, Fashion, Food, Electronics, Furniture Stores, Home & Garden',
#  'Wildlife Control, Local Services, Pest Control',
#  'Burgers, Restaurants, Fast Food',
#  'Japanese, Chinese, Restaurants, Thai',
#  'Restaurants, Bakeries, Caterers, Bagels, Food, Event Planning & Services',
#  'Food, Coffee & Tea',
#  'Real Estate, Apartments, Home Services',
#  'Health & Medical, Doctors, Medical Centers, Local Services, Obstetricians & Gynecologists, Naturopathic/Holistic',
#  'Carpet Cleaning, Rugs, Shopping, Flooring, Local Services, Home Cleaning, Carpeting, Home & Garden, Home Services',
#  'Drugstores, Convenience Stores, Food, Shopping',
#  'Home Services, Tree Services',
#  'Automotive, Auto Detailing, Car Wash, Auto Glass Services',
#  'Restaurants, Breakfast & Brunch, Vegan, Bagels, Food, Coffee & Tea',
#  'Shopping, Jewelry',
#  'Local Flavor, Team Building Activities, Active Life, Arts & Entertainment, Event Planning & Services, Walking Tours, Scavenger Hunts, Museums, Hotels & Travel, Tours',
#  'Shanghainese, Restaurants, Sushi Bars, Szechuan, Sports Bars, Lounges, Asian Fusion, Thai, Karaoke, Chinese, Nightlife, Bars',
#  'Pet Services, Pet Sitting, Pets',
#  'Drugstores, Pharmacy, Health & Medical, Convenience Stores, Food, Shopping',
#  'Shopping, Fashion, Outdoor Gear, Active Life, Golf Lessons, Sporting Goods, Golf Equipment, Golf, Fitness & Instruction, Sports Wear',
#  'Active Life, Fitness & Instruction, Trainers, Gyms',
#  'Food, Bakeries, Restaurants',
#  'Mountain Biking, Bike Repair/Maintenance, Shopping, Bikes, Active Life, Local Services, Sporting Goods',
#  'Cupcakes, Caribbean, Restaurants, Trinidadian, Food, Bakeries, Cafes',
#  'Tex-Mex, Restaurants, American (Traditional), Nightlife, Bars',
#  'Orthodontists, Health & Medical, Oral Surgeons, General Dentistry, Dentists, Cosmetic Dentists',
#  'Bike Rentals, Active Life, Bikes, Shopping, Sporting Goods',
#  'Italian, Pizza, Gluten-Free, Restaurants, Bars, Wine Bars, Nightlife',
#  'Health & Medical, Medical Spas, Beauty & Spas, Skin Care, Makeup Artists',
#  'Tours, Walking Tours, Hotels & Travel, Food Tours',
#  'Italian, Restaurants, Salad, Bars, Venues & Event Spaces, Wine Bars, Nightlife, Event Planning & Services',
#  'Nightlife, Bars, Cocktail Bars, Japanese, Restaurants, Sushi Bars, Asian Fusion',
#  'Event Planning & Services, Hotels & Travel, Hotels, Venues & Event Spaces',
#  'Beauty & Spas, Hair Salons',
#  'Sandwiches, Chicken Wings, Restaurants, Donuts, Food',
#  'Arts & Crafts, Sports Wear, Costumes, Performing Arts, Adult, Shopping, Sporting Goods, Arts & Entertainment, Fashion',
#  'Flooring, Home Services, Carpeting, Contractors, Refinishing Services',
#  'Shoe Repair, Sewing & Alterations, Local Services',
#  'Thai, Vietnamese, Chinese, Restaurants',
#  "Men's Clothing, Women's Clothing, Children's Clothing, Fashion, Shopping, Accessories",
#  'Radiologists, Doctors, Health & Medical',
#  'Ethnic Food, Specialty Food, Restaurants, Food, Pizza',
#  'Chinese, Restaurants, Japanese',
#  'Restaurants, Cajun/Creole, Southern, Nightlife, Cocktail Bars, Breakfast & Brunch, Seafood, Bars',
#  'Education, Preschools, Local Services, Child Care & Day Care, Elementary Schools',
#  'Auto Repair, Automotive',
#  'Car Wash, Automotive',
#  'Automotive, Propane, Movers, Self Storage, Towing, Home Services, Truck Rental, Local Services',
#  'Pets, Veterinarians',
#  'Food, Beer, Wine & Spirits',
#  'Nightlife, Pubs, American (Traditional), Restaurants, Bars',
#  'Mexican, Pizza, Restaurants',
#  'Churches, Religious Organizations',
#  'Arts & Entertainment, Event Planning & Services, Venues & Event Spaces, Museums',
#  'Bars, Pubs, Nightlife, Restaurants, American (Traditional)',
#  'Local Services, Community Service/Non-Profit, Health & Medical, Doctors, Family Practice, Medical Centers, Counseling & Mental Health',
#  'American (Traditional), Active Life, Nightlife, Bowling, Restaurants',
#  'Restaurants, Fast Food, Burgers, Food, Coffee & Tea',
#  'Home & Garden, Countertop Installation, Cabinetry, Home Services, Kitchen & Bath, Shopping, Contractors',
#  'Restaurants, Fast Food',
#  'Food, Desserts, Shopping, Specialty Food, Candy Stores, Chocolatiers & Shops',
#  'Restaurants, American (New), Breakfast & Brunch, Burgers',
#  'Food, Convenience Stores, Restaurants, Food Delivery Services, Local Flavor, Delis',
#  'Carpet Cleaning, Local Services, Home Services, Home Cleaning, Window Washing, Professional Services, Pressure Washers, Office Cleaning',
#  'American (New), Restaurants',
#  'Shopping, Food, Arts & Entertainment, Wholesale Stores, Brewing Supplies, Beer, Wine & Spirits, Wineries',
#  'Food, Wholesalers, Coffee Roasteries, Professional Services, Coffee & Tea',
#  'Active Life, Escape Games',
#  'Auto Parts & Supplies, Automotive',
#  'Japanese, Restaurants, Sushi Bars, Chinese',
#  'Bars, Nightlife, Pubs',
#  'Shopping, Hair Salons, Professional Services, Beauty & Spas, Cosmetics & Beauty Supply',
#  'Caterers, Event Planning & Services, Sandwiches, Restaurants',
#  'Windows Installation, Home Services, Door Sales/Installation, Shutters, Siding',
#  'Automotive, Auto Repair',
#  'Fitness & Instruction, Food, Shopping, Health & Medical, Beauty & Spas, Cosmetics & Beauty Supply, Active Life, Yoga, Specialty Food, Health Markets, Vitamins & Supplements',
#  'Desserts, Specialty Food, Food, Chocolatiers & Shops',
#  'Carpenters, Pressure Washers, Wallpapering, Home Services, Painters',
#  'Restaurants, Thai, Food, Specialty Food, Ethnic Food',
#  'Event Planning & Services, Whiskey Bars, American (New), American (Traditional), Venues & Event Spaces, Bars, Nightlife, Restaurants',
#  'American (Traditional), Restaurants, Diners, Breakfast & Brunch',
#  'Plumbing, Home Services',
#  'Shopping, Electronics Repair, Local Services, IT Services & Computer Repair, Mobile Phone Repair, Mobile Phone Accessories, Mobile Phones',
#  'Food, Burgers, Restaurants, Coffee & Tea, Fast Food',
#  'Coffee & Tea, Restaurants, American (New), Food, Cafes, Breakfast & Brunch',
#  'Local Services, Shoe Repair',
#  'Building Supplies, Shopping, Home & Garden, Home Decor, Home Services, Kitchen & Bath',
#  'Hospitals, Health & Medical, Optometrists',
#  'Restaurants, French',
#  'Body Shops, Automotive',
#  "Hair Salons, Barbers, Beauty & Spas, Men's Hair Salons",
#  'Hair Salons, Hair Stylists, Beauty & Spas, Hair Removal, Eyelash Service, Nail Salons',
#  'Contractors, Home Services, Septic Services, Local Services',
#  'Italian, Restaurants, Fast Food, Chicken Wings, Pizza',
#  'Mobile Phones, Shopping',
#  'Restaurants, Food, Bagels, Breakfast & Brunch, Coffee & Tea, Sandwiches, Delis, American (New)',
#  'Auto Repair, Oil Change Stations, Auto Parts & Supplies, Tires, Automotive',
#  'Shopping, Cannabis Collective, Cannabis Clinics, Cannabis Dispensaries, Health & Medical',
#  'Food, American (Traditional), Fast Food, Ice Cream & Frozen Yogurt, Burgers, Restaurants',
#  'Automotive, Auto Repair, Tires, Body Shops, Oil Change Stations, Towing',
#  'Auto Parts & Supplies, Automotive, Auto Repair, Tires, Oil Change Stations',
#  'Antiques, Shopping',
#  'Indian, Restaurants',
#  'Restaurants, Cocktail Bars, American (New), Desserts, American (Traditional), Nightlife, Bars, Food',
#  'Carpeting, Home Services',
#  'Event Planning & Services, American (Traditional), Restaurants, Food, Caterers, Fast Food, Chicken Shop, Breakfast & Brunch',
#  'Veterinarians, Pet Stores, Pets, Pet Photography, Pet Services, Pet Sitting, Pet Groomers',
#  'Restaurants, Fast Food, Burgers',
#  'Beauty & Spas, Nail Salons',
#  'Bagels, Food, Breakfast & Brunch, Coffee & Tea, Restaurants, Burgers, Delis',
#  'Active Life, Event Planning & Services, Escape Games, Challenge Courses, Team Building Activities',
#  'Chinese, Restaurants',
#  'American (Traditional), Bars, Breakfast & Brunch, Nightlife, Cocktail Bars, Restaurants, Hotels & Travel, Hotels, Event Planning & Services',
#  'Cajun/Creole, Seafood, Noodles, Restaurants',
#  'Hair Extensions, Hair Salons, Hair Stylists, Beauty & Spas, Blow Dry/Out Services',
#  'Grocery, Food, Farmers Market',
#  'Breakfast & Brunch, Coffee & Tea, Sandwiches, Food, Restaurants, Cafes',
#  'Food, Cafes, Restaurants, Coffee & Tea, Breakfast & Brunch',
#  'Italian, Spanish, Restaurants, Food',
#  'Orthodontists, Health & Medical, Pediatric Dentists, Dentists',
#  'Nutritionists, Weight Loss Centers, Health & Medical, Chiropractors, Active Life, Fitness & Instruction',
#  'Italian, American (Traditional), Pizza, Restaurants, Cheesesteaks',
#  'Apartments, University Housing, Home Services, Real Estate, Property Management',
#  'Party Supplies, Event Planning & Services, Party Equipment Rentals',
#  'Restaurants, Chicken Shop, Fast Food, Chicken Wings',
#  'Korean, American (Traditional), Sandwiches, Cheesesteaks, Restaurants, Coffee & Tea, Breakfast & Brunch, Food',
#  'Towing, Roadside Assistance, Automotive',
#  'Delis, Convenience Stores, Restaurants, Food, Coffee & Tea, Sandwiches',
#  'Restaurants, Bakeries, Cafes, Bagels, Food, Soup, Salad, Sandwiches, Breakfast & Brunch',
#  'Cosmetic Dentists, Health & Medical, Endodontists, Dentists, Orthodontists, General Dentistry, Oral Surgeons',
#  'Breakfast & Brunch, Restaurants, American (Traditional)',
#  'Restaurants, American (New), Event Planning & Services, Bars, Pubs, American (Traditional), Social Clubs, Hotels, Hotels & Travel, Nightlife, Arts & Entertainment, Venues & Event Spaces',
#  'Desserts, Food, Ice Cream & Frozen Yogurt, Shaved Ice',
#  'Hotels & Travel, Tours',
#  'Preschools, Recreation Centers, Education, Gyms, Community Centers, Day Camps, Fitness & Instruction, Local Services, Active Life, Public Services & Government, Child Care & Day Care, Summer Camps',
#  'Bars, Breweries, Beer Tours, Tours, Food, Hotels & Travel, Beer, Wine & Spirits, Food Trucks, Nightlife, Beer Bar',
#  'Real Estate, Home Services, Apartments',
#  'Art Classes, Party & Event Planning, Education, Paint & Sip, Arts & Entertainment, Event Planning & Services',
#  'Urgent Care, Pediatricians, Doctors, Health & Medical',
#  'Restaurants, Indian',
#  'Home Services, Flooring, Refinishing Services',
#  'Ice Cream & Frozen Yogurt, Food, Food Stands, Restaurants, Hot Dogs',
#  'Restaurants, Fast Food, Food, Coffee & Tea, Burgers',
#  'Home & Garden, Mattresses, Shopping',
#  'Automotive, Oil Change Stations',
#  'Restaurants, Food, Bakeries, Greek',
#  'Gelato, Chocolatiers & Shops, Food, Gift Shops, Candy Stores, Flowers & Gifts, Shopping, Specialty Food, Local Flavor',
#  'Nightlife, Bars, Beer, Wine & Spirits, Pubs, Irish, Food, Restaurants',
#  'Garage Door Services, Home Services',
#  'Bars, Beer Bar, American (Traditional), Nightlife, Pubs, Burgers, Restaurants',
#  'Car Dealers, Auto Parts & Supplies, Auto Repair, Hotels & Travel, Automotive, Car Rental',
#  'Food, Juice Bars & Smoothies',
#  'Jewelry, Shopping, Local Services, Jewelry Repair',
#  'Arts & Entertainment, Haunted Houses, Local Flavor',
#  'Italian, Delis, Restaurants, Salad',
#  'Italian, Bars, Restaurants, Nightlife, Wine Bars, Breakfast & Brunch',
#  'Fast Food, Sandwiches, Delis, Restaurants',
#  'Shoe Stores, Shopping, Fashion',
#  'Golf, Venues & Event Spaces, Event Planning & Services, Restaurants, Active Life',
#  'Day Camps, Fitness & Instruction, Summer Camps, Active Life, Yoga, Kids Activities',
#  'Nail Salons, Beauty & Spas',
#  'Restaurants, Vegan, Vegetarian',
#  'Commercial Real Estate, Shopping, Apartments, Real Estate, Home Services',
#  'Restaurants, Pizza, Salad',
#  'Shopping, Jewelry, Watches, Antiques',
#  'Soup, Salad, American (Traditional), Vegetarian, Sandwiches, American (New), Restaurants',
#  'Restaurants, Pizza, Fast Food',
#  'Health & Medical, Hospitals, Medical Centers',
#  'Shopping, Home & Garden, Appliances',
#  'Radio Stations, Mass Media',
#  'Arts & Entertainment, Performing Arts, Cinema',
#  'Wigs, Adult Entertainment, Fashion, Adult, Arts & Crafts, Lingerie, Costumes, Nightlife, Shopping',
#  'Event Planning & Services, Hotels, Hotels & Travel',
#  'Beauty & Spas, Nail Salons, Waxing, Hair Removal',
#  'Massage, Health & Medical, Beauty & Spas, Medical Spas',
#  'Gift Shops, Flowers & Gifts, Food, Florists, Chocolatiers & Shops, Shopping, Specialty Food',
#  'Day Spas, Cosmetics & Beauty Supply, Beauty & Spas, Shopping, Nail Salons',
#  'Shopping, Food, Health & Medical, Pharmacy, Convenience Stores, Drugstores',
#  'Diners, Restaurants, Sandwiches, Breakfast & Brunch, Vegetarian',
#  'Home Services, Home Inspectors',
#  'Food, Coffee & Tea, Gas Stations, Restaurants, Automotive, Sandwiches, Convenience Stores',
#  'Restaurants, Sandwiches, Cheesesteaks',
#  'Health & Medical, Cosmetic Dentists, Dentists, General Dentistry',
#  'Active Life, Playgrounds',
#  'Flowers & Gifts, Specialty Food, Shopping, Food, Florists, Gift Shops, Chocolatiers & Shops',
#  'Hotels & Travel, Hotels, Event Planning & Services, Resorts, Venues & Event Spaces',
#  "Fashion, Men's Clothing, Shopping, Shoe Stores, Sporting Goods, Sports Wear",
#  'Restaurants, Delis, Salad, Sandwiches',
#  'Food, Nightlife, Restaurants, Irish Pub, Bars, Irish, Pubs, Beer, Wine & Spirits, Event Planning & Services, Gastropubs, Caterers',
#  'Steakhouses, Restaurants, Nightlife, Seafood, Bars, American (Traditional)',
#  'Farmers Market, Specialty Food, Food, Fruits & Veggies',
#  'Restaurants, Donuts, Coffee & Tea, Food',
#  'Shopping, Department Stores, Fashion',
#  'Beauty & Spas, Hair Salons, Cosmetics & Beauty Supply, Hair Stylists, Hair Extensions, Shopping',
#  'Shopping, Beauty & Spas, Cosmetics & Beauty Supply, Skin Care, Hair Salons',
#  "Men's Hair Salons, Hair Salons, Barbers, Beauty & Spas",
#  'Auto Repair, Automotive, Auto Detailing, Motorcycle Repair',
#  'Coffee & Tea, Bakeries, Desserts, Food, Ice Cream & Frozen Yogurt',
#  'Home & Garden, Shopping, Furniture Stores, Antiques, Home Decor',
#  'Fashion, Outdoor Furniture Stores, Building Supplies, Appliances & Repair, Appliances, Shopping, Home Services, Home & Garden, Hardware Stores, Department Stores, Outlet Stores, Local Services',
#  'Chinese, Restaurants, Seafood, Noodles',
#  'Pizza, Seafood, Restaurants, Mexican, Italian, Burgers, Salad, Greek, Sandwiches',
#  'Laundromat, Local Services, Laundry Services',
#  'Apartments, Shopping Centers, Property Management, Local Services, Commercial Real Estate, Real Estate, Home Services, Shopping',
#  'Beer, Wine & Spirits, Food',
#  'Gutter Services, Landscape Architects, Home Services, Landscaping',
#  'Veterinarians, Pets',
#  'Trinidadian, Caribbean, Restaurants, Seafood',
#  'Smog Check Stations, Wheel & Rim Repair, Auto Repair, Auto Parts & Supplies, Tires, Automotive, Oil Change Stations, Body Shops',
#  'Dog Walkers, Pet Services, Health & Medical, Reiki, Pet Sitting, Pets',
#  'Japanese, Restaurants',
#  "Shopping, Shoe Stores, Fashion, Accessories, Women's Clothing",
#  'Donuts, Food, Coffee & Tea, Restaurants',
#  'Delis, Gas Stations, Food, Convenience Stores, Restaurants, Automotive, Coffee & Tea, Sandwiches',
#  'Fitness & Instruction, Health & Medical, Weight Loss Centers, Active Life, Gyms, Trainers',
#  'Health & Medical, Pediatric Dentists, Dentists, General Dentistry, Orthodontists',
#  'Sandwiches, Vegetarian, Pizza, Food, Coffee & Tea, Delis, Restaurants, American (New)',
#  'Beer, Wine & Spirits, Organic Stores, Grocery, Fruits & Veggies, Specialty Food, Food, Meat Shops, Department Stores, Fashion, Shopping, Discount Store',
#  'Pizza, Restaurants, Italian',
#  'Beauty & Spas, Tanning, Nail Salons, Hair Salons, Waxing, Hair Removal',
#  'Sandwiches, Fast Food, Restaurants',
#  'Restaurants, Food, Bakeries',
#  'Music & DVDs, Shopping, Vinyl Records, Books, Mags, Music & Video',
#  'Active Life, Skating Rinks',
#  'Hotels, Event Planning & Services, Hotels & Travel',
#  'Coffee & Tea, Food',
#  'Waxing, Hair Removal, Beauty & Spas, Hair Salons',
#  'Auto Repair, Oil Change Stations, Automotive, Tires',
#  'Auto Repair, Car Dealers, Oil Change Stations, Automotive',
#  'Beauty & Spas, Hair Extensions, Makeup Artists, Hair Salons',
#  'Waxing, Beauty & Spas, Eyelash Service, Used, Vintage & Consignment, Hair Salons, Hair Removal, Makeup Artists, Shopping, Fashion',
#  'Restaurants, Mexican, Arts & Entertainment, Event Planning & Services, Italian, Gluten-Free, Nightlife, Lounges, Vegan, Bars, Caterers, Vegetarian',
#  'IT Services & Computer Repair, Local Services',
#  'Gastroenterologist, Chiropractors, Nutritionists, Doctors, Health & Medical',
#  'Nightlife, Seafood, Bars, Restaurants, Cajun/Creole',
#  'Cosmetic Dentists, General Dentistry, Health & Medical, Orthodontists, Dentists, Prosthodontists, Oral Surgeons',
#  'Ramen, Restaurants, Japanese',
#  'General Dentistry, Health & Medical, Dentists',
#  'Event Planning & Services, Party Supplies',
#  'Cosmetics & Beauty Supply, Beauty & Spas, Shopping, Hair Extensions, Wigs, Skin Care, Hair Salons',
#  'Health & Medical, Urgent Care',
#  'Home Services, Heating & Air Conditioning/HVAC, Water Heater Installation/Repair, Plumbing',
#  'Restaurants, Pizza',
#  'Home Services, Irrigation',
#  'Scavenger Hunts, Active Life, Team Building Activities, Event Planning & Services',
#  'Kitchen & Bath, Flooring, Cabinetry, Home Services, Shopping, Home & Garden',
#  'Employment Law, Lawyers, Personal Injury Law, Professional Services, Workers Compensation Law',
#  'Home Services, Contractors',
#  'Coffee & Tea, Food, Water Delivery, Local Services',
#  'Cafes, Restaurants, Food, Coffee & Tea',
#  'Home Decor, Home Services, Home & Garden, Building Supplies, Shopping, Contractors',
#  'Sporting Goods, Fashion, Souvenir Shops, Sports Wear, Shopping',
#  'Bars, Food, Restaurants, Beer, Wine & Spirits, American (Traditional), Nightlife',
#  'Steakhouses, Barbeque, Restaurants, American (Traditional), Food',
#  'Restaurants, Thai, Food, Cafes, Cupcakes',
#  "Beauty & Spas, Barbers, Hair Salons, Men's Hair Salons",
#  'Tex-Mex, Restaurants, Mexican',
#  'Laundry Services, Dry Cleaning & Laundry, Local Services',
#  'Arts & Entertainment, Professional Services, Spiritual Shop, Supernatural Readings, Life Coach, Shopping, Religious Items',
#  'Chicken Wings, Nightlife, Bars, Delis, Food, Beer Gardens, Sandwiches, Beer Bar, Restaurants, Beer, Wine & Spirits, Gastropubs',
#  'Hotels & Travel, Automotive, Car Rental, Truck Rental',
#  'Food, Donuts, Coffee & Tea',
#  'Restaurants, Bakeries, Donuts, Food',
#  'Restaurants, Pizza, Italian',
#  'Breakfast & Brunch, Coffee & Tea, Restaurants, Sandwiches, Food',
#  'Appliances & Repair, Farm Equipment Repair, Local Services',
#  'Restaurants, Cajun/Creole',
#  'Naturopathic/Holistic, Cannabis Clinics, Neurologist, Doctors, Alternative Medicine, Medical Cannabis Referrals, Health & Medical',
#  'Ramen, Japanese, Restaurants',
#  'Restaurants, Malaysian, Burmese, Asian Fusion, Thai',
#  'Books, Mags, Music & Video, Shopping, Toy Stores, Comic Books, Bookstores',
#  'Juice Bars & Smoothies, Sandwiches, Food, Restaurants, Coffee & Tea',
#  'Amateur Sports Teams, Gyms, Active Life, Fitness & Instruction',
#  'Health & Medical, General Dentistry, Dental Hygienists, Cosmetic Dentists, Dentists',
#  'Hair Removal, Beauty & Spas',
#  'Beauty & Spas, Nail Salons, Hair Salons',
#  'Beauty & Spas, Hair Removal, Nail Salons, Nail Technicians, Waxing',
#  'Organic Stores, Meat Shops, Food, Discount Store, Shopping, Fruits & Veggies, Specialty Food, Grocery, Beer, Wine & Spirits',
#  'Specialty Food, Mediterranean, Restaurants, Italian, Food',
#  'Shades & Blinds, Flooring, Home Services, Carpeting',
#  'Breakfast & Brunch, Restaurants',
#  'Restaurants, Pizza, Salad, Sandwiches',
#  'Internet Service Providers, Mobile Phones, Professional Services, Shopping, Home Services, Electronics',
#  'Hair Removal, Nail Salons, Beauty & Spas',
#  'Burgers, Restaurants',
#  'Fashion, Home & Garden, Used, Vintage & Consignment, Jewelry, Shopping, Furniture Stores, Antiques',
#  'Restaurants, Fast Food, Sandwiches, Italian',
#  'Hotels & Travel, Event Planning & Services, Hotels',
#  'Architects, Home Services, Structural Engineers, Professional Services',
#  'Home Services, Movers',
#  'Home Services, Heating & Air Conditioning/HVAC, Local Services, Air Duct Cleaning',
#  'Boot Camps, Weight Loss Centers, Health & Medical, Gyms, Trainers, Fitness & Instruction, Active Life, Martial Arts, Massage Therapy, Nutritionists',
#  'Pediatric Dentists, Health & Medical, Dentists, Cosmetic Dentists',
#  'Wineries, Arts & Entertainment, Food',
#  'Vietnamese, Asian Fusion, Bars, American (New), Restaurants, Breakfast & Brunch, Nightlife, Thai, Gluten-Free',
#  'Food Delivery Services, Halal, Food, Restaurants, Buffets, Pakistani, Indian',
#  'Home & Garden, Building Supplies, Shopping, Hardware Stores, Home Services, Appliances, Nurseries & Gardening',
#  'Sporting Goods, Skate Shops, Surfing, Shopping, Active Life',
#  'Bars, Nightlife',
#  'Dive Bars, Nightlife, Bars',
#  'Food, Beer, Wine & Spirits, Shopping',
#  'Event Planning & Services, Flowers & Gifts, Shopping, Florists, Floral Designers',
#  'Pets, Pet Groomers, Pet Sitting, Pet Services',
#  'Shopping, Restaurants, Cafes, Fashion',
#  'Filipino, Restaurants',
#  'Cheesesteaks, Restaurants',
#  'Sandwiches, Breakfast & Brunch, Coffee & Tea, Food, Restaurants, Cafes, Juice Bars & Smoothies',
#  'Juice Bars & Smoothies, Restaurants, Food, Coffee & Tea, Specialty Food, Organic Stores, Health Markets, Grocery, Sandwiches, Shopping, Vitamins & Supplements',
#  'Real Estate Agents, Real Estate Services, Home Services, Real Estate',
#  'Automotive, Car Stereo Installation, Auto Parts & Supplies, Tires',
#  'Coffee & Tea, Pubs, Restaurants, Bars, Food, American (New), Nightlife, Breakfast & Brunch, Brewpubs, Breweries',
#  'Restaurants, Delis, Sandwiches',
#  'Shopping, Computers, Specialty Schools, Marketing, Mobile Phone Repair, Professional Services, Telecommunications, Education, Graphic Design, Web Design, Mobile Phone Accessories, Home Network Installation, Security Systems, Legal Services, Local Services, Home Services, IT Services & Computer Repair',
#  'Bowling, Sports Bars, Restaurants, Bars, Mexican, American (Traditional), Active Life, Pubs, Nightlife',
#  'Restaurants, Indian, Buffets, Vegetarian, Seafood',
#  "Cosmetics & Beauty Supply, Beauty & Spas, Men's Hair Salons, Shopping, Hair Removal, Waxing, Makeup Artists, Blow Dry/Out Services, Hair Stylists, Hair Salons",
#  'Sandwiches, Burgers, Cheesesteaks, Restaurants',
#  'Mexican, Food, Restaurants, Breakfast & Brunch, Bakeries',
#  'Contractors, Home Services, Masonry/Concrete, Excavation Services',
#  'Restaurants, Sandwiches, Breakfast & Brunch, Caterers, American (New), Comfort Food, Food Trucks, Event Planning & Services, American (Traditional), Food',
#  'Chinese, Restaurants, Asian Fusion, Japanese, Sushi Bars, Thai',
#  'Hair Salons, Beauty & Spas, Barbers',
#  'Home Services, Real Estate, Apartments',
#  'Cafes, Pakistani, Juice Bars & Smoothies, Restaurants, Ice Cream & Frozen Yogurt, Halal, Indian, Coffee & Tea, Food',
#  'Nail Salons, Waxing, Beauty & Spas, Hair Removal',
#  'Cosmetics & Beauty Supply, Beauty & Spas, Shopping',
#  'Piercing, Beauty & Spas, Tattoo',
#  'Gift Shops, Shopping, Arts & Entertainment, Flowers & Gifts',
#  'Family Practice, Health & Medical, Doctors',
#  'Grocery, Food, Shopping, Drugstores',
#  "Women's Clothing, Fashion, Accessories, Children's Clothing, Personal Shopping, Shopping",
#  'Plumbing, Contractors, Home Services',
#  'Ear Nose & Throat, Hearing Aid Providers, Medical Spas, Beauty & Spas, Doctors, Health & Medical',
#  'Cinema, Arts & Entertainment',
#  'Specialty Food, Meat Shops, Sandwiches, Food, Restaurants, Delis, Grocery',
#  'Property Management, Real Estate, Home Services',
#  'Breakfast & Brunch, American (Traditional), Korean, Restaurants, Gastropubs, Nightlife, Bars, Cocktail Bars',
#  'Gas Stations, Food, Automotive, Restaurants, Sandwiches, Convenience Stores, Coffee & Tea',
#  'Delis, Seafood, Cheesesteaks, Convenience Stores, Sandwiches, Food, Restaurants',
#  'Bubble Tea, Juice Bars & Smoothies, Food, Coffee & Tea',
#  'Decks & Railing, Junk Removal & Hauling, Carpenters, Contractors, Painters, Windows Installation, Handyman, TV Mounting, Drywall Installation & Repair, Plumbing, Local Services, Demolition Services, Home Services',
#  'Shopping, Books, Mags, Music & Video, Videos & Video Game Rental, Arts & Entertainment, Food, Cinema, Ice Cream & Frozen Yogurt',
#  'Tattoo, Arts & Entertainment, Beauty & Spas, Art Galleries, Shopping',
#  'Financial Services, Financial Advising, Accountants, Tax Services, Investing, Professional Services',
#  'Restaurants, Tex-Mex, Mexican',
#  'Guns & Ammo, Gun/Rifle Ranges, Active Life, Shopping, Specialty Schools, Education, Firearm Training',
#  'Eyewear & Opticians, Shopping, Health & Medical, Ophthalmologists, Laser Eye Surgery/Lasik, Optometrists, Doctors',
#  'Heating & Air Conditioning/HVAC, Home Services, Water Heater Installation/Repair, Plumbing',
#  'American (Traditional), Steakhouses, Italian, Restaurants, Tapas/Small Plates',
#  "Hair Salons, Hair Stylists, Men's Hair Salons, Barbers, Beauty & Spas, Hair Extensions",
#  'Nail Salons, Hair Removal, Waxing, Beauty & Spas',
#  'Breakfast & Brunch, Restaurants, Soul Food, Cafes, Food',
#  'Health & Medical, Dentists, General Dentistry',
#  'Fitness & Instruction, Gyms, Active Life',
#  'Restaurants, American (New), Nightlife, Breakfast & Brunch, Bars, Vietnamese',
#  'Bagels, Food, Sandwiches, Delis, Breakfast & Brunch, Restaurants, Event Planning & Services, Caterers',
#  'Pizza, Italian, Restaurants, Sandwiches',
#  'Shopping, Piercing, Beauty & Spas, Jewelry',
#  'Barbeque, Restaurants, American (New), Salad, Sandwiches, Breakfast & Brunch',
#  'Food, Grocery, Drugstores, Shopping',
#  'Shopping, Golf, Active Life, Sporting Goods, Golf Equipment, Mini Golf',
#  'Fitness & Instruction, Active Life, Gyms',
#  'Health & Medical, Chiropractors',
#  'Pet Services, Pet Groomers, Pets',
#  'Restaurants, Buffets',
#  "Shopping, Baby Gear & Furniture, Thrift Stores, Children's Clothing, Fashion, Used, Vintage & Consignment",
#  'Arts & Entertainment, Professional Sports Teams',
#  'Chicken Wings, Restaurants, Fast Food',
#  'Laundry Services, Sewing & Alterations, Local Services, Dry Cleaning',
#  'Automotive, Auto Repair, Car Dealers',
#  'Active Life, Bowling',
#  'Oral Surgeons, Health & Medical, Cosmetic Dentists, Dentists, Orthodontists',
#  'Restaurants, Mediterranean',
#  'Hair Salons, Beauty & Spas',
#  'Restaurants, American (Traditional), Breakfast & Brunch, American (New), Buffets',
#  'Contractors, Home Services, Cabinetry, Interior Design',
#  'Restaurants, Food, Caribbean, Food Trucks',
#  'Automotive, Tires',
#  'Appliances, Shopping, Local Services, Sewing & Alterations, Home Services, Home & Garden, Heating & Air Conditioning/HVAC, Appliances & Repair',
#  'Mediterranean, Restaurants, Salad',
#  'Sushi Bars, Ramen, Restaurants, Japanese',
#  'Tanning, Beauty & Spas',
#  'Food, Seafood, Sardinian, Gelato, Restaurants, Pizza, Italian',
#  'Hotels, Event Planning & Services, Hotels & Travel, Caterers',
#  'Pets, Animal Shelters, Pet Stores',
#  'Water Heater Installation/Repair, Septic Services, Contractors, Local Services, Home Services, Plumbing',
#  'Obstetricians & Gynecologists, Doctors, Beauty & Spas, Health & Medical, Skin Care, Midwives',
#  'Tobacco Shops, Food, Beer, Wine & Spirits, Shopping',
#  'Cosmetic Dentists, Oral Surgeons, Periodontists, Health & Medical, General Dentistry, Dentists',
#  'Event Planning & Services, Hotels & Travel, Hotels',
#  'Gluten-Free, Wine Bars, Restaurants, Italian, Pizza, Nightlife, Bars',
#  'Caterers, Restaurants, Event Planning & Services, Delis',
#  'Restaurants, Sushi Bars, Desserts, Food, Japanese',
#  'Home Inspectors, Home Services',
#  'Restaurants, Mexican',
#  'Restaurants, Coffee & Tea, Delis, Bagels, Food',
#  'American (Traditional), Pizza, Food, Restaurants',
#  'Reiki, Health & Medical, Beauty & Spas, Massage, Massage Therapy',
#  "Beauty & Spas, Cosmetics & Beauty Supply, Hair Salons, Shopping, Hair Stylists, Men's Hair Salons",
#  'Hair Removal, Waxing, Beauty & Spas, Hair Salons',
#  'American (New), Italian, Restaurants, Event Planning & Services, Food, Coffee & Tea, Caterers',
#  'Restaurants, Sushi Bars, Japanese, Salad',
#  'Cupcakes, Food',
#  'American (New), Restaurants, Venues & Event Spaces, Event Planning & Services, Breakfast & Brunch',
#  'Car Dealers, Automotive',
#  'Bakeries, Delis, Italian, Restaurants, Food',
#  'Pet Services, Pet Groomers, Pet Stores, Pets',
#  'Tires, Automotive, Auto Repair, Oil Change Stations',
#  'Restaurants, Korean',
#  'Seafood, Restaurants, Soul Food, Southern',
#  'Doctors, Audiologist, Hospitals, Rehabilitation Center, Physical Therapy, Health & Medical, Occupational Therapy, Speech Therapists',
#  'Waxing, Eyelash Service, Beauty & Spas, Nail Salons, Hair Removal',
#  'Pizza, Seafood, Restaurants, American (Traditional), American (New)',
#  'Local Services, Junk Removal & Hauling',
#  'General Dentistry, Dentists, Cosmetic Dentists, Health & Medical',
#  'Hotels & Travel, Public Transportation, Transportation',
#  'Active Life, Yoga, Fitness & Instruction',
#  'Gyms, Climbing, Fitness & Instruction, Active Life',
#  'Home Services, Apartments, Real Estate',
#  'Fast Food, Food, Restaurants, Coffee & Tea, Burgers',
#  'Bikes, Shopping, Sporting Goods, Local Services, Active Life, Bike Repair/Maintenance, Mountain Biking',
#  'Restaurants, American (Traditional)',
#  'Restaurants, American (Traditional), Sandwiches',
#  'Restaurants, Diners',
#  'Towing, Automotive, Roadside Assistance',
#  'Automotive, Car Dealers',
#  'Utilities, Home Services',
#  'Hair Salons, Beauty & Spas, Waxing, Hair Removal',
#  'Doctors, Optometrists, Shopping, Eyewear & Opticians, Health & Medical',
#  'Breakfast & Brunch, Pizza, Greek, Restaurants, Food',
#  'Food, Pakistani, Indian, Specialty Food, Ethnic Food, Restaurants',
#  'Shopping, Vape Shops, Electronics, Tobacco Shops',
#  'Home Services, Gutter Services, Contractors',
#  'Professional Services, IT Services & Computer Repair, Telecommunications, Television Service Providers, Local Services, Internet Service Providers, Home Services',
#  'Food Court, Shopping, Shopping Centers, IT Services & Computer Repair, Local Services, Souvenir Shops, Restaurants',
#  'Used Car Dealers, Automotive, Car Dealers',
#  'Latin American, Restaurants',
#  'Arts & Entertainment, Cinema',
#  'Beauty & Spas, Shopping, Cosmetics & Beauty Supply, Hair Salons',
#  'Sandwiches, Restaurants, Bagels, Coffee Roasteries, Coffee & Tea, Food',
#  'Grocery, Personal Shopping, Specialty Food, Food, Shopping',
#  'Ice Cream & Frozen Yogurt, Cafes, Juice Bars & Smoothies, Coffee & Tea, Food, Restaurants, Desserts',
#  'Rheumatologists, Doctors, Health & Medical',
#  'Food, Caterers, Event Planning & Services, Restaurants, Soul Food',
#  'Fitness & Instruction, Active Life, Swimming Lessons/Schools, Education, Specialty Schools',
#  'Food, Farmers Market',
#  'Diners, Food, Restaurants',
#  'Restaurants, Breakfast & Brunch, Food, Juice Bars & Smoothies, American (New), Coffee & Tea, Sandwiches',
#  'Food, Bagels, Restaurants',
#  'Bike Repair/Maintenance, Local Services, Sporting Goods, Bikes, Shopping',
#  'Eyebrow Services, Nail Salons, Beauty & Spas, Hair Removal, Waxing',
#  "Thrift Stores, Used, Vintage & Consignment, Accessories, Women's Clothing, Shopping, Fashion",
#  'Sandwiches, Cheesesteaks, Vegetarian, Restaurants, Salad',
#  'Automotive, Car Wash',
#  'Desserts, Food',
#  'Doctors, Ear Nose & Throat, Health & Medical, Allergists, Audiologist, Cosmetic Surgeons',
#  'Tours, Local Flavor, Hotels & Travel',
#  'Venues & Event Spaces, Hotels, Event Planning & Services, Hotels & Travel',
#  'Pediatric Dentists, Oral Surgeons, Health & Medical, General Dentistry, Endodontists, Cosmetic Dentists, Dentists, Periodontists',
#  'Italian, Restaurants, Pizza',
#  'Books, Mags, Music & Video, Shopping, Video Game Stores, Videos & Video Game Rental, Electronics',
#  'Counseling & Mental Health, Health & Medical',
#  'Specialty Food, Caterers, Meat Shops, Food, Event Planning & Services',
#  'Food, Ice Cream & Frozen Yogurt',
#  'Health & Medical, General Dentistry, Dentists',
#  'Salad, Restaurants, American (Traditional), Food, Sandwiches, Do-It-Yourself Food, Soup, Vegetarian, American (New)',
#  None,
#  'Pizza, Food, Bagels, Sandwiches, Comfort Food, Breakfast & Brunch, Burgers, American (New), Nightlife, Bars, Wine Bars, Restaurants',
#  'Shopping, Food, Gift Shops, Chocolatiers & Shops, Flowers & Gifts, Florists, Fruits & Veggies, Specialty Food',
#  'Restaurants, Chinese, Asian Fusion',
#  'Restaurants, Chinese, Szechuan',
#  'Community Service/Non-Profit, Local Services, Active Life, Botanical Gardens, Arts & Entertainment, Local Flavor, Parks',
#  'Burgers, Venues & Event Spaces, Diners, Restaurants, Event Planning & Services, Nightlife, Active Life, Bars, American (Traditional), Golf',
#  'Used Car Dealers, Car Dealers, Automotive',
#  'Restaurants, Sandwiches, Food, Delis, Grocery, Coffee & Tea',
#  "Shopping, Department Stores, Fashion, Accessories, Men's Clothing, Women's Clothing, Home Decor, Children's Clothing, Home & Garden",
#  'Diners, Seafood, Restaurants',
#  'Restaurants, Breakfast & Brunch, Diners, Sandwiches, Burgers, Seafood',
#  'Food, Beer Bar, Bars, Nightlife, Restaurants, Cheesesteaks, Chicken Wings, Pizza, Beer, Wine & Spirits',
#  'Pets, Pet Groomers, Pet Services',
#  'Pet Services, Pets, Pet Groomers',
#  'Restaurants, Sandwiches, Chicken Wings, Pizza',
#  'Beauty & Spas, Hair Stylists, Hair Salons, Makeup Artists',
#  'Hotels & Travel, Event Planning & Services, Venues & Event Spaces, Hotels, Wedding Planning',
#  'Automotive, Auto Repair, Gas Stations, Oil Change Stations',
#  'Delis, Convenience Stores, Restaurants, Cafes, Food',
#  'Restaurants, Food, Coffee & Tea, Sandwiches, Breakfast & Brunch, Cafes',
#  'Beauty & Spas, Barbers',
#  'Pizza, Restaurants, Gelato, Coffee & Tea, Ice Cream & Frozen Yogurt, Food',
#  'Coffee & Tea, Fast Food, Food, Burgers, Restaurants',
#  'Home Services, Landscaping',
#  'Self Storage, Local Services',
#  'RV Parks, Car Dealers, RV Dealers, RV Repair, Hotels & Travel, Auto Repair, RV Rental, Automotive',
#  'Cycling Classes, Active Life, Gyms, Fitness & Instruction',
#  'Event Planning & Services, Venues & Event Spaces',
#  'Barbeque, Bars, Nightlife, Restaurants',
#  'Restaurants, Seafood',
#  'Sporting Goods, Shopping, Sports Clubs, Active Life, Archery',
#  'Home & Garden, Shopping, Furniture Stores, Interior Design, Home Services',
#  'Massage Therapy, Beauty & Spas, Massage, Health & Medical',
#  'Restaurants, Japanese',
#  'Beer, Wine & Spirits, Event Planning & Services, Food, Party Supplies',
#  'Nightlife, Arts & Entertainment, Comedy Clubs, Performing Arts',
#  'Home Services, Real Estate Services, Real Estate',
#  'Burgers, American (Traditional), Karaoke, Pubs, Restaurants, Nightlife, Bars',
#  'Restaurants, Burgers, Fast Food',
#  'Restaurants, American (New), Wine Tasting Classes, Beer, Wine & Spirits, Food, Education, Italian, Bars, Nightlife, Wine Bars, Tasting Classes',
#  'Golf, Mini Golf, Venues & Event Spaces, Active Life, Event Planning & Services',
#  'Restaurants, Pizza, Italian, Pasta Shops, Specialty Food, Food',
#  "Shopping, Fashion, Sports Wear, Children's Clothing, Sporting Goods, Men's Clothing, Women's Clothing",
#  'Breakfast & Brunch, Restaurants, Coffee & Tea, Food, Sandwiches, American (New)',
#  'Auto Repair, Automotive, Tires, Oil Change Stations',
#  'Vietnamese, Noodles, Restaurants',
#  'Shopping, Flowers & Gifts, Florists',
#  'Bagels, Breakfast & Brunch, Food, Restaurants, Sandwiches',
#  'Grocery, Flowers & Gifts, Beer, Wine & Spirits, Specialty Food, Shopping, Florists, Food',
#  'Sushi Bars, Japanese, Restaurants',
#  'Pizza, Barbeque, Salad, Restaurants, Sandwiches',
#  'Active Life, Fishing, Guns & Ammo, Sporting Goods, Shopping, Outdoor Gear',
#  'Automotive, Transmission Repair, Tires, Oil Change Stations, Auto Repair',
#  'Coffee & Tea, Food, Convenience Stores, Drugstores, Shopping',
#  'Appliances, Nurseries & Gardening, Hardware Stores, Home & Garden, Shopping, Home Services, Building Supplies',
#  'Day Spas, Nail Salons, Hair Salons, Beauty & Spas',
#  'Event Planning & Services, American (New), Fish & Chips, Burgers, Restaurants, Venues & Event Spaces',
#  'Digitizing Services, Hotels & Travel, Photography Stores & Services, Shopping, Passport & Visa Services, Local Services, Printing Services, Travel Services, Professional Services',
#  'Food, Ice Cream & Frozen Yogurt, Juice Bars & Smoothies, Coffee & Tea',
#  'Local Flavor',
#  "Used, Vintage & Consignment, Art Galleries, Fashion, Antiques, Shopping, Women's Clothing, Arts & Entertainment",
#  'Hair Salons, Beauty & Spas, Hair Stylists, Nail Salons',
#  'Gun/Rifle Ranges, Active Life',
#  'Diagnostic Imaging, Health & Medical, Professional Services, Diagnostic Services',
#  'Local Services, Home Services, Carpet Cleaning, Air Duct Cleaning, Pressure Washers, Damage Restoration',
#  'Cheesesteaks, Chicken Wings, Restaurants, Pizza',
#  'Caterers, Event Planning & Services',
#  "Men's Clothing, Notaries, Shipping Centers, Shopping, Local Services, Fashion, Printing Services, Mailbox Centers",
#  'American (Traditional), Restaurants, Tapas/Small Plates, Desserts, Bars, American (New), Gluten-Free, Nightlife, Food',
#  'Real Estate Services, Real Estate, Home Services, Pressure Washers, Gutter Services, Home Cleaning, Tiling',
#  'Discount Store, Shopping, Food, Outlet Stores, Grocery',
#  'Bars, Sports Bars, Adult Entertainment, Nightlife',
#  'Doctors, General Dentistry, Dentists, Health & Medical',
#  'Seafood Markets, Specialty Food, Food',
#  'Coffee & Tea, Donuts, Food',
#  'Food Trucks, Specialty Food, Food',
#  'Massage Therapy, Beauty & Spas, Health & Medical, Day Spas, Reflexology',
#  'Optometrists, Shopping, Eyewear & Opticians, Health & Medical, Doctors, Ophthalmologists',
#  'Seafood, Restaurants, Chinese',
#  'Restaurants, Food, Donuts, Mexican',
#  'Cosmetic Dentists, Dentists, General Dentistry, Health & Medical, Endodontists',
#  'Grocery, Shopping, Drugstores, Food',
#  'Landscaping, Local Services, Pest Control, Lawn Services, Professional Services, Home Services',
#  'Restaurants, Food Court',
#  'Donuts, Coffee & Tea, Food',
#  'Caterers, Mexican, Restaurants, Event Planning & Services',
#  'Beauty & Spas, Hair Salons, Tanning, Skin Care, Massage, Hair Removal',
#  'Pretzels, Candy Stores, Food, Specialty Food, Herbs & Spices, Coffee & Tea',
#  'Damage Restoration, Local Services, Home Cleaning, Carpet Cleaning, Shopping, Home Services, Air Duct Cleaning, Home & Garden',
#  'Massage, Health & Medical, Massage Schools, Beauty & Spas, Day Spas, Massage Therapy, Education, Childbirth Education, Specialty Schools',
#  'Food, Breakfast & Brunch, Convenience Stores, Sandwiches, Delis, Restaurants, Wraps',
#  'Environmental Testing, Local Services, Home Inspectors, Home Services',
#  'Coffee & Tea, Food, Cafes, Restaurants',
#  'Delis, Food, Coffee & Tea, Restaurants',
#  'Italian, Pizza, Restaurants, American (Traditional), Bars, Nightlife, American (New)',
#  'Auto Repair, Automotive, Gas Stations',
#  'Shopping, Home & Garden, Grilling Equipment, Kitchen & Bath, Appliances, Mattresses, Appliances & Repair, Local Services',
#  'Chinese, Restaurants, Vietnamese, Asian Fusion',
#  'Home Services, Painters, Contractors',
#  'Seafood, Restaurants',
#  'Computers, Shopping, Mobile Phones, Local Services, IT Services & Computer Repair',
#  'Coffee & Tea, Food, Donuts',
#  'Home Services',
#  'Restaurants, American (New), Nightlife, American (Traditional), Pubs, Southern, Bars, Gastropubs',
#  'Restaurants, African',
#  'Restaurants, Barbeque',
#  'Local Services, Shipping Centers',
#  'Fruits & Veggies, Specialty Food, Food',
#  'Shopping, Home & Garden, Nurseries & Gardening, Appliances, Building Supplies, Hardware Stores, Home Services',
#  'Doctors, Hair Removal, Health & Medical, Beauty & Spas, Dermatologists',
#  'Water Delivery, Water Purification Services, Home Services, Local Services',
#  'Electricians, Generator Installation/Repair, Lighting Fixtures & Equipment, Local Services, Home Services',
#  'Home & Garden, Furniture Stores, Shopping',
#  'Food, Restaurants, Asian Fusion',
#  'Massage Therapy, Beauty & Spas, Health & Medical, Massage',
#  'Local Services, Water Stores, Home Services, Water Purification Services, Food, Water Delivery',
#  'Tree Services, Contractors, Home Services, Landscaping',
#  'Food, Food Trucks',
#  'Active Life, Fitness & Instruction, Boot Camps, Gyms, Trainers',
#  'Escape Games, Active Life',
#  'Employment Agencies, Professional Services',
#  'Delis, Restaurants',
#  'Restaurants, Fast Food, Burgers, Coffee & Tea, Food',
#  'Laundry Services, Local Services, Laundromat, Dry Cleaning & Laundry',
#  'Pet Stores, Pets',
#  'Security Systems, Professional Services, Private Investigation, Home Services',
#  'Beauty & Spas, IV Hydration, Medical Spas, Health & Medical',
#  'Food, Restaurants, Seafood',
#  'Restaurants, Sushi Bars, Food, Chinese',
#  'Shopping, Appliances, Appliances & Repair, Mattresses, Home & Garden, Local Services, Outlet Stores, Furniture Stores',
#  'Health & Medical, Shopping, Fashion, Optometrists, Accessories, Eyewear & Opticians',
#  'Hotels & Travel, Car Rental',
#  'Tanning, Hair Removal, Eyelash Service, Spray Tanning, Beauty & Spas, Skin Care',
#  'Oral Surgeons, Pediatric Dentists, Police Departments, Public Services & Government, Health & Medical, Dentists',
#  'Food, Breweries',
#  'Food, Juice Bars & Smoothies, Coffee & Tea, Restaurants, Bakeries, Cafes',
#  'Health & Medical, Pharmacy, Drugstores, Food, Convenience Stores, Shopping',
#  'Restaurants, Pubs, Bars, Irish, Nightlife',
#  'Food, Vegetarian, Cafes, Vegan, Food Delivery Services, Gluten-Free, Event Planning & Services, Caterers, Restaurants',
#  'Couriers & Delivery Services, Local Services',
#  'Local Services, Community Service/Non-Profit',
#  'Flooring, Painters, Home Services, Contractors, Handyman',
#  'Tires, Automotive',
#  'Pet Training, Pet Services, Pets, Dog Walkers, Pet Sitting',
#  'Barbeque, Restaurants',
#  'Gyms, Active Life, Trainers, Fitness & Instruction, Yoga, Sports Clubs',
#  'Drugstores, Health & Medical, Convenience Stores, Pharmacy, Shopping, Food',
#  'Auto Repair, Wheel & Rim Repair, Automotive, Tires, Oil Change Stations',
#  'Fast Food, Restaurants, Burgers',
#  'Chicken Wings, Restaurants, Sandwiches, Pizza',
#  'Self Storage, Home Services, Local Services, Couriers & Delivery Services, Movers, Home Cleaning',
#  'Amusement Parks, Parks, Active Life, Party & Event Planning, Event Planning & Services, Kids Activities',
#  'Restaurants, Breakfast & Brunch',
#  'Thrift Stores, Used, Vintage & Consignment, Fashion, Shopping',
#  'Restaurants, Vietnamese, Cafes',
#  'Gas Stations, Oil Change Stations, Car Wash, Auto Detailing, Automotive',
#  "Fashion, Women's Clothing, Flowers & Gifts, Shopping, Jewelry, Accessories, Gift Shops",
#  'Roofing, Home Services',
#  'Recycling Center, Home Services, Movers, Local Services, Junk Removal & Hauling, Shopping, Self Storage, Home Staging, Furniture Stores, Home & Garden, Real Estate',
#  'Cheesesteaks, Restaurants, Pizza, Chicken Wings',
#  'Recycling Center, Local Services, Junkyards, Junk Removal & Hauling',
#  'Barbeque, Restaurants, Steakhouses, American (Traditional)',
#  'Nightlife, Sports Bars, American (New), Bars, Restaurants',
#  'Beauty & Spas, Cosmetics & Beauty Supply, Shopping',
#  'Internet Service Providers, Mobile Phones, Electronics, Professional Services, Shopping, Home Services',
#  'Restaurants, Pubs, Food, Bars, American (New), Nightlife',
#  'Health & Medical, Orthodontists, Oral Surgeons, Dentists, General Dentistry, Endodontists, Cosmetic Dentists',
#  'Bridal, Shopping',
#  'American (New), Restaurants, American (Traditional)',
#  'Restaurants, Coffee & Tea, Food',
#  'Furniture Stores, Mattresses, Home Decor, Home & Garden, Shopping',
#  'Irish Pub, Restaurants, Sports Bars, American (Traditional), Pubs, Bars, Nightlife',
#  'Lounges, Sports Bars, Bars, Cocktail Bars, Nightlife, Restaurants, American (Traditional)',
#  'Pizza, Restaurants, Italian, Desserts, Food',
#  'Hobby Shops, Shopping',
#  'Auto Repair, Automotive, Tires, Transmission Repair',
#  'Dive Bars, Restaurants, American (Traditional), Nightlife, Bars',
#  'Florists, Shopping, Accessories, Fashion, Gift Shops, Flowers & Gifts',
#  'Massage, Beauty & Spas, Day Spas, Skin Care',
#  'Refinishing Services, Home Services, Flooring',
#  'Arts & Entertainment, Amusement Parks, Recreation Centers, Museums, Playgrounds, Active Life',
#  'Oil Change Stations, Auto Repair, Transmission Repair, Body Shops, Towing, Automotive, Tires',
#  'Hair Removal, Waxing, Beauty & Spas, Skin Care',
#  'Restaurants, Italian, Pizza',
#  'Thai, Restaurants',
#  'Waterproofing, Plumbing, Flooring, Contractors, Home Services',
#  'Hot Dogs, Bars, Restaurants, Nightlife, American (Traditional), Mexican, Salad, Tacos, Fish & Chips, Burgers',
#  'Eyelash Service, Massage, Nail Salons, Hair Extensions, Beauty & Spas, Hair Salons',
#  'Hiking, Active Life',
#  'Chiropractors, Health & Medical',
#  'Pet Services, Pet Groomers, Pet Training, Pets, Pet Stores',
#  'American (New), Breakfast & Brunch, Bars, Nightlife, Restaurants',
#  'Local Services, Car Dealers, Car Buyers, Used Car Dealers, Automotive, Appraisal Services',
#  'Mexican, Food Stands, Restaurants, Tacos',
#  'Hotels & Travel, Event Planning & Services, Venues & Event Spaces, Hotels',
#  'Chicken Wings, Fast Food, Restaurants',
# ...
#  'Diagnostic Services, Health & Medical, Laboratory Testing',
#  'Skin Care, Beauty & Spas, Massage, Nail Salons',
#  'Real Estate Services, Home Services, Real Estate',
#  'Flowers & Gifts, Shopping, Florists',
#  'Hair Extensions, Cosmetics & Beauty Supply, Beauty & Spas, Hair Salons, Nail Salons, Kids Hair Salons, Shopping',
#  'Auto Repair, Automotive, Hotels & Travel, Car Rental, Body Shops, Car Dealers',
#  'Bars, Nightlife, Pubs, Sports Bars, American (Traditional), Restaurants',
#  'Active Life, Amateur Sports Teams, Arts & Entertainment, Social Clubs, Sports Clubs',
#  'Restaurants, Breakfast & Brunch, Food, Desserts, Bakeries',
#  'Noodles, Japanese, Restaurants, Sushi Bars',
#  'Beauty & Spas, Makeup Artists, Blow Dry/Out Services, Hair Salons, Hair Extensions',
#  'Restaurants, Fast Food, Mexican',
#  'Active Life, Yoga, Pilates, Cycling Classes, Fitness & Instruction',
#  'Restaurants, Caribbean',
#  'Car Rental, Hotels & Travel, Motorcycle Dealers, Active Life, ATV Rentals/Tours, Motorcycle Repair, Specialty Schools, Automotive, Motorcycle Rental, Firearm Training, Bike Rentals, Education',
#  'Professional Services, Matchmakers',
#  'Bike Rentals, Shopping, Sporting Goods, Active Life, Bikes',
#  'Event Planning & Services, Party & Event Planning, Bartenders, Caterers, Professional Services',
#  'Beauty & Spas, Piercing, Tattoo',
#  'Shopping, Hardware Stores, Guns & Ammo, Home & Garden',
#  'Golf, Venues & Event Spaces, Active Life, Event Planning & Services, Tennis, Arts & Entertainment, Country Clubs',
#  'Eyewear & Opticians, Shopping, Optometrists, Health & Medical',
#  'Food, Restaurants, Beer, Wine & Spirits, Bars, Nightlife, American (Traditional)',
#  'Home & Garden, Hardware Stores, Shopping',
#  'Restaurants, Nightlife, American (Traditional), Bars',
#  'Fitness & Instruction, Yoga, Reiki, Health & Medical, Reflexology, Beauty & Spas, Massage, Active Life',
#  'Pet Sitting, Pets, Dog Walkers, Pet Services',
#  'Shopping, Florists, Home & Garden, Flowers & Gifts, Nurseries & Gardening',
#  'Pediatricians, Doctors, Health & Medical',
#  'Office Equipment, Home Decor, Shopping, Interior Design, Home Organization, Home & Garden, Kitchen & Bath, Furniture Stores, Home Services',
#  'Shopping, Home & Garden, Appliances & Repair, Appliances, Local Services',
#  'Pizza, Breakfast & Brunch, Restaurants',
#  'Bartenders, Caterers, Event Planning & Services, Party Equipment Rentals',
#  'Restaurants, Pizza, Delis',
#  'Zoos, Active Life, Kids Activities, Petting Zoos',
#  'Windows Installation, Roofing, Contractors, Home Services, Siding',
#  'Appliances, Shopping, Home & Garden, Appliances & Repair, Local Services',
#  'Hot Tub & Pool, Pool & Hot Tub Service, Shopping, Home Services, Home & Garden',
#  'Art Restoration, Shopping, Jewelry Repair, Local Services, Jewelry, Watches, Fashion, Watch Repair, Bridal',
#  'Restaurants, Japanese, Asian Fusion',
#  'Diners, Restaurants, Comfort Food',
#  'Oil Change Stations, Auto Parts & Supplies, Tires, Auto Repair, Automotive',
#  'Home & Garden, Kitchen & Bath, Shopping',
#  'Financial Services, Mortgage Brokers, Home Services, Real Estate, Banks & Credit Unions',
#  'Fitness & Instruction, Gyms, Active Life, Trainers',
#  'Restaurants, American (New), American (Traditional), Pizza, Gluten-Free',
#  'Dry Cleaning & Laundry, Local Services, Laundry Services',
#  'Traditional Chinese Medicine, Health & Medical, Massage Therapy, Beauty & Spas, Massage',
#  'Salad, Italian, Restaurants, Pizza',
#  'Hot Dogs, Restaurants',
#  'Blow Dry/Out Services, Beauty & Spas, Hair Salons, Hair Stylists',
#  'Contractors, Electricians, Home Services, Plumbing, Heating & Air Conditioning/HVAC',
#  'Gardeners, Shopping, Snow Removal, Home Services, Local Services, Nurseries & Gardening, Landscaping, Home & Garden, Landscape Architects, Tree Services, Masonry/Concrete',
#  'Beer Bar, Bars, American (New), Gastropubs, Restaurants, Nightlife, Burgers',
#  'Hotels & Travel, Event Planning & Services, Hotels, Venues & Event Spaces',
#  'Breakfast & Brunch, Coffee & Tea, Restaurants, Donuts, Food',
#  'Orthopedists, Nutritionists, Pilates, Fitness & Instruction, Sports Medicine, Physical Therapy, Doctors, Active Life, Rehabilitation Center, Health & Medical, Acupuncture',
#  'Pizza, Sandwiches, Cheesesteaks, Restaurants',
#  'Spray Tanning, Skin Care, Makeup Artists, Beauty & Spas, Hair Removal, Waxing, Tanning, Teeth Whitening',
#  'Emergency Pet Hospital, Pets, Pet Services, Veterinarians, Orthopedists, Health & Medical, Doctors',
#  'Car Wash, Automotive, Auto Detailing',
#  'Beer Gardens, Nightlife',
#  'Oral Surgeons, Dentists, General Dentistry, Health & Medical, Cosmetic Dentists',
#  'Italian, Chicken Wings, Restaurants, Pizza',
#  'Shopping, Local Services, Furniture Stores, Interior Design, Home Services, Furniture Repair, Home & Garden, Furniture Assembly, Carpenters',
#  'Active Life, Local Services, Fitness & Instruction, Child Care & Day Care, Gyms',
#  'American (Traditional), Fast Food, Restaurants, Chicken Wings, Food, Seafood, Sandwiches, Wraps, Burgers',
#  'Movers, Home Services',
#  'Nightlife, Bars, American (New), Restaurants, Italian, Cocktail Bars, Mediterranean, Seafood',
#  'Coffee & Tea, Cafes, Food, Creperies, Internet Cafes, Restaurants, Breakfast & Brunch',
#  'Delis, Restaurants, Italian, Local Flavor, Sandwiches',
#  'Restaurants, Buffets, Chinese, Japanese',
#  'Breweries, Food, Brewpubs',
#  'Dermatologists, Hair Removal, Laser Hair Removal, Skin Care, Doctors, Health & Medical, Beauty & Spas',
#  'Restaurants, Food, Ethnic Food, Cafes, Caribbean, Specialty Food',
#  'Grocery, Home & Garden, Furniture Stores, Food, Department Stores, Shopping, Electronics, Fashion',
#  'Towing, Tires, Oil Change Stations, Automotive, Roadside Assistance',
#  'Test Preparation, Specialty Schools, Adult Education, Education',
#  'Vegan, Restaurants, Fast Food, Cheesesteaks',
#  'Local Services, Septic Services, Plumbing, Home Services',
#  'Education, Specialty Schools',
#  'Automotive, Tires, Gas Stations, Auto Repair, Oil Change Stations, Transmission Repair',
#  'Active Life, Arts & Entertainment, Venues & Event Spaces, Axe Throwing, Arcades, Summer Camps, Party & Event Planning, Fitness & Instruction, Go Karts, Event Planning & Services, Virtual Reality Centers',
#  'Food, Ice Cream & Frozen Yogurt, Desserts',
#  'Hotels & Travel, Hotels, Event Planning & Services',
#  'Day Spas, Beauty & Spas, Hair Salons',
#  'Beauty & Spas, Health & Medical, Nail Salons, Medical Spas, Hair Salons, Hair Stylists',
#  'Body Shops, Used Car Dealers, Automotive, Auto Repair',
#  'Barbers, Hair Salons, Beauty & Spas, Hair Removal, Waxing, Hair Stylists',
#  'Food, Cupcakes, Custom Cakes, Desserts, Ice Cream & Frozen Yogurt',
#  'Auto Repair, Tires, Wheel & Rim Repair, Automotive, Auto Detailing',
#  'Latin American, Caribbean, Cuban, Restaurants',
#  'Restaurants, Sandwiches, Gas Stations, Coffee & Tea, Automotive, Convenience Stores, Food',
#  'Nightlife, Bars, Restaurants, Irish, Pubs',
#  'Home Services, Shopping, Home & Garden, Furniture Stores, Home Decor, Interior Design',
#  'Financial Services, Home Services, Banks & Credit Unions, Investing, Mortgage Brokers, Real Estate',
#  'Dry Cleaning & Laundry, Local Services, Dry Cleaning, Laundry Services',
#  'Taiwanese, Chinese, Noodles, Restaurants',
#  'Restaurants, Breakfast & Brunch, Delis, Sandwiches',
#  'Steakhouses, Restaurants, Japanese, Sushi Bars',
#  'Japanese, Chicken Wings, Fast Food, Restaurants',
#  'Italian, Pizza, Restaurants',
#  'Mobile Phones, Telecommunications, Electronics, Mobile Phone Accessories, Shopping, IT Services & Computer Repair, Local Services',
#  'Active Life, Yoga, Fitness & Instruction, Health & Medical',
#  'Caribbean, Food, Restaurants',
#  'Beer Bar, Nightlife, Breweries, Bars, Food',
#  'Child Care & Day Care, Local Services, Preschools, Education, Elementary Schools',
#  'Mobile Phone Accessories, Electronics Repair, IT Services & Computer Repair, Shopping, Mobile Phone Repair, Local Services',
#  "Beauty & Spas, Barbers, Hair Stylists, Men's Hair Salons, Hair Salons",
#  'Car Stereo Installation, Automotive',
#  'Financial Services, Banks & Credit Unions',
#  'Pizza, Restaurants, American (New), American (Traditional)',
#  'Bakeries, Custom Cakes, Food, Event Planning & Services, Party Supplies, Restaurants',
#  'Videos & Video Game Rental, Shopping, Books, Mags, Music & Video',
#  'Mexican, Italian, Food Trucks, Restaurants, Food',
#  'Doctors, Optometrists, Health & Medical, Ophthalmologists, Shopping, Eyewear & Opticians',
#  'Beer, Wine & Spirits, American (Traditional), Bars, Food, Restaurants, Nightlife',
#  'Pediatric Dentists, Endodontists, Cosmetic Dentists, Health & Medical, Dentists',
#  'Restaurants, Burgers, Italian, Salad, Pizza',
#  'Snow Removal, Home Services, Professional Services, Lawn Services, Tree Services, Pest Control, Local Services, Landscaping',
#  'Generator Installation/Repair, Local Services, Electricians, Home Services',
#  'Plumbing, Contractors, Home Services, Heating & Air Conditioning/HVAC',
#  'Home Services, Contractors, Drywall Installation & Repair',
#  'Drugstores, Medical Centers, Shopping, Health & Medical',
#  'American (Traditional), Spanish, Restaurants, Food Trucks, Mexican, Food',
#  'Massage, Health & Medical, Massage Therapy, Day Spas, Beauty & Spas, Skin Care',
#  'Breakfast & Brunch, American (Traditional), Restaurants, Local Flavor, Event Planning & Services, Bakeries, Food, Delis, Donuts, American (New), Caterers, Ice Cream & Frozen Yogurt, Desserts',
#  'Car Dealers, Auto Repair, Automotive',
#  "Formal Wear, Men's Clothing, Fashion, Shopping, Accessories",
#  'Food, Specialty Food, Macarons',
#  'Diners, Food, Breakfast & Brunch, Restaurants, Donuts, Desserts',
#  'Pet Stores, Pet Groomers, Pets, Pet Adoption, Pet Services',
#  'Gun/Rifle Ranges, Guns & Ammo, Shopping, Active Life',
#  'Restaurants, American (New)',
#  'Local Services, Fingerprinting',
#  'Oral Surgeons, Health & Medical, Sleep Specialists, General Dentistry, Dentists, Cosmetic Dentists',
#  'Food, Bakeries, Delis, Sandwiches, Restaurants',
#  'American (New), Bars, Beer Bar, Nightlife, Restaurants, Cocktail Bars, Salad',
#  'Laser Tag, Arts & Entertainment, Party & Event Planning, Recreation Centers, Event Planning & Services, Amusement Parks, Active Life',
#  'Physical Therapy, Fitness & Instruction, Gyms, Active Life, Health & Medical, Trainers',
#  'Mini Golf, Amusement Parks, Active Life',
#  'Italian, Wine Bars, Restaurants, Bars, Nightlife, Pizza',
#  'Tex-Mex, Restaurants, Fast Food, Tacos, Mexican, Breakfast & Brunch',
#  'Bars, Gelato, Breakfast & Brunch, Italian, Food, Nightlife, Restaurants, Pizza',
#  'Restaurants, American (New), Burgers, Breakfast & Brunch, Sandwiches',
#  'Shopping, Discount Store',
#  'Piercing, Art Galleries, Tattoo, Beauty & Spas, Arts & Entertainment, Shopping',
#  'Chinese, Cantonese, Noodles, Restaurants',
#  'Fashion, Head Shops, Shopping, Vape Shops, Arts & Entertainment, Art Galleries, Jewelry, Tobacco Shops',
#  'Electricians, Home Services',
#  'Beauty & Spas, Makeup Artists, Hair Salons, Hair Extensions',
#  'Steakhouses, Cheesesteaks, Food, Restaurants',
#  'Cinema, Jazz & Blues, Performing Arts, Arts & Entertainment, Nightlife, Music Venues',
#  'Pet Groomers, Pets, Pet Services',
#  'Restaurants, Cafes, Creperies',
#  'Restaurants, Food, Cafes, Bakeries, Italian',
#  'Body Shops, Auto Detailing, Automotive, Auto Repair',
#  'Vegetarian, Specialty Food, Health Markets, Halal, Indian, Restaurants, Food',
#  'Sports Bars, Restaurants, Bars, Nightlife',
#  'American (New), Italian, Restaurants',
#  'Food, American (Traditional), Breweries, Restaurants',
#  'Restaurants',
#  'Restaurants, Burgers, Fast Food, Coffee & Tea, Food',
#  'Appliances & Repair, Farming Equipment, Local Services, Sporting Goods, Shopping, Appliances, Home & Garden',
#  'Food, Automotive, Convenience Stores, Coffee & Tea, Gas Stations, Sandwiches, Restaurants',
#  'Bars, Pubs, Irish Pub, Nightlife, Sports Bars, Restaurants, American (New)',
#  'Pet Cremation Services, Pet Services, Pets',
#  'Sandwiches, American (New), Vegetarian, Vegan, Breakfast & Brunch, Restaurants',
#  "Barbers, Men's Clothing, Beauty & Spas, Shopping, Fashion",
#  'Restaurants, Nightlife, Bars, Barbeque, Sports Bars, Dive Bars, Arts & Entertainment, Music Venues',
#  'Transportation, Limos, Hotels & Travel',
#  'Specialty Food, Meat Shops, Shopping, Food',
#  'Shopping, Convenience Stores, Pharmacy, Health & Medical, Food, Drugstores',
#  'Health & Medical, Laboratory Testing, Diagnostic Services',
#  'American (Traditional), Restaurants, Pubs, Bars, Nightlife',
#  'Beauty & Spas, Spray Tanning, Tanning',
#  'Delis, Nightlife, Sports Bars, Bars, American (New), Burgers, Restaurants, Pizza',
#  'Art Supplies, Shopping, Home & Garden, Home Decor, Fabric Stores, Arts & Crafts',
#  'Restaurants, Chicken Shop, American (Traditional)',
#  'Hair Extensions, Hair Salons, Beauty & Spas',
#  'Pet Groomers, Pet Services, Pets, Pet Sitting, Pet Training',
#  'Specialty Food, Fruits & Veggies, Food, Farmers Market',
#  'Pizza, Food, Restaurants',
#  'Steakhouses, Restaurants, Seafood, American (Traditional)',
#  'Soul Food, Restaurants, Caribbean',
#  'American (Traditional), Event Planning & Services, Nightlife, Restaurants, Bars, Venues & Event Spaces',
#  'Pubs, Bars, Restaurants, Diners, American (Traditional), Nightlife, Food, Bakeries',
#  'Food, Specialty Food, Fruits & Veggies',
#  'Shopping, Thrift Stores',
#  'Moroccan, Halal, Restaurants',
#  'Real Estate Agents, Home Services, Real Estate, Real Estate Services',
#  'Department Stores, Food, Grocery, Fashion, Drugstores, Shopping',
#  'Animal Shelters, Pet Adoption, Pets',
#  'Home Services, Mobile Phones, Internet Service Providers, Electronics, Professional Services, Shopping',
#  'Food, Coffee & Tea, Fast Food, Burgers, Restaurants',
#  'Nightlife, Pubs, Bars, American (Traditional), Restaurants',
#  'Restaurants, Bars, Pizza, Nightlife, Italian',
#  'Pizza, American (Traditional), Restaurants, Italian',
#  'Food, Delis, Restaurants, Grocery, Bakeries',
#  'Restaurants, Beer, Wine & Spirits, Food, Indian',
#  'American (Traditional), Irish, Restaurants, Breakfast & Brunch',
#  'Mobile Phone Accessories, Shopping, Professional Services, Internet Service Providers, Home Services, Television Service Providers, Mobile Phones',
#  'Festivals, Arts & Entertainment',
#  'Food, Beer, Wine & Spirits, Pharmacy, Grocery, Health & Medical',
#  'Books, Mags, Music & Video, Newspapers & Magazines, Shopping',
#  'Breakfast & Brunch, American (Traditional), Bars, Restaurants, Nightlife',
#  'Pet Groomers, Pet Stores, Pet Services, Pet Training, Pets, Pet Sitting',
#  'Contractors, Home Services, Water Heater Installation/Repair, Plumbing',
#  'Coffee & Tea, American (New), Restaurants, Food',
#  'Hair Salons, Day Spas, Beauty & Spas, Hair Removal',
#  'Tacos, Salad, Gluten-Free, Burgers, Mexican, Pizza, Restaurants, Sandwiches, Italian, Caterers, Event Planning & Services, Cheesesteaks',
#  'Shopping, Grocery, Wholesale Stores, Food',
#  'Pet Services, Pets, Veterinarians',
#  'Beauty & Spas, Hair Salons, Hair Stylists',
#  'Restaurants, Caribbean, Soul Food',
#  'Shoe Repair, Local Services',
#  'Bars, Pubs, Nightlife',
#  'Caribbean, Restaurants',
#  'Restaurants, Pizza, Food, Food Trucks',
#  'Local Flavor, Landmarks & Historical Buildings, Public Services & Government',
#  'Bars, Jazz & Blues, Arts & Entertainment, Nightlife',
#  'Tattoo, Beauty & Spas',
#  'Pet Stores, Pets, Pet Adoption, Animal Shelters',
#  'Home & Garden, Nurseries & Gardening, Shopping',
#  'Burgers, Food, Coffee & Tea, Restaurants, Fast Food',
#  'Beer, Wine & Spirits, Restaurants, Specialty Food, Food, Sandwiches, Delis, Fruits & Veggies, Grocery',
#  "Accessories, Shopping, Men's Clothing, Fashion, Women's Clothing",
#  'Sandwiches, Pizza, Chicken Wings, Restaurants',
#  'Restaurants, Sandwiches',
#  'Bars, Ethiopian, Coffee & Tea, Nightlife, Sandwiches, Breakfast & Brunch, Food, Restaurants',
#  'Bridal, Cards & Stationery, Office Equipment, Shopping, Arts & Crafts, Event Planning & Services, Home & Garden, Flowers & Gifts, Home Decor, Gift Shops',
#  'General Dentistry, Dentists, Health & Medical',
#  ...]

# %%
# plot
fig, ax = plt.subplots(figsize=(20,20))
bizPhil.to_crs('EPSG: 3857').plot(ax=ax, color = 'red')
ctx.add_basemap(ax)

plt.savefig('images/yelp_philly.png', dpi=300)

# %%
# plot
fig, ax = plt.subplots(figsize=(20,20))
bizGdf.to_crs('EPSG: 3857').plot(ax=ax, color = 'red')
ctx.add_basemap(ax)

plt.savefig('images/yelp_country.png', dpi=300)

# %% [markdown]
# ## Bring in reviews for Philadelphia area

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Reset kernel before running loop! Takes 30+ mins to run
# </div>

# %%
# create jsonreader object
reader = pd.read_json('/Users/harper/Documents/GitHub/yelp_dataset/yelp_academic_dataset_review.json', 
                    orient = 'records', lines=True, chunksize=1000)

# initialize empty dataframe
colnames = ['review_id','user_id','business_id','stars','useful','funny','cool','text','date']
reviews = pd.DataFrame(columns = colnames)

# iterate through, filter for state, then add each chunk to the dataframe.
for chunk in reader:
    subset = chunk[chunk['business_id'].isin(bizPhil.business_id)]
    reviews = pd.concat([reviews, subset])

# %%
reviews.to_pickle('data/reviewsPhil.pandas')

# %%
reviews.to_csv('data/reviewsPhil.csv')

# %%
# just for testing -- dont run
limit = 10 
for index,chunk in zip(range(limit), reader):
    subset = chunk[chunk['business_id'].isin(bizPhil.business_id)]
    reviews = pd.concat([reviews, subset])

# %% [markdown]
# ## Gay Businesses in Philadelphia

# %% [markdown]
# First, bring in Michael's list of the names of gay businesses in philadelphia. Then subset the bizDf for business names in the gay business list. Then use that subset to bring in review only for those businesses. Then pickle those reviews and bring them over to NLP and just run through that script.

# %% [markdown]
# ## Filter business JSON for gay business in Philadelphia

# %%
# read in gay businesses and biz id 
gaybiz = pd.read_csv('data/philly_gay_businesses.csv')

# %%
# create jsonreader object
reader = pd.read_json('/Users/harper/Documents/GitHub/yelp_dataset/yelp_academic_dataset_review.json', 
                    orient = 'records', lines=True, chunksize=10000)

# initialize empty dataframe
colnames = ['review_id','user_id','business_id','stars','useful','funny','cool','text','date']
reviews = pd.DataFrame(columns = colnames)

# iterate through, filter for state, then add each chunk to the dataframe.
for chunk in reader:
    subset = chunk[chunk['business_id'].isin(gaybiz.business_id)]
    reviews = pd.concat([reviews, subset])

# %%
reviews.to_pickle('data/gay_reviews_phil.pandas')

# %%
reviews.to_csv('data/gay_reviews_phil.csv')

# %%
# just for testing -- dont run
limit = 10 
for index,chunk in zip(range(limit), reader):
    subset = chunk[chunk['business_id'].isin(bizPhil.business_id)]
    reviews = pd.concat([reviews, subset])
