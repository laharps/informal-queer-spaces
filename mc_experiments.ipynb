# %%
#In order to scrap yelp we must identify the best way to identify locations. There are multiple ways to attempt this.
# one avenue is to identify the business listing and scrap the individual page
# an alternative attempt would be to scrape the results page to aggregate a list more quickly 
# High level information to collect would be Name of business, address, lat/lon, neighborhood name, communities it hosts

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.yelp.com/search?find_desc=Gay+Bars&find_loc=seattle%2C+wa'
r = requests.get(url)

soup = BeautifulSoup(r.content)
print(soup.prettify())
#This is very overwhelming but I was able to find the following: Business name, lat/lon, full address, neighborhood name for one listing i was hunting for. Unclear how to filter all the posts this way...
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;">
#  <head>
#   <script>
# /,"js");
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="en-US" http-equiv="Content-Language"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <link content="#FF1A1A" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/>
#   <link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico" rel="shortcut icon"/>
#   <script>
#    window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js">
# ...

# %%
url = 'https://www.yelp.com/biz/diesel-seattle-seattle-2?osq=Gay+Bars'
r = requests.get(url)

soup = BeautifulSoup(r.content)
print(soup.prettify())
#I already hate this...but I must keep a positive attitude
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;">
#  <head>
#   <script>
# /,"js");
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="en-US" http-equiv="Content-Language"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <link content="#FF1A1A" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/>
#   <link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico" rel="shortcut icon"/>
#   <script>
#    window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js">
# ...

# %%
#foursquare api key: fsq33hB8/3RdSR1qMVugLpm2KW73ZNrLunRC8xzmOoEEneU=

# %%
#13011 is the gtegory code for 'gay bar' this is the only formal mention without using reviews to discover other businesses

url = "https://api.foursquare.com/v3/places/search?categories=13011&near=Seattle%2C%20WA&limit=50"

headers = {
    "Accept": "application/json",
    "Authorization": "fsq33hB8/3RdSR1qMVugLpm2KW73ZNrLunRC8xzmOoEEneU="
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"4df4284f18386ecb4e334859","categories":[{"id":13011,"name":"Gay Bar","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_","suffix":".png"}},{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":1553,"geocodes":{"main":{"latitude":47.61327,"longitude":-122.314398},"roof":{"latitude":47.61327,"longitude":-122.314398}},"link":"/v3/places/4df4284f18386ecb4e334859","location":{"address":"1413 14th Ave","census_block":"530330075032006","country":"US","cross_street":"at Madison St","dma":"Seattle-Tacoma","formatted_address":"1413 14th Ave (at Madison St), Seattle, WA 98122","locality":"Seattle","neighborhood":["Capitol Hill"],"postcode":"98122","region":"WA"},"name":"Diesel","related_places":{},"timezone":"America/Los_Angeles"},{"fsq_id":"40e4a580f964a520f4091fe3","categories":[{"id":13010,"name":"Dive Bar","icon":{"prefix":"https://ss3.4sqi.net/img/categ
# ...

# %%
#the output appears to ge a JSON or geoJSON, can I move this into a dataframe

import json
d = json.loads(response.text)
print(type(d))
# Out:
# <class 'dict'>

# %%
print(d.keys())
# Out:
# dict_keys(['results', 'context'])

# %%
print((d['context'].keys()))
# Out:
# dict_keys(['geo_bounds'])

# %%
#print((d['results'].keys()))
#no attribute 'keys'

# %%
print(d['results'][0])
# Out:
# {'fsq_id': '4df4284f18386ecb4e334859', 'categories': [{'id': 13011, 'name': 'Gay Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_', 'suffix': '.png'}}, {'id': 13065, 'name': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'distance': 1553, 'geocodes': {'main': {'latitude': 47.61327, 'longitude': -122.314398}, 'roof': {'latitude': 47.61327, 'longitude': -122.314398}}, 'link': '/v3/places/4df4284f18386ecb4e334859', 'location': {'address': '1413 14th Ave', 'census_block': '530330075032006', 'country': 'US', 'cross_street': 'at Madison St', 'dma': 'Seattle-Tacoma', 'formatted_address': '1413 14th Ave (at Madison St), Seattle, WA 98122', 'locality': 'Seattle', 'neighborhood': ['Capitol Hill'], 'postcode': '98122', 'region': 'WA'}, 'name': 'Diesel', 'related_places': {}, 'timezone': 'America/Los_Angeles'}

# %%
print(d['results'][0]['name'])
print(d['results'][0]['location'])
# Out:
# Diesel
# {'address': '1413 14th Ave', 'census_block': '530330075032006', 'country': 'US', 'cross_street': 'at Madison St', 'dma': 'Seattle-Tacoma', 'formatted_address': '1413 14th Ave (at Madison St), Seattle, WA 98122', 'locality': 'Seattle', 'neighborhood': ['Capitol Hill'], 'postcode': '98122', 'region': 'WA'}

# %%
import pandas as pd
gayDf = pd.DataFrame(d['results'])
gayDf
# Out:
#                       fsq_id  \
# 0   4df4284f18386ecb4e334859
# 1   40e4a580f964a520f4091fe3
# 2   40b13b00f964a520b5f61ee3
# 3   43012c80f964a520fc261fe3
# 4   5300602411d271adabb2fde2
# 5   40b13b00f964a5205bf61ee3
# 6   5b5d3e09de3bbf002c5fe283
# 7   59d82d4f898bdc08036bd851
# 8   5a5052e059c423256ccc3289
# 9   40b13b00f964a520ebf61ee3
# 10  42accc80f964a52035251fe3
# 11  40b13b00f964a5203bf71ee3
# 12  40b13b00f964a52002f71ee3
# 13  483c1c07f964a52016501fe3
# 14  4f883979e4b0298189124b63
# 15  57d0f154cd1044e800fae432
# 16  4cdd043e4e15a09093f3e82b
# 17  4e23d7eaae6015b212bdff83
# 18  5c4f526b5f68b9002c0d7874
# 19  5a51bd79fd9d737c5162405a
#
#                                            categories chains  distance  \
# 0   [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...     []      1553
# 1   [{'id': 13010, 'name': 'Dive Bar', 'icon': {'p...     []      1203
# 2   [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...     []      1514
# ...

# %%
gayDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fsq_id          20 non-null     object
#  1   categories      20 non-null     object
#  2   chains          20 non-null     object
#  3   distance        20 non-null     int64
#  4   geocodes        20 non-null     object
#  5   link            20 non-null     object
#  6   location        20 non-null     object
#  7   name            20 non-null     object
#  8   related_places  20 non-null     object
#  9   timezone        20 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 1.7+ KB

# %%
#can utilize the 'categoris' to map to gay guide categories (when applicable)
#will need to pull out all the location details into own columns to make geoJSON with geometry
#is lat lon in both geocode and location?
#can drop chains, distance, link, and timezone to simplify

# %%
url2 = "https://api.foursquare.com/v3/places/search?query=bath%20house&exclude_all_chains=true&limit=50"

headers2 = {
    "Accept": "application/json",
    "Authorization": "fsq33hB8/3RdSR1qMVugLpm2KW73ZNrLunRC8xzmOoEEneU="
}

response2 = requests.get(url2, headers2=headers)

print(response2.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 8>()
#       1 url2 = "https://api.foursquare.com/v3/places/search?query=bath%20house&exclude_all_chains=true&limit=50"
#       3 headers2 = {
#       4     "Accept": "application/json",
#       5     "Authorization": "fsq33hB8/3RdSR1qMVugLpm2KW73ZNrLunRC8xzmOoEEneU="
#       6 }
# ----> 8 response2 = requests.get(url2, headers2=headers)
#      10 print(response2.text)
#
# File ~/opt/anaconda3/envs/uds/lib/python3.8/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# ...

# %%
bathDf = pd.DataFrame(d['results'])
bathDf
# Out:
#                       fsq_id  \
# 0   4df4284f18386ecb4e334859
# 1   40e4a580f964a520f4091fe3
# 2   40b13b00f964a520b5f61ee3
# 3   43012c80f964a520fc261fe3
# 4   5300602411d271adabb2fde2
# 5   40b13b00f964a5205bf61ee3
# 6   5b5d3e09de3bbf002c5fe283
# 7   59d82d4f898bdc08036bd851
# 8   5a5052e059c423256ccc3289
# 9   40b13b00f964a520ebf61ee3
# 10  42accc80f964a52035251fe3
# 11  40b13b00f964a5203bf71ee3
# 12  40b13b00f964a52002f71ee3
# 13  483c1c07f964a52016501fe3
# 14  4f883979e4b0298189124b63
# 15  57d0f154cd1044e800fae432
# 16  4cdd043e4e15a09093f3e82b
# 17  4e23d7eaae6015b212bdff83
# 18  5c4f526b5f68b9002c0d7874
# 19  5a51bd79fd9d737c5162405a
#
#                                            categories chains  distance  \
# 0   [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...     []      1553
# 1   [{'id': 13010, 'name': 'Dive Bar', 'icon': {'p...     []      1203
# 2   [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...     []      1514
# ...

# %%
url = 'https://seattle.gaycities.com/bars/514-the-cuff-complex'
r = requests.get(url)

soup = BeautifulSoup(r.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <!-- Ad Script -->
#   <!-- [1] Load DFP as normal. -->
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script>
#    window.googletag = window.googletag || {cmd: []};
#   </script>
#   <!-- [2] include the AdBridg library. -->
#   <script type="text/javascript">
#    var AdBridg = AdBridg || {};
#   AdBridg.cmd = AdBridg.cmd || [];
#   (function() {
#       var adb = document.createElement("script");
#       adb.async = true;
#       adb.type = "text/javascript";
#       adb.src = '//prod.adspsp.com/adb.2634970.min.js';
#       var node = document.getElementsByTagName('script')[0];
#       node.parentNode.insertBefore(adb, node);
#
#       // Return control to GPT if the AdBridg library fails to load.
#       adb.onerror = function() {
#         console.log('Fallback: ')
#         if (AdBridg.exists) { return; }
# ...
