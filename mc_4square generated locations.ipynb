# %%
# all the results below are generated with the gay bar code of 13011
import requests
import pandas as pd
import json

# %%
url = "https://api.foursquare.com/v3/places/search?categories=13011&exclude_all_chains=true&near=Philadelphia%2C%20PA&limit=50"

headers = {
    "Accept": "application/json",
    "Authorization": "fsq33hB8/3RdSR1qMVugLpm2KW73ZNrLunRC8xzmOoEEneU="
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"51c4d828498edcb7e3004097","categories":[{"id":10032,"name":"Night Club","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_","suffix":".png"}},{"id":13011,"name":"Gay Bar","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_","suffix":".png"}},{"id":13068,"name":"American Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":588,"geocodes":{"main":{"latitude":39.947224,"longitude":-75.161526},"roof":{"latitude":39.947224,"longitude":-75.161526}},"link":"/v3/places/51c4d828498edcb7e3004097","location":{"address":"243 S Camac St","address_extended":"(Btw Spruce  Locust)","census_block":"421010009011013","country":"US","cross_street":"btwn Locust & Spruce St","dma":"Philadelphia","formatted_address":"243 S Camac St (btwn Locust & Spruce St), Philadelphia, PA 19107","locality":"Philadelphia","neighborhood":["Center City"],"postcode":"19107","regio
# ...

# %%
d = json.loads(response.text)
print(type(d))
# Out:
# <class 'dict'>

# %%
paDf = pd.DataFrame(d['results'])
paDf
# Out:
#                       fsq_id  \
# 0   51c4d828498edcb7e3004097
# 1   4a862930f964a5209e0020e3
# 2   412d2800f964a520d60c1fe3
# 3   5bd13213898bdc0039dab383
# 4   410ed580f964a520c30b1fe3
# 5   40b28c80f964a5203af91ee3
# 6   49ac48a9f964a520b1521fe3
# 7   515a3cece4b0f13084193c99
# 8   5a0796513af9887646948ee9
# 9   4af87235f964a520530d22e3
# 10  5f248409d0112a7dc96afeb3
# 11  4b382cd6f964a520804c25e3
#
#                                            categories chains  distance  \
# 0   [{'id': 10032, 'name': 'Night Club', 'icon': {...     []       588
# 1   [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...     []       561
# 2   [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...     []       530
# 3   [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...     []       636
# 4   [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...     []       535
# 5   [{'id': 13011, 'name': 'Gay Bar', 'icon': {'pr...     []       417
# 6   [{'id': 13009, 'name': 'Cocktail Bar', 'icon':...     []       566
# ...

# %%
#this is the one and ONLY result for Wilmington, DE...it is technically closed but the review might still be helpful
url = "https://api.foursquare.com/v3/places/search?categories=13011&exclude_all_chains=true&near=Wilmington%2C%20DE&limit=50"

headers = {
    "Accept": "application/json",
    "Authorization": "fsq33hB8/3RdSR1qMVugLpm2KW73ZNrLunRC8xzmOoEEneU="
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"4b1583c5f964a520faad23e3","categories":[{"id":10032,"name":"Night Club","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_","suffix":".png"}},{"id":13011,"name":"Gay Bar","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_","suffix":".png"}},{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":2187,"geocodes":{"main":{"latitude":39.750729,"longitude":-75.571461},"roof":{"latitude":39.750729,"longitude":-75.571461}},"link":"/v3/places/4b1583c5f964a520faad23e3","location":{"address":"1909 W 6th St","census_block":"100030014002015","country":"US","cross_street":"btw N Union & N Lincoln","dma":"Philadelphia","formatted_address":"1909 W 6th St (btw N Union & N Lincoln), Wilmington, DE 19805","locality":"Wilmington","neighborhood":["Little Italy"],"postcode":"19805","region":"DE"},"name":"Crimson Moon Tavern","related_places":
# ...

# %%
d2 = json.loads(response.text)
deDf = pd.DataFrame(d2['results'])
deDf
# Out:
#                      fsq_id  \
# 0  4b1583c5f964a520faad23e3
#
#                                           categories chains  distance  \
# 0  [{'id': 10032, 'name': 'Night Club', 'icon': {...     []      2187
#
#                                             geocodes  \
# 0  {'main': {'latitude': 39.750729, 'longitude': ...
#
#                                   link  \
# 0  /v3/places/4b1583c5f964a520faad23e3
#
#                                             location                 name  \
# 0  {'address': '1909 W 6th St', 'census_block': '...  Crimson Moon Tavern
#
#   related_places          timezone
# 0             {}  America/New_York

# %%
#There were no results for Camden, NJ...but if Trenton is part of the dataset see below (not fully convinced these are all relevant...the first result is in Jersey City)

url = "https://api.foursquare.com/v3/places/search?categories=13011&exclude_all_chains=true&near=Trenton%2C%20NJ&limit=50"

headers = {
    "Accept": "application/json",
    "Authorization": "fsq33hB8/3RdSR1qMVugLpm2KW73ZNrLunRC8xzmOoEEneU="
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[],"context":{"geo_bounds":{"circle":{"center":{"latitude":40.21705,"longitude":-74.74294},"radius":3063}}}}

# %%
d3 = json.loads(response.text)
njDf = pd.DataFrame(d3['results'])
njDf
# Out:
# Empty DataFrame
# Columns: []
# Index: []
